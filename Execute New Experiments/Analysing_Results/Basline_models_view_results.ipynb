# %%
from IPython.utils import io
import pandas as pd
import os
from pathlib import Path
from matplotlib import pyplot as plt
from scipy.signal import find_peaks
import numpy as np
import seaborn as sns
import time
import joblib
from os.path import exists
import shutil
import sys
import time
import matplotlib.patches as mpatches


from sklearn.model_selection import train_test_split
#From my EEG package 
import run_expts
import constants

from scipy import stats
import scikit_posthocs as sp

#Let me see as many results as I want to see
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
clf_list = ['Random_Forest' , 'SVC']

#Results dictionary structure : {model : {expt_type : {folder : results_df }}}
results_dict = {}
for clf in clf_list:
    results_dict[clf] = {1 : {} , 2 : {} , 3: {} , 4 : {}}

core_path = '/export/sphere/ebirah/ko20929/RBD_files/notebooks/frequency_analysis/constructed_data/band_power_time_series/expt_dfs/'

folders = ['N1_full_expts', 'N2_full_expts', 'N3_full_expts', 'REM_full_expts', 'EC_full_expts']

files_not_found = []

for num in [1,2,3,4]:
    for folder in folders:
        for clf in clf_list:
            try:
                # os.path.dirname(os.getcwd()) + '/' 
                # This generates path to folder one up from folder in which script is executing
                save_path = os.path.dirname(os.getcwd()) + '/' + 'Results/Results_4/' + clf + 'expt_type_' + str(num) + '_' + folder[:3] + 'int_df.h5'
                results_df = pd.read_hdf(save_path , key='df', mode='r')
            except FileNotFoundError:
                files_not_found.append(save_path)
                continue
                
            res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)           
            results_dict[clf][num][folder] = res_df
            
#Put results in a Df structure that is easy to plot etc....  
#Defining the dataframe dictionary to be filled up

expt_info = [ '1. PD vs HC', '2. (PD , PD+RBD) vs HC', '3. (PD + PD&RBD) vs HC vs RBD  multiclass', 
             '4. PD vs PD+RBD vs RBD vs HC  multiclass' ]

df_cols = ['Expt_type num', 'Folder', 'Classifier Name', 'Classifier', 'EEG Type',
       'Brain Region', 'Accuracy', 'Accuracy_std', 'TS processing']

df_dict = {}
for col in df_cols:
    df_dict[col] = []

regions = constants.regions

for clf in clf_list:
    for folder in folders:
        #Define EEG type from folder
        for eeg_type in ['N1' , 'N2' , 'N3' , 'REM' , 'EC']:
            if folder.startswith(eeg_type):
                eeg_type_res = eeg_type
        proc = 'N/A'
        for expt_num in [1,2,3,4]:
            #Fill up the results_dict with the appropriate values
            #Grab accuracy and std performance for each region
            try:
                mean_df = pd.DataFrame(results_dict[clf][expt_num][folder].mean(axis = 0) ).T
            
            except KeyError:
                continue
            for region in regions:
                #For each region take mean accuracy and std
                region_cols = [col for col in mean_df.columns if region in col]
                acc_col = [col for col in region_cols if 'acc' in col]
                std_col = [col for col in region_cols if 'std' in col]
                region_acc = mean_df[acc_col].values[0][0]
                region_acc_std = mean_df[std_col].values[0][0]
                
                #Now fill up the dataframe
                df_dict['Expt_type num'].append(expt_num)
                df_dict['Folder'].append(folder)
                df_dict['Classifier Name'].append(clf)
                df_dict['Classifier'].append(clf)
                df_dict['EEG Type'].append(eeg_type_res)
                df_dict['Brain Region'].append(region)
                df_dict['Accuracy'].append(region_acc)
                df_dict['Accuracy_std'].append(region_acc_std)
                df_dict['TS processing'].append(proc)

results_df = pd.DataFrame(df_dict)

# %% [markdown]
# ## This portion of the notebook plots accuracy by region (to view trends)

# %%
results_df_sorted = results_df.sort_values(by = ['Accuracy'], ascending = False)
results_df_sorted.head(12)
# Out:
#      Expt_type num          Folder Classifier Name     Classifier EEG Type  \
# 478              1   EC_full_expts             SVC            SVC       EC
# 477              1   EC_full_expts             SVC            SVC       EC
# 419              1  REM_full_expts             SVC            SVC      REM
# 73               2   N2_full_expts   Random_Forest  Random_Forest       N2
# 475              1   EC_full_expts             SVC            SVC       EC
# 221              2   EC_full_expts   Random_Forest  Random_Forest       EC
# 480              1   EC_full_expts             SVC            SVC       EC
# 224              2   EC_full_expts   Random_Forest  Random_Forest       EC
# 160              1  REM_full_expts   Random_Forest  Random_Forest      REM
# 425              1  REM_full_expts             SVC            SVC      REM
# 418              1  REM_full_expts             SVC            SVC      REM
# 473              1   EC_full_expts             SVC            SVC       EC
#
#        Brain Region  Accuracy  Accuracy_std TS processing
# 478   Left Parietal  0.780000      0.166163           N/A
# 477        Parietal  0.756667      0.163958           N/A
# 419   Right Frontal  0.700000      0.167695           N/A
# 73   Right Temporal  0.698889      0.170806           N/A
# 475   Left Temporal  0.696667      0.091831           N/A
# 221      Prefrontal  0.696429      0.103978           N/A
# 480       Occipital  0.686667      0.126332           N/A
# 224   Right Frontal  0.680357      0.146775           N/A
# 160         Central  0.662500      0.165831           N/A
# 425        Parietal  0.662500      0.132203           N/A
# 418    Left Frontal  0.650000      0.119658           N/A
# 473    Left Central  0.646667      0.155509           N/A

# %%
model = input("Enter model:")
# Out:
# Enter username:Laprama

# %%
results_df_sorted[results_df_sorted['Classifier Name'] == 'SVC']
# Out:
#      Expt_type num          Folder Classifier Name Classifier EEG Type  \
# 478              1   EC_full_expts             SVC        SVC       EC
# 477              1   EC_full_expts             SVC        SVC       EC
# 419              1  REM_full_expts             SVC        SVC      REM
# 475              1   EC_full_expts             SVC        SVC       EC
# 480              1   EC_full_expts             SVC        SVC       EC
# 425              1  REM_full_expts             SVC        SVC      REM
# 418              1  REM_full_expts             SVC        SVC      REM
# 473              1   EC_full_expts             SVC        SVC       EC
# 433              2  REM_full_expts             SVC        SVC      REM
# 313              1   N2_full_expts             SVC        SVC       N2
# 366              1   N3_full_expts             SVC        SVC       N3
# 438              2  REM_full_expts             SVC        SVC      REM
# 474              1   EC_full_expts             SVC        SVC       EC
# 371              1   N3_full_expts             SVC        SVC       N3
# 323              1   N2_full_expts             SVC        SVC       N2
# 423              1  REM_full_expts             SVC        SVC      REM
# 426              1  REM_full_expts             SVC        SVC      REM
# 264              1   N1_full_expts             SVC        SVC       N1
# 484              2   EC_full_expts             SVC        SVC       EC
# 377              2   N3_full_expts             SVC        SVC       N3
# 432              2  REM_full_expts             SVC        SVC      REM
# 481              2   EC_full_expts             SVC        SVC       EC
# 471              1   EC_full_expts             SVC        SVC       EC
# 422              1  REM_full_expts             SVC        SVC      REM
# 364              1   N3_full_expts             SVC        SVC       N3
# 430              2  REM_full_expts             SVC        SVC      REM
# 429              2  REM_full_expts             SVC        SVC      REM
# 365              1   N3_full_expts             SVC        SVC       N3
# 487              2   EC_full_expts             SVC        SVC       EC
# 470              1   EC_full_expts             SVC        SVC       EC
# 469              1   EC_full_expts             SVC        SVC       EC
# 479              1   EC_full_expts             SVC        SVC       EC
# 427              1  REM_full_expts             SVC        SVC      REM
# 315              1   N2_full_expts             SVC        SVC       N2
# 491              2   EC_full_expts             SVC        SVC       EC
# 369              1   N3_full_expts             SVC        SVC       N3
# 421              1  REM_full_expts             SVC        SVC      REM
# 428              1  REM_full_expts             SVC        SVC      REM
# 277              2   N1_full_expts             SVC        SVC       N1
# 324              1   N2_full_expts             SVC        SVC       N2
# 317              1   N2_full_expts             SVC        SVC       N2
# 320              1   N2_full_expts             SVC        SVC       N2
# 322              1   N2_full_expts             SVC        SVC       N2
# 374              1   N3_full_expts             SVC        SVC       N3
# 263              1   N1_full_expts             SVC        SVC       N1
# 370              1   N3_full_expts             SVC        SVC       N3
# 368              1   N3_full_expts             SVC        SVC       N3
# 472              1   EC_full_expts             SVC        SVC       EC
# 329              2   N2_full_expts             SVC        SVC       N2
# 434              2  REM_full_expts             SVC        SVC      REM
# 269              1   N1_full_expts             SVC        SVC       N1
# 417              1  REM_full_expts             SVC        SVC      REM
# 376              1   N3_full_expts             SVC        SVC       N3
# 490              2   EC_full_expts             SVC        SVC       EC
# 280              2   N1_full_expts             SVC        SVC       N1
# 381              2   N3_full_expts             SVC        SVC       N3
# 492              2   EC_full_expts             SVC        SVC       EC
# 268              1   N1_full_expts             SVC        SVC       N1
# 272              1   N1_full_expts             SVC        SVC       N1
# 318              1   N2_full_expts             SVC        SVC       N2
# 389              2   N3_full_expts             SVC        SVC       N3
# 367              1   N3_full_expts             SVC        SVC       N3
# 424              1  REM_full_expts             SVC        SVC      REM
# 431              2  REM_full_expts             SVC        SVC      REM
# 373              1   N3_full_expts             SVC        SVC       N3
# 440              2  REM_full_expts             SVC        SVC      REM
# 337              2   N2_full_expts             SVC        SVC       N2
# 266              1   N1_full_expts             SVC        SVC       N1
# 260              1   N1_full_expts             SVC        SVC       N1
# 314              1   N2_full_expts             SVC        SVC       N2
# 416              1  REM_full_expts             SVC        SVC      REM
# 321              1   N2_full_expts             SVC        SVC       N2
# 493              2   EC_full_expts             SVC        SVC       EC
# 483              2   EC_full_expts             SVC        SVC       EC
# 375              1   N3_full_expts             SVC        SVC       N3
# 285              2   N1_full_expts             SVC        SVC       N1
# 334              2   N2_full_expts             SVC        SVC       N2
# 283              2   N1_full_expts             SVC        SVC       N1
# 386              2   N3_full_expts             SVC        SVC       N3
# 420              1  REM_full_expts             SVC        SVC      REM
# 267              1   N1_full_expts             SVC        SVC       N1
# 262              1   N1_full_expts             SVC        SVC       N1
# 271              1   N1_full_expts             SVC        SVC       N1
# 372              1   N3_full_expts             SVC        SVC       N3
# 312              1   N2_full_expts             SVC        SVC       N2
# 489              2   EC_full_expts             SVC        SVC       EC
# 270              1   N1_full_expts             SVC        SVC       N1
# 316              1   N2_full_expts             SVC        SVC       N2
# 486              2   EC_full_expts             SVC        SVC       EC
# 325              2   N2_full_expts             SVC        SVC       N2
# 319              1   N2_full_expts             SVC        SVC       N2
# 482              2   EC_full_expts             SVC        SVC       EC
# 382              2   N3_full_expts             SVC        SVC       N3
# 332              2   N2_full_expts             SVC        SVC       N2
# 326              2   N2_full_expts             SVC        SVC       N2
# 328              2   N2_full_expts             SVC        SVC       N2
# 435              2  REM_full_expts             SVC        SVC      REM
# 468              1   EC_full_expts             SVC        SVC       EC
# 335              2   N2_full_expts             SVC        SVC       N2
# 282              2   N1_full_expts             SVC        SVC       N1
# 441              2  REM_full_expts             SVC        SVC      REM
# 488              2   EC_full_expts             SVC        SVC       EC
# 281              2   N1_full_expts             SVC        SVC       N1
# 261              1   N1_full_expts             SVC        SVC       N1
# 437              2  REM_full_expts             SVC        SVC      REM
# 476              1   EC_full_expts             SVC        SVC       EC
# 336              2   N2_full_expts             SVC        SVC       N2
# 436              2  REM_full_expts             SVC        SVC      REM
# 284              2   N1_full_expts             SVC        SVC       N1
# 439              2  REM_full_expts             SVC        SVC      REM
# 276              2   N1_full_expts             SVC        SVC       N1
# 265              1   N1_full_expts             SVC        SVC       N1
# 509              4   EC_full_expts             SVC        SVC       EC
# 510              4   EC_full_expts             SVC        SVC       EC
# 273              2   N1_full_expts             SVC        SVC       N1
# 331              2   N2_full_expts             SVC        SVC       N2
# 499              3   EC_full_expts             SVC        SVC       EC
# 380              2   N3_full_expts             SVC        SVC       N3
# 385              2   N3_full_expts             SVC        SVC       N3
# 383              2   N3_full_expts             SVC        SVC       N3
# 330              2   N2_full_expts             SVC        SVC       N2
# 485              2   EC_full_expts             SVC        SVC       EC
# 388              2   N3_full_expts             SVC        SVC       N3
# 379              2   N3_full_expts             SVC        SVC       N3
# 462              4  REM_full_expts             SVC        SVC      REM
# 307              4   N1_full_expts             SVC        SVC       N1
# 378              2   N3_full_expts             SVC        SVC       N3
# 384              2   N3_full_expts             SVC        SVC       N3
# 514              4   EC_full_expts             SVC        SVC       EC
# 387              2   N3_full_expts             SVC        SVC       N3
# 339              3   N2_full_expts             SVC        SVC       N2
# 279              2   N1_full_expts             SVC        SVC       N1
# 449              3  REM_full_expts             SVC        SVC      REM
# 306              4   N1_full_expts             SVC        SVC       N1
# 290              3   N1_full_expts             SVC        SVC       N1
# 360              4   N2_full_expts             SVC        SVC       N2
# 333              2   N2_full_expts             SVC        SVC       N2
# 352              4   N2_full_expts             SVC        SVC       N2
# 359              4   N2_full_expts             SVC        SVC       N2
# 345              3   N2_full_expts             SVC        SVC       N2
# 299              4   N1_full_expts             SVC        SVC       N1
# 356              4   N2_full_expts             SVC        SVC       N2
# 507              4   EC_full_expts             SVC        SVC       EC
# 464              4  REM_full_expts             SVC        SVC      REM
# 451              3  REM_full_expts             SVC        SVC      REM
# 274              2   N1_full_expts             SVC        SVC       N1
# 390              3   N3_full_expts             SVC        SVC       N3
# 275              2   N1_full_expts             SVC        SVC       N1
# 518              4   EC_full_expts             SVC        SVC       EC
# 348              3   N2_full_expts             SVC        SVC       N2
# 443              3  REM_full_expts             SVC        SVC      REM
# 459              4  REM_full_expts             SVC        SVC      REM
# 401              3   N3_full_expts             SVC        SVC       N3
# 414              4   N3_full_expts             SVC        SVC       N3
# 495              3   EC_full_expts             SVC        SVC       EC
# 327              2   N2_full_expts             SVC        SVC       N2
# 505              3   EC_full_expts             SVC        SVC       EC
# 445              3  REM_full_expts             SVC        SVC      REM
# 292              3   N1_full_expts             SVC        SVC       N1
# 288              3   N1_full_expts             SVC        SVC       N1
# 342              3   N2_full_expts             SVC        SVC       N2
# 446              3  REM_full_expts             SVC        SVC      REM
# 494              3   EC_full_expts             SVC        SVC       EC
# 293              3   N1_full_expts             SVC        SVC       N1
# 297              3   N1_full_expts             SVC        SVC       N1
# 497              3   EC_full_expts             SVC        SVC       EC
# 405              4   N3_full_expts             SVC        SVC       N3
# 357              4   N2_full_expts             SVC        SVC       N2
# 343              3   N2_full_expts             SVC        SVC       N2
# 361              4   N2_full_expts             SVC        SVC       N2
# 355              4   N2_full_expts             SVC        SVC       N2
# 294              3   N1_full_expts             SVC        SVC       N1
# 346              3   N2_full_expts             SVC        SVC       N2
# 496              3   EC_full_expts             SVC        SVC       EC
# 347              3   N2_full_expts             SVC        SVC       N2
# 466              4  REM_full_expts             SVC        SVC      REM
# 287              3   N1_full_expts             SVC        SVC       N1
# 309              4   N1_full_expts             SVC        SVC       N1
# 296              3   N1_full_expts             SVC        SVC       N1
# 286              3   N1_full_expts             SVC        SVC       N1
# 508              4   EC_full_expts             SVC        SVC       EC
# 399              3   N3_full_expts             SVC        SVC       N3
# 303              4   N1_full_expts             SVC        SVC       N1
# 344              3   N2_full_expts             SVC        SVC       N2
# 358              4   N2_full_expts             SVC        SVC       N2
# 465              4  REM_full_expts             SVC        SVC      REM
# 412              4   N3_full_expts             SVC        SVC       N3
# 501              3   EC_full_expts             SVC        SVC       EC
# 442              3  REM_full_expts             SVC        SVC      REM
# 450              3  REM_full_expts             SVC        SVC      REM
# 304              4   N1_full_expts             SVC        SVC       N1
# 444              3  REM_full_expts             SVC        SVC      REM
# 289              3   N1_full_expts             SVC        SVC       N1
# 458              4  REM_full_expts             SVC        SVC      REM
# 455              4  REM_full_expts             SVC        SVC      REM
# 463              4  REM_full_expts             SVC        SVC      REM
# 403              4   N3_full_expts             SVC        SVC       N3
# 515              4   EC_full_expts             SVC        SVC       EC
# 310              4   N1_full_expts             SVC        SVC       N1
# 400              3   N3_full_expts             SVC        SVC       N3
# 411              4   N3_full_expts             SVC        SVC       N3
# 517              4   EC_full_expts             SVC        SVC       EC
# 456              4  REM_full_expts             SVC        SVC      REM
# 302              4   N1_full_expts             SVC        SVC       N1
# 512              4   EC_full_expts             SVC        SVC       EC
# 460              4  REM_full_expts             SVC        SVC      REM
# 395              3   N3_full_expts             SVC        SVC       N3
# 504              3   EC_full_expts             SVC        SVC       EC
# 278              2   N1_full_expts             SVC        SVC       N1
# 409              4   N3_full_expts             SVC        SVC       N3
# 340              3   N2_full_expts             SVC        SVC       N2
# 498              3   EC_full_expts             SVC        SVC       EC
# 363              4   N2_full_expts             SVC        SVC       N2
# 291              3   N1_full_expts             SVC        SVC       N1
# 301              4   N1_full_expts             SVC        SVC       N1
# 305              4   N1_full_expts             SVC        SVC       N1
# 396              3   N3_full_expts             SVC        SVC       N3
# 394              3   N3_full_expts             SVC        SVC       N3
# 351              4   N2_full_expts             SVC        SVC       N2
# 353              4   N2_full_expts             SVC        SVC       N2
# 457              4  REM_full_expts             SVC        SVC      REM
# 448              3  REM_full_expts             SVC        SVC      REM
# 502              3   EC_full_expts             SVC        SVC       EC
# 402              3   N3_full_expts             SVC        SVC       N3
# 300              4   N1_full_expts             SVC        SVC       N1
# 398              3   N3_full_expts             SVC        SVC       N3
# 408              4   N3_full_expts             SVC        SVC       N3
# 404              4   N3_full_expts             SVC        SVC       N3
# 503              3   EC_full_expts             SVC        SVC       EC
# 511              4   EC_full_expts             SVC        SVC       EC
# 295              3   N1_full_expts             SVC        SVC       N1
# 447              3  REM_full_expts             SVC        SVC      REM
# 410              4   N3_full_expts             SVC        SVC       N3
# 413              4   N3_full_expts             SVC        SVC       N3
# 407              4   N3_full_expts             SVC        SVC       N3
# 338              3   N2_full_expts             SVC        SVC       N2
# 311              4   N1_full_expts             SVC        SVC       N1
# 461              4  REM_full_expts             SVC        SVC      REM
# 406              4   N3_full_expts             SVC        SVC       N3
# 506              3   EC_full_expts             SVC        SVC       EC
# 391              3   N3_full_expts             SVC        SVC       N3
# 362              4   N2_full_expts             SVC        SVC       N2
# 452              3  REM_full_expts             SVC        SVC      REM
# 392              3   N3_full_expts             SVC        SVC       N3
# 516              4   EC_full_expts             SVC        SVC       EC
# 341              3   N2_full_expts             SVC        SVC       N2
# 298              3   N1_full_expts             SVC        SVC       N1
# 513              4   EC_full_expts             SVC        SVC       EC
# 453              3  REM_full_expts             SVC        SVC      REM
# 393              3   N3_full_expts             SVC        SVC       N3
# 308              4   N1_full_expts             SVC        SVC       N1
# 349              3   N2_full_expts             SVC        SVC       N2
# 500              3   EC_full_expts             SVC        SVC       EC
# 454              3  REM_full_expts             SVC        SVC      REM
# 415              4   N3_full_expts             SVC        SVC       N3
# 397              3   N3_full_expts             SVC        SVC       N3
# 467              4  REM_full_expts             SVC        SVC      REM
# 350              3   N2_full_expts             SVC        SVC       N2
# 354              4   N2_full_expts             SVC        SVC       N2
# 519              4   EC_full_expts             SVC        SVC       EC
#
#        Brain Region  Accuracy  Accuracy_std TS processing
# 478   Left Parietal  0.780000      0.166163           N/A
# 477        Parietal  0.756667      0.163958           N/A
# 419   Right Frontal  0.700000      0.167695           N/A
# 475   Left Temporal  0.696667      0.091831           N/A
# 480       Occipital  0.686667      0.126332           N/A
# 425        Parietal  0.662500      0.132203           N/A
# 418    Left Frontal  0.650000      0.119658           N/A
# 473    Left Central  0.646667      0.155509           N/A
# 433         Central  0.637778      0.190697           N/A
# 313         Frontal  0.618056      0.182270           N/A
# 366    Left Frontal  0.616667      0.180499           N/A
# 438        Parietal  0.615556      0.137818           N/A
# 474   Right Central  0.610000      0.193711           N/A
# 460    Left Central  0.274176      0.105653           N/A
# 395    Left Central  0.270952      0.068433           N/A
# 504   Left Parietal  0.270909      0.111191           N/A
# 278    Left Central  0.270000      0.181650           N/A
# 409   Right Central  0.269524      0.095879           N/A
# 340    Left Frontal  0.268571      0.081897           N/A
# 498         Central  0.268182      0.137878           N/A
# 363       Occipital  0.268095      0.094770           N/A
# 291    Left Central  0.267619      0.089301           N/A
# 301    Left Frontal  0.267619      0.078422           N/A
# 305   Right Central  0.267619      0.042314           N/A
# 396   Right Central  0.264286      0.068078           N/A
# 394         Central  0.262381      0.081424           N/A
# 351      Prefrontal  0.261429      0.101708           N/A
# 353    Left Frontal  0.261429      0.069993           N/A
# 457    Left Frontal  0.259341      0.114250           N/A
# 448   Right Central  0.259341      0.125870           N/A
# 502  Right Temporal  0.257273      0.099653           N/A
# 402       Occipital  0.256667      0.074839           N/A
# 300         Frontal  0.253810      0.092088           N/A
# 398  Right Temporal  0.250952      0.070875           N/A
# 408    Left Central  0.249524      0.050761           N/A
# 404         Frontal  0.249524      0.091390           N/A
# 503        Parietal  0.249091      0.126026           N/A
# 511         Central  0.248182      0.125988           N/A
# 295        Parietal  0.245714      0.097938           N/A
# 447    Left Central  0.245055      0.073881           N/A
# 410   Left Temporal  0.243333      0.101621           N/A
# 413   Left Parietal  0.241905      0.084540           N/A
# 407         Central  0.241429      0.064483           N/A
# 338      Prefrontal  0.240476      0.100981           N/A
# 311       Occipital  0.240000      0.052615           N/A
# 461   Right Central  0.237912      0.116637           N/A
# 406   Right Frontal  0.236667      0.060136           N/A
# 506       Occipital  0.236364      0.086573           N/A
# 391         Frontal  0.235238      0.065288           N/A
# 362  Right Parietal  0.232857      0.094189           N/A
# 452   Left Parietal  0.231319      0.103856           N/A
# 392    Left Frontal  0.229048      0.137117           N/A
# 516        Parietal  0.228182      0.135443           N/A
# 341   Right Frontal  0.225714      0.103674           N/A
# 298       Occipital  0.224762      0.060019           N/A
# 513   Right Central  0.224545      0.092822           N/A
# 453  Right Parietal  0.224176      0.128462           N/A
# 393   Right Frontal  0.222381      0.079323           N/A
# 308        Parietal  0.219524      0.109453           N/A
# 349  Right Parietal  0.218571      0.119780           N/A
# 500   Right Central  0.218182      0.059417           N/A
# 454       Occipital  0.217033      0.095967           N/A
# 415       Occipital  0.216190      0.049164           N/A
# 397   Left Temporal  0.215238      0.071509           N/A
# 467       Occipital  0.209890      0.105813           N/A
# 350       Occipital  0.203810      0.105924           N/A
# 354   Right Frontal  0.197143      0.099702           N/A
# 519       Occipital  0.178182      0.076607           N/A

# %%
fig = plt.figure()
fig = plt.figure(figsize=(15,5),dpi=100)

for i in [1,2,3,4]:
    expt_num = i
    expt_results = results_df[results_df['Expt_type num'] == expt_num].copy()
    expt_results.sort_values(by=['Brain Region','Accuracy'], ascending = False)
    
    ax = fig.add_subplot(1,4,i)
    
    plt.title('Accuracy vs Brain Region \n' + expt_info[expt_num-1])
    
    #Define colours for the different data types
    colors = {'EC':'tab:blue', 'N1':'tab:orange', 'N2':'tab:green', 'N3':'tab:red', 'REM':'tab:purple'}
#     plt.scatter(expt_results['Brain Region'].values, expt_results['Accuracy'].values,
#                     c = expt_results['EEG Type'].map(colors))

    #Plot one data point per region / data type combination - average the performance across short and long processing
    for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
        for region in regions:
            acc = expt_results[(expt_results['Brain Region'] == region) & (expt_results['EEG Type'] == eeg_type)].mean(numeric_only = True)['Accuracy']
            plt.scatter(region, acc,
                    c = colors[eeg_type])
    
   
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
    plt.xlabel('Brain Region')
    plt.ylabel('Accuracy')
    plt.ylim((expt_results['Accuracy'].min() - 0.05 , expt_results['Accuracy'].max() + 0.1))
    plt.grid()

    plt.tight_layout()

#Custom Legend, because standard legend wouldn't work for some reason
patches = []
for key, val in colors.items():
    patches.append(mpatches.Patch(color= val, label=key) )

# plt.legend(handles=patches, framealpha = 0.1)
plt.legend(loc = 'upper center', ncol = 3 ,  handles=patches, framealpha = 0.4)
    
plt.tight_layout()

#Do the plots again for data type accuracy distribution
fig = plt.figure()
fig = plt.figure(figsize=(15,5),dpi=100)

for i in [1,2,3,4]:
    expt_num = i
    expt_results = results_df[results_df['Expt_type num'] == expt_num].copy()
    expt_results.sort_values(by=['Brain Region','Accuracy'], ascending = False)
    
    ax = fig.add_subplot(1,4,i)
    
    plt.title('Accuracy vs Brain Region \n' + expt_info[expt_num-1])
    
    #Define colours for the different data types
    colors = {'EC':'tab:blue', 'N1':'tab:orange', 'N2':'tab:green', 'N3':'tab:red', 'REM':'tab:purple'}
#     plt.scatter(expt_results['Brain Region'].values, expt_results['Accuracy'].values,
#                     c = expt_results['EEG Type'].map(colors))

    #Plot one data point per region / data type combination - average the performance across short and long processing
    for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
        for region in regions:
            acc = expt_results[(expt_results['Brain Region'] == region) & (expt_results['EEG Type'] == eeg_type)].mean(numeric_only = True)['Accuracy']
            plt.scatter(eeg_type, acc,
                    c = colors[eeg_type])
    
   
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
    plt.xlabel('EEG Type')
    plt.ylabel('Accuracy')
    plt.ylim((expt_results['Accuracy'].min() - 0.05 , expt_results['Accuracy'].max() + 0.1))
    plt.grid()

    plt.tight_layout()

plt.tight_layout()


# plt.savefig('classifier_accuracy_original_epoch_bpw.png', dpi=200)

# %% [markdown]
# #### Do statistical significance tests

# %%
results_df = results_df[results_df['Classifier'] == 'Random_Forest']
rocket_results = results_df[results_df['Expt_type num'] == 4] 
rocket_results
# Out:
#      Expt_type num          Folder Classifier Name     Classifier EEG Type  \
# 39               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 40               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 41               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 42               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 43               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 44               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 45               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 46               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 47               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 48               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 49               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 50               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 51               4   N1_full_expts   Random_Forest  Random_Forest       N1
# 91               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 92               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 93               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 94               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 95               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 96               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 97               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 98               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 99               4   N2_full_expts   Random_Forest  Random_Forest       N2
# 100              4   N2_full_expts   Random_Forest  Random_Forest       N2
# 101              4   N2_full_expts   Random_Forest  Random_Forest       N2
# 102              4   N2_full_expts   Random_Forest  Random_Forest       N2
# 103              4   N2_full_expts   Random_Forest  Random_Forest       N2
# 143              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 144              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 145              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 146              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 147              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 148              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 149              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 150              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 151              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 152              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 153              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 154              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 155              4   N3_full_expts   Random_Forest  Random_Forest       N3
# 195              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 196              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 197              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 198              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 199              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 200              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 201              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 202              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 203              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 204              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 205              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 206              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 207              4  REM_full_expts   Random_Forest  Random_Forest      REM
# 247              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 248              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 249              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 250              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 251              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 252              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 253              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 254              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 255              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 256              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 257              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 258              4   EC_full_expts   Random_Forest  Random_Forest       EC
# 259              4   EC_full_expts   Random_Forest  Random_Forest       EC
#
#        Brain Region  Accuracy  Accuracy_std TS processing
# 39       Prefrontal  0.351429      0.116103           N/A
# 40          Frontal  0.260952      0.083265           N/A
# 41     Left Frontal  0.316190      0.106516           N/A
# 42    Right Frontal  0.325238      0.079251           N/A
# 43          Central  0.317619      0.122890           N/A
# 44     Left Central  0.335714      0.107214           N/A
# 45    Right Central  0.345714      0.157671           N/A
# 46    Left Temporal  0.255238      0.100753           N/A
# 47   Right Temporal  0.330476      0.114121           N/A
# 48         Parietal  0.317619      0.095981           N/A
# 49    Left Parietal  0.282381      0.115161           N/A
# 50   Right Parietal  0.254286      0.092603           N/A
# 51        Occipital  0.246190      0.118007           N/A
# 91       Prefrontal  0.232857      0.072486           N/A
# 92          Frontal  0.370952      0.133806           N/A
# 93     Left Frontal  0.246667      0.078535           N/A
# 94    Right Frontal  0.232857      0.055648           N/A
# 95          Central  0.450952      0.064128           N/A
# 96     Left Central  0.246190      0.091783           N/A
# 97    Right Central  0.367143      0.045626           N/A
# 98    Left Temporal  0.210476      0.083052           N/A
# 99   Right Temporal  0.396667      0.124927           N/A
# 100        Parietal  0.360476      0.101967           N/A
# 101   Left Parietal  0.318571      0.108877           N/A
# 102  Right Parietal  0.316667      0.137236           N/A
# 103       Occipital  0.318095      0.105181           N/A
# 143      Prefrontal  0.250000      0.076823           N/A
# 144         Frontal  0.227143      0.095999           N/A
# 145    Left Frontal  0.254762      0.090915           N/A
# 146   Right Frontal  0.248571      0.079802           N/A
# 147         Central  0.241905      0.076624           N/A
# 148    Left Central  0.242857      0.059742           N/A
# 149   Right Central  0.320000      0.090946           N/A
# 150   Left Temporal  0.282857      0.123396           N/A
# 151  Right Temporal  0.271905      0.089343           N/A
# 152        Parietal  0.206667      0.101959           N/A
# 153   Left Parietal  0.222857      0.089267           N/A
# 154  Right Parietal  0.207619      0.060786           N/A
# 155       Occipital  0.153810      0.114707           N/A
# 195      Prefrontal  0.232418      0.127737           N/A
# 196         Frontal  0.237912      0.127876           N/A
# 197    Left Frontal  0.260989      0.086616           N/A
# 198   Right Frontal  0.244505      0.142658           N/A
# 199         Central  0.289560      0.131655           N/A
# 200    Left Central  0.238462      0.112672           N/A
# 201   Right Central  0.333516      0.165630           N/A
# 202   Left Temporal  0.311538      0.092857           N/A
# 203  Right Temporal  0.245604      0.127129           N/A
# 204        Parietal  0.317033      0.087311           N/A
# 205   Left Parietal  0.275824      0.083135           N/A
# 206  Right Parietal  0.341209      0.127778           N/A
# 207       Occipital  0.247802      0.132074           N/A
# 247      Prefrontal  0.368182      0.093490           N/A
# 248         Frontal  0.247273      0.089774           N/A
# 249    Left Frontal  0.374545      0.140231           N/A
# 250   Right Frontal  0.252727      0.119965           N/A
# 251         Central  0.197273      0.073389           N/A
# 252    Left Central  0.227273      0.062651           N/A
# 253   Right Central  0.282727      0.102199           N/A
# 254   Left Temporal  0.253636      0.048833           N/A
# 255  Right Temporal  0.237273      0.106718           N/A
# 256        Parietal  0.228182      0.120415           N/A
# 257   Left Parietal  0.290909      0.135159           N/A
# 258  Right Parietal  0.308182      0.115658           N/A
# 259       Occipital  0.196364      0.081246           N/A

# %%
regional_means, eeg_type_means = {} , {}
for region in regions:
    regional_means[region] = round(rocket_results[rocket_results['Brain Region'] == region].mean(numeric_only= True)['Accuracy'],3)

for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
    eeg_type_means[eeg_type] = round(rocket_results[rocket_results['EEG Type'] == eeg_type].mean(numeric_only= True)['Accuracy'],3)

print(regional_means)
print('\n')
print(eeg_type_means)
# Out:
# {'Prefrontal': 0.287, 'Frontal': 0.269, 'Left Frontal': 0.291, 'Right Frontal': 0.261, 'Central': 0.299, 'Left Central': 0.258, 'Right Central': 0.33, 'Left Temporal': 0.263, 'Right Temporal': 0.296, 'Parietal': 0.286, 'Left Parietal': 0.278, 'Right Parietal': 0.286, 'Occipital': 0.232}
#
#
# {'EC': 0.267, 'N1': 0.303, 'N2': 0.313, 'N3': 0.241, 'REM': 0.275}

# %%
pd.DataFrame(regional_means, index = ['mean_acc']).T.sort_values(by = ['mean_acc']).T
# Out:
#           Occipital  Left Central  Right Frontal  Left Temporal  Frontal  \
# mean_acc      0.232         0.258          0.261          0.263    0.269
#
#           Left Parietal  Parietal  Right Parietal  Prefrontal  Left Frontal  \
# mean_acc          0.278     0.286           0.286       0.287         0.291
#
#           Right Temporal  Central  Right Central
# mean_acc           0.296    0.299           0.33

# %%
pd.DataFrame(eeg_type_means, index = ['mean_acc']).T.sort_values(by = ['mean_acc']).T
# Out:
#              N3     EC    REM     N1     N2
# mean_acc  0.241  0.267  0.275  0.303  0.313

# %%
#1. generate the dfs 
regional_acc_distribution , eeg_type_distribution = {} , {}

for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
    eeg_type_distribution[eeg_type] = rocket_results[rocket_results['EEG Type'] == eeg_type]['Accuracy'].values

for region in regions:
    regional_acc_distribution[region] = rocket_results[rocket_results['Brain Region'] == region]['Accuracy'].values

eeg_type_dist = pd.DataFrame(eeg_type_distribution)
regional_acc_dist = pd.DataFrame(regional_acc_distribution)

# %%
print(stats.friedmanchisquare(*eeg_type_dist.T.values) ) 
output_results = sp.posthoc_nemenyi_friedman(eeg_type_dist.values)

column_mapping = {0: 'EC', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'REM'}
row_mapping = {0: 'EC', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'REM'}
df = output_results.rename(columns=column_mapping, index=row_mapping)
df
# Out:
# FriedmanchisquareResult(statistic=10.892307692307696, pvalue=0.027801363961457087)
#            EC        N1        N2        N3       REM
# EC   1.000000  0.339031  0.413055  0.900000  0.900000
