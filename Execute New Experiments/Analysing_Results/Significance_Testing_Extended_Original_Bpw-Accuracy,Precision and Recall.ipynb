# %%
from IPython.utils import io
import pandas as pd
import os
from pathlib import Path
from matplotlib import pyplot as plt
from scipy.signal import find_peaks
import numpy as np
import seaborn as sns
import time
import joblib
from os.path import exists
import shutil
import sys
import time
import matplotlib.patches as mpatches


from sklearn.model_selection import train_test_split
#From my EEG package 
import run_expts
import constants
import calculate_results

from scipy import stats
import scikit_posthocs as sp

#Let me see as many results as I want to see
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
clf_list = ['Rocket', 'C_I_F', 'Dr_C_I_F']

#Results dictionary structure : {model : {expt_type : {folder : results_df }}}
results_dict = {}
for clf in clf_list:
    results_dict[clf] = {1 : {} , 2 : {} , 3: {} , 4 : {}}

core_path = '/export/sphere/ebirah/ko20929/RBD_files/notebooks/frequency_analysis/constructed_data/band_power_time_series/expt_dfs/'

folders = ['N1_customised_40_expt_files', 'N2_120_expt_files_v2', 'N3_82_expt_files', 'REM_19_expt_files', 'EC_8_expts',
           'N1_full_expts', 'N2_full_expts', 'N3_full_expts', 'REM_full_expts', 'EC_full_expts']

files_not_found = []

for num in [1,2,3,4]:
    for folder in folders:
        for clf in clf_list:
            try:
                #first term is the parent directory
                save_path = os.path.dirname(os.getcwd()) + '/Results/Results_2/' + clf + 'expt_type_' + str(num) + '_' + folder + 'int_df.h5'
                results_df = pd.read_hdf(save_path , key='df', mode='r')
            except FileNotFoundError:
                files_not_found.append(save_path)
                continue
                
            #Replace res_df with dataframe that looks at accuracy and precision also
            expt_type = {1 : 'binary', 2: 'binary', 3: 'multi-class' , 4: 'multiclass'}[num]
            with io.capture_output() as captured:
                per_fold_metrics = calculate_results.calc_per_fold_metrics(results_df, expt_type)
                df_overall = calculate_results.overall_weighted_metrics(per_fold_metrics, expt_type)

            
                       
            results_dict[clf][num][folder] = df_overall


#Put results in a Df structure that is easy to plot etc....  
#Defining the dataframe dictionary to be filled up

expt_info = [ '1. PD vs HC', '2. (PD , PD+RBD) vs HC', '3. (PD + PD&RBD) vs HC vs RBD  multiclass', 
             '4. PD vs PD+RBD vs RBD vs HC  multiclass' ]

df_cols = ['Expt_type num', 'Folder', 'Classifier Name', 'Classifier', 'EEG Type',
       'Brain Region', 'Accuracy', 'Accuracy_std', 'Precision', 'Precision_std', 'Recall', 'Recall_std' , 'TS processing']

df_dict = {}
for col in df_cols:
    df_dict[col] = []

regions = constants.regions

for clf in clf_list:
    for folder in folders:
        #Define EEG type from folder
        for eeg_type in ['N1' , 'N2' , 'N3' , 'REM' , 'EC']:
            if folder.startswith(eeg_type):
                eeg_type_res = eeg_type
        if 'full' in folder: 
            proc = 'full length'
        else:
            proc = 'shorter_expts'
        for expt_num in [1,2,3,4]:
            #Fill up the results_dict with the appropriate values
            #Grab accuracy and std performance for each region
            try:
                #mean_df is a legacy name but I'm keeping it for simplicity
                mean_df = results_dict[clf][expt_num][folder]
            
            except KeyError:
                continue
            for region in regions:
                #For each region take accuracy ,accuracy std ,precision , precision std, recall and recall std
                                                
                region_acc = mean_df[[region + '_' + clf + '_' + 'acc_mean']].values[0][0]
                region_acc_std = mean_df[[region + '_' + clf + '_' + 'acc_std']].values[0][0]
                
                region_prec = mean_df[[region + '_' + clf + '_' + 'prec_mean']].values[0][0]
                region_prec_std = mean_df[[region + '_' + clf + '_' + 'prec_std']].values[0][0]
                
                region_recall = mean_df[[region + '_' + clf + '_' + 'recall_mean']].values[0][0]
                region_recall_std = mean_df[[region + '_' + clf + '_' + 'recall_std']].values[0][0]
                
                #Now fill up the dataframe
                df_dict['Expt_type num'].append(expt_num)
                df_dict['Folder'].append(folder)
                df_dict['Classifier Name'].append(clf)
                df_dict['Classifier'].append(clf)
                df_dict['EEG Type'].append(eeg_type_res)
                df_dict['Brain Region'].append(region)
                
                df_dict['Accuracy'].append(region_acc)
                df_dict['Accuracy_std'].append(region_acc_std)
                
                df_dict['Precision'].append(region_acc)
                df_dict['Precision_std'].append(region_acc_std)
                
                df_dict['Recall'].append(region_acc)
                df_dict['Recall_std'].append(region_acc_std)
                
                df_dict['TS processing'].append(proc)

results_df = pd.DataFrame(df_dict)

# %%
results_df
# Out:
#       Expt_type num                       Folder Classifier Name Classifier  \
# 0                 1  N1_customised_40_expt_files          Rocket     Rocket
# 1                 1  N1_customised_40_expt_files          Rocket     Rocket
# 2                 1  N1_customised_40_expt_files          Rocket     Rocket
# 3                 1  N1_customised_40_expt_files          Rocket     Rocket
# 4                 1  N1_customised_40_expt_files          Rocket     Rocket
# ...             ...                          ...             ...        ...
# 1555              4                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 1556              4                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 1557              4                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 1558              4                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 1559              4                EC_full_expts        Dr_C_I_F   Dr_C_I_F
#
#      EEG Type    Brain Region  Accuracy  Accuracy_std  Precision  \
# 0          N1      Prefrontal  0.650000      0.123247   0.650000
# 1          N1         Frontal  0.712500      0.126416   0.712500
# 2          N1    Left Frontal  0.625000      0.079556   0.625000
# 3          N1   Right Frontal  0.725000      0.146694   0.725000
# 4          N1         Central  0.675000      0.100631   0.675000
# ...       ...             ...       ...           ...        ...
# 1555       EC  Right Temporal  0.273585      0.170881   0.273585
# 1556       EC        Parietal  0.207547      0.116862   0.207547
# 1557       EC   Left Parietal  0.235849      0.136250   0.235849
# 1558       EC  Right Parietal  0.264151      0.158842   0.264151
# 1559       EC       Occipital  0.216981      0.099365   0.216981
#
#       Precision_std    Recall  Recall_std  TS processing
# 0          0.123247  0.650000    0.123247  shorter_expts
# 1          0.126416  0.712500    0.126416  shorter_expts
# 2          0.079556  0.625000    0.079556  shorter_expts
# 3          0.146694  0.725000    0.146694  shorter_expts
# 4          0.100631  0.675000    0.100631  shorter_expts
# ...             ...       ...         ...            ...
# 1555       0.170881  0.273585    0.170881    full length
# 1556       0.116862  0.207547    0.116862    full length
# 1557       0.136250  0.235849    0.136250    full length
# 1558       0.158842  0.264151    0.158842    full length
# 1559       0.099365  0.216981    0.099365    full length
#
# [1560 rows x 13 columns]

# %%
results_df = results_df[results_df['Classifier'] == 'Rocket']
print('Keeping only the Rocket Results')
# Out:
# Keeping only the Rocket Results

# %% [markdown]
# ## This portion of the notebook plots accuracy by region (to view trends)

# %%
results_df_sorted = results_df.sort_values(by = ['Accuracy'], ascending = False)
results_df_sorted.head(12)
# Out:
#      Expt_type num                       Folder Classifier Name Classifier  \
# 267              1                N1_full_expts          Rocket     Rocket
# 3                1  N1_customised_40_expt_files          Rocket     Rocket
# 266              1                N1_full_expts          Rocket     Rocket
# 12               1  N1_customised_40_expt_files          Rocket     Rocket
# 1                1  N1_customised_40_expt_files          Rocket     Rocket
# 261              1                N1_full_expts          Rocket     Rocket
# 264              1                N1_full_expts          Rocket     Rocket
# 268              1                N1_full_expts          Rocket     Rocket
# 265              1                N1_full_expts          Rocket     Rocket
# 272              1                N1_full_expts          Rocket     Rocket
# 263              1                N1_full_expts          Rocket     Rocket
# 260              1                N1_full_expts          Rocket     Rocket
#
#     EEG Type    Brain Region  Accuracy  Accuracy_std  Precision  \
# 267       N1   Left Temporal    0.7625      0.088052     0.7625
# 3         N1   Right Frontal    0.7250      0.146694     0.7250
# 266       N1   Right Central    0.7250      0.123247     0.7250
# 12        N1       Occipital    0.7125      0.149366     0.7125
# 1         N1         Frontal    0.7125      0.126416     0.7125
# 261       N1         Frontal    0.7125      0.138368     0.7125
# 264       N1         Central    0.7125      0.113210     0.7125
# 268       N1  Right Temporal    0.7000      0.161088     0.7000
# 265       N1    Left Central    0.7000      0.115287     0.7000
# 272       N1       Occipital    0.7000      0.140072     0.7000
# 263       N1   Right Frontal    0.6875      0.151470     0.6875
# 260       N1      Prefrontal    0.6875      0.151470     0.6875
#
#      Precision_std  Recall  Recall_std  TS processing
# 267       0.088052  0.7625    0.088052    full length
# 3         0.146694  0.7250    0.146694  shorter_expts
# 266       0.123247  0.7250    0.123247    full length
# 12        0.149366  0.7125    0.149366  shorter_expts
# 1         0.126416  0.7125    0.126416  shorter_expts
# 261       0.138368  0.7125    0.138368    full length
# 264       0.113210  0.7125    0.113210    full length
# 268       0.161088  0.7000    0.161088    full length
# 265       0.115287  0.7000    0.115287    full length
# 272       0.140072  0.7000    0.140072    full length
# 263       0.151470  0.6875    0.151470    full length
# 260       0.151470  0.6875    0.151470    full length

# %%
fig = plt.figure()
fig = plt.figure(figsize=(15,5),dpi=100)

for i in [1,2,3,4]:
    expt_num = i
    expt_results = results_df[results_df['Expt_type num'] == expt_num].copy()
    expt_results.sort_values(by=['Brain Region','Accuracy'], ascending = False)
    
    ax = fig.add_subplot(1,4,i)
    
    plt.title('Accuracy vs Brain Region \n' + expt_info[expt_num-1])
    
    #Define colours for the different data types
    colors = {'EC':'tab:blue', 'N1':'tab:orange', 'N2':'tab:green', 'N3':'tab:red', 'REM':'tab:purple'}
#     plt.scatter(expt_results['Brain Region'].values, expt_results['Accuracy'].values,
#                     c = expt_results['EEG Type'].map(colors))

    #Plot one data point per region / data type combination - average the performance across short and long processing
    for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
        for region in regions:
            acc = expt_results[(expt_results['Brain Region'] == region) & (expt_results['EEG Type'] == eeg_type)].mean(numeric_only = True)['Accuracy']
            plt.scatter(region, acc,
                    c = colors[eeg_type])
    
   
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
    plt.xlabel('Brain Region')
    plt.ylabel('Accuracy')
    plt.ylim((expt_results['Accuracy'].min() - 0.05 , expt_results['Accuracy'].max() + 0.1))
    plt.grid()

    plt.tight_layout()

#Custom Legend, because standard legend wouldn't work for some reason
patches = []
for key, val in colors.items():
    patches.append(mpatches.Patch(color= val, label=key) )

# plt.legend(handles=patches, framealpha = 0.1)
plt.legend(loc = 'upper center', ncol = 3 ,  handles=patches, framealpha = 0.4)
    
plt.tight_layout()

#Do the plots again for data type accuracy distribution
fig = plt.figure()
fig = plt.figure(figsize=(15,5),dpi=100)

for i in [1,2,3,4]:
    expt_num = i
    expt_results = results_df[results_df['Expt_type num'] == expt_num].copy()
    expt_results.sort_values(by=['Brain Region','Accuracy'], ascending = False)
    
    ax = fig.add_subplot(1,4,i)
    
    plt.title('Accuracy vs Brain Region \n' + expt_info[expt_num-1])
    
    #Define colours for the different data types
    colors = {'EC':'tab:blue', 'N1':'tab:orange', 'N2':'tab:green', 'N3':'tab:red', 'REM':'tab:purple'}
#     plt.scatter(expt_results['Brain Region'].values, expt_results['Accuracy'].values,
#                     c = expt_results['EEG Type'].map(colors))

    #Plot one data point per region / data type combination - average the performance across short and long processing
    for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
        for region in regions:
            acc = expt_results[(expt_results['Brain Region'] == region) & (expt_results['EEG Type'] == eeg_type)].mean(numeric_only = True)['Accuracy']
            plt.scatter(eeg_type, acc,
                    c = colors[eeg_type])
    
   
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
    plt.xlabel('EEG Type')
    plt.ylabel('Accuracy')
    plt.ylim((expt_results['Accuracy'].min() - 0.05 , expt_results['Accuracy'].max() + 0.1))
    plt.grid()

    plt.tight_layout()

plt.tight_layout()


# plt.savefig('classifier_accuracy_original_epoch_bpw.png', dpi=200)

# %% [markdown]
# ## Do statistical significance tests

# %%
results_df = results_df[results_df['Classifier'] == 'Rocket']
rocket_results = results_df[results_df['Expt_type num'] == 4] 
rocket_results
# Out:
#      Expt_type num                       Folder Classifier Name Classifier  \
# 39               4  N1_customised_40_expt_files          Rocket     Rocket
# 40               4  N1_customised_40_expt_files          Rocket     Rocket
# 41               4  N1_customised_40_expt_files          Rocket     Rocket
# 42               4  N1_customised_40_expt_files          Rocket     Rocket
# 43               4  N1_customised_40_expt_files          Rocket     Rocket
# 44               4  N1_customised_40_expt_files          Rocket     Rocket
# 45               4  N1_customised_40_expt_files          Rocket     Rocket
# 46               4  N1_customised_40_expt_files          Rocket     Rocket
# 47               4  N1_customised_40_expt_files          Rocket     Rocket
# 48               4  N1_customised_40_expt_files          Rocket     Rocket
# 49               4  N1_customised_40_expt_files          Rocket     Rocket
# 50               4  N1_customised_40_expt_files          Rocket     Rocket
# 51               4  N1_customised_40_expt_files          Rocket     Rocket
# 91               4         N2_120_expt_files_v2          Rocket     Rocket
# 92               4         N2_120_expt_files_v2          Rocket     Rocket
# 93               4         N2_120_expt_files_v2          Rocket     Rocket
# 94               4         N2_120_expt_files_v2          Rocket     Rocket
# 95               4         N2_120_expt_files_v2          Rocket     Rocket
# 96               4         N2_120_expt_files_v2          Rocket     Rocket
# 97               4         N2_120_expt_files_v2          Rocket     Rocket
# 98               4         N2_120_expt_files_v2          Rocket     Rocket
# 99               4         N2_120_expt_files_v2          Rocket     Rocket
# 100              4         N2_120_expt_files_v2          Rocket     Rocket
# 101              4         N2_120_expt_files_v2          Rocket     Rocket
# 102              4         N2_120_expt_files_v2          Rocket     Rocket
# 103              4         N2_120_expt_files_v2          Rocket     Rocket
# 143              4             N3_82_expt_files          Rocket     Rocket
# 144              4             N3_82_expt_files          Rocket     Rocket
# 145              4             N3_82_expt_files          Rocket     Rocket
# 146              4             N3_82_expt_files          Rocket     Rocket
# 147              4             N3_82_expt_files          Rocket     Rocket
# 148              4             N3_82_expt_files          Rocket     Rocket
# 149              4             N3_82_expt_files          Rocket     Rocket
# 150              4             N3_82_expt_files          Rocket     Rocket
# 151              4             N3_82_expt_files          Rocket     Rocket
# 152              4             N3_82_expt_files          Rocket     Rocket
# 153              4             N3_82_expt_files          Rocket     Rocket
# 154              4             N3_82_expt_files          Rocket     Rocket
# 155              4             N3_82_expt_files          Rocket     Rocket
# 195              4            REM_19_expt_files          Rocket     Rocket
# 196              4            REM_19_expt_files          Rocket     Rocket
# 197              4            REM_19_expt_files          Rocket     Rocket
# 198              4            REM_19_expt_files          Rocket     Rocket
# 199              4            REM_19_expt_files          Rocket     Rocket
# 200              4            REM_19_expt_files          Rocket     Rocket
# 201              4            REM_19_expt_files          Rocket     Rocket
# 202              4            REM_19_expt_files          Rocket     Rocket
# 203              4            REM_19_expt_files          Rocket     Rocket
# 204              4            REM_19_expt_files          Rocket     Rocket
# 205              4            REM_19_expt_files          Rocket     Rocket
# 206              4            REM_19_expt_files          Rocket     Rocket
# 207              4            REM_19_expt_files          Rocket     Rocket
# 247              4                   EC_8_expts          Rocket     Rocket
# 248              4                   EC_8_expts          Rocket     Rocket
# 249              4                   EC_8_expts          Rocket     Rocket
# 250              4                   EC_8_expts          Rocket     Rocket
# 251              4                   EC_8_expts          Rocket     Rocket
# 252              4                   EC_8_expts          Rocket     Rocket
# 253              4                   EC_8_expts          Rocket     Rocket
# 254              4                   EC_8_expts          Rocket     Rocket
# 255              4                   EC_8_expts          Rocket     Rocket
# 256              4                   EC_8_expts          Rocket     Rocket
# 257              4                   EC_8_expts          Rocket     Rocket
# 258              4                   EC_8_expts          Rocket     Rocket
# 259              4                   EC_8_expts          Rocket     Rocket
# 299              4                N1_full_expts          Rocket     Rocket
# 300              4                N1_full_expts          Rocket     Rocket
# 301              4                N1_full_expts          Rocket     Rocket
# 302              4                N1_full_expts          Rocket     Rocket
# 303              4                N1_full_expts          Rocket     Rocket
# 304              4                N1_full_expts          Rocket     Rocket
# 305              4                N1_full_expts          Rocket     Rocket
# 306              4                N1_full_expts          Rocket     Rocket
# 307              4                N1_full_expts          Rocket     Rocket
# 308              4                N1_full_expts          Rocket     Rocket
# 309              4                N1_full_expts          Rocket     Rocket
# 310              4                N1_full_expts          Rocket     Rocket
# 311              4                N1_full_expts          Rocket     Rocket
# 351              4                N2_full_expts          Rocket     Rocket
# 352              4                N2_full_expts          Rocket     Rocket
# 353              4                N2_full_expts          Rocket     Rocket
# 354              4                N2_full_expts          Rocket     Rocket
# 355              4                N2_full_expts          Rocket     Rocket
# 356              4                N2_full_expts          Rocket     Rocket
# 357              4                N2_full_expts          Rocket     Rocket
# 358              4                N2_full_expts          Rocket     Rocket
# 359              4                N2_full_expts          Rocket     Rocket
# 360              4                N2_full_expts          Rocket     Rocket
# 361              4                N2_full_expts          Rocket     Rocket
# 362              4                N2_full_expts          Rocket     Rocket
# 363              4                N2_full_expts          Rocket     Rocket
# 403              4                N3_full_expts          Rocket     Rocket
# 404              4                N3_full_expts          Rocket     Rocket
# 405              4                N3_full_expts          Rocket     Rocket
# 406              4                N3_full_expts          Rocket     Rocket
# 407              4                N3_full_expts          Rocket     Rocket
# 408              4                N3_full_expts          Rocket     Rocket
# 409              4                N3_full_expts          Rocket     Rocket
# 410              4                N3_full_expts          Rocket     Rocket
# 411              4                N3_full_expts          Rocket     Rocket
# 412              4                N3_full_expts          Rocket     Rocket
# 413              4                N3_full_expts          Rocket     Rocket
# 414              4                N3_full_expts          Rocket     Rocket
# 415              4                N3_full_expts          Rocket     Rocket
# 455              4               REM_full_expts          Rocket     Rocket
# 456              4               REM_full_expts          Rocket     Rocket
# 457              4               REM_full_expts          Rocket     Rocket
# 458              4               REM_full_expts          Rocket     Rocket
# 459              4               REM_full_expts          Rocket     Rocket
# 460              4               REM_full_expts          Rocket     Rocket
# 461              4               REM_full_expts          Rocket     Rocket
# 462              4               REM_full_expts          Rocket     Rocket
# 463              4               REM_full_expts          Rocket     Rocket
# 464              4               REM_full_expts          Rocket     Rocket
# 465              4               REM_full_expts          Rocket     Rocket
# 466              4               REM_full_expts          Rocket     Rocket
# 467              4               REM_full_expts          Rocket     Rocket
# 507              4                EC_full_expts          Rocket     Rocket
# 508              4                EC_full_expts          Rocket     Rocket
# 509              4                EC_full_expts          Rocket     Rocket
# 510              4                EC_full_expts          Rocket     Rocket
# 511              4                EC_full_expts          Rocket     Rocket
# 512              4                EC_full_expts          Rocket     Rocket
# 513              4                EC_full_expts          Rocket     Rocket
# 514              4                EC_full_expts          Rocket     Rocket
# 515              4                EC_full_expts          Rocket     Rocket
# 516              4                EC_full_expts          Rocket     Rocket
# 517              4                EC_full_expts          Rocket     Rocket
# 518              4                EC_full_expts          Rocket     Rocket
# 519              4                EC_full_expts          Rocket     Rocket
#
#     EEG Type    Brain Region  Accuracy  Accuracy_std  Precision  \
# 39        N1      Prefrontal  0.485915      0.110123   0.485915
# 40        N1         Frontal  0.394366      0.109688   0.394366
# 41        N1    Left Frontal  0.422535      0.130084   0.422535
# 42        N1   Right Frontal  0.422535      0.077109   0.422535
# 43        N1         Central  0.387324      0.142517   0.387324
# 44        N1    Left Central  0.352113      0.071840   0.352113
# 45        N1   Right Central  0.492958      0.156317   0.492958
# 46        N1   Left Temporal  0.338028      0.076365   0.338028
# 47        N1  Right Temporal  0.359155      0.106596   0.359155
# 48        N1        Parietal  0.359155      0.141451   0.359155
# 49        N1   Left Parietal  0.330986      0.137175   0.330986
# 50        N1  Right Parietal  0.408451      0.120377   0.408451
# 51        N1       Occipital  0.380282      0.098040   0.380282
# 91        N2      Prefrontal  0.284615      0.133973   0.284615
# 92        N2         Frontal  0.261538      0.098891   0.261538
# 93        N2    Left Frontal  0.276923      0.125469   0.276923
# 94        N2   Right Frontal  0.261538      0.078750   0.261538
# 95        N2         Central  0.269231      0.079128   0.269231
# 96        N2    Left Central  0.223077      0.064144   0.223077
# 97        N2   Right Central  0.269231      0.105031   0.269231
# 98        N2   Left Temporal  0.200000      0.070774   0.200000
# 99        N2  Right Temporal  0.300000      0.121852   0.300000
# 100       N2        Parietal  0.269231      0.105031   0.269231
# 101       N2   Left Parietal  0.207692      0.103890   0.207692
# 102       N2  Right Parietal  0.330769      0.084943   0.330769
# 103       N2       Occipital  0.276923      0.092665   0.276923
# 143       N3      Prefrontal  0.275362      0.131260   0.275362
# 144       N3         Frontal  0.210145      0.081312   0.210145
# 145       N3    Left Frontal  0.239130      0.095579   0.239130
# 146       N3   Right Frontal  0.362319      0.087957   0.362319
# 147       N3         Central  0.152174      0.080950   0.152174
# 148       N3    Left Central  0.202899      0.083062   0.202899
# 149       N3   Right Central  0.311594      0.158255   0.311594
# 150       N3   Left Temporal  0.246377      0.058872   0.246377
# 151       N3  Right Temporal  0.304348      0.168575   0.304348
# 152       N3        Parietal  0.159420      0.053617   0.159420
# 153       N3   Left Parietal  0.297101      0.088214   0.297101
# 154       N3  Right Parietal  0.282609      0.135241   0.282609
# 155       N3       Occipital  0.166667      0.054600   0.166667
# 195      REM      Prefrontal  0.456522      0.146004   0.456522
# 196      REM         Frontal  0.369565      0.180093   0.369565
# 197      REM    Left Frontal  0.427536      0.110802   0.427536
# 198      REM   Right Frontal  0.442029      0.149810   0.442029
# 199      REM         Central  0.333333      0.083136   0.333333
# 200      REM    Left Central  0.384058      0.144465   0.384058
# 201      REM   Right Central  0.485507      0.175014   0.485507
# 202      REM   Left Temporal  0.398551      0.130327   0.398551
# 203      REM  Right Temporal  0.376812      0.097670   0.376812
# 204      REM        Parietal  0.333333      0.131678   0.333333
# 205      REM   Left Parietal  0.442029      0.186858   0.442029
# 206      REM  Right Parietal  0.391304      0.151628   0.391304
# 207      REM       Occipital  0.376812      0.119465   0.376812
# 247       EC      Prefrontal  0.210000      0.083485   0.210000
# 248       EC         Frontal  0.270000      0.090453   0.270000
# 249       EC    Left Frontal  0.330000      0.142489   0.330000
# 250       EC   Right Frontal  0.220000      0.075210   0.220000
# 251       EC         Central  0.340000      0.102494   0.340000
# 252       EC    Left Central  0.410000      0.145297   0.410000
# 253       EC   Right Central  0.370000      0.101005   0.370000
# 254       EC   Left Temporal  0.330000      0.119342   0.330000
# 255       EC  Right Temporal  0.280000      0.075210   0.280000
# 256       EC        Parietal  0.180000      0.133333   0.180000
# 257       EC   Left Parietal  0.310000      0.164838   0.310000
# 258       EC  Right Parietal  0.410000      0.164838   0.410000
# 259       EC       Occipital  0.370000      0.046057   0.370000
# 299       N1      Prefrontal  0.316901      0.077595   0.316901
# 300       N1         Frontal  0.366197      0.128131   0.366197
# 301       N1    Left Frontal  0.323944      0.079194   0.323944
# 302       N1   Right Frontal  0.316901      0.089140   0.316901
# 303       N1         Central  0.359155      0.150811   0.359155
# 304       N1    Left Central  0.309859      0.090572   0.309859
# 305       N1   Right Central  0.401408      0.158102   0.401408
# 306       N1   Left Temporal  0.295775      0.095538   0.295775
# 307       N1  Right Temporal  0.309859      0.117944   0.309859
# 308       N1        Parietal  0.309859      0.065207   0.309859
# 309       N1   Left Parietal  0.366197      0.129963   0.366197
# 310       N1  Right Parietal  0.316901      0.091015   0.316901
# 311       N1       Occipital  0.338028      0.079825   0.338028
# 351       N2      Prefrontal  0.394366      0.107668   0.394366
# 352       N2         Frontal  0.274648      0.108197   0.274648
# 353       N2    Left Frontal  0.330986      0.125877   0.330986
# 354       N2   Right Frontal  0.274648      0.143252   0.274648
# 355       N2         Central  0.309859      0.118658   0.309859
# 356       N2    Left Central  0.295775      0.093934   0.295775
# 357       N2   Right Central  0.253521      0.092505   0.253521
# 358       N2   Left Temporal  0.295775      0.084669   0.295775
# 359       N2  Right Temporal  0.281690      0.125155   0.281690
# 360       N2        Parietal  0.338028      0.101936   0.338028
# 361       N2   Left Parietal  0.295775      0.111067   0.295775
# 362       N2  Right Parietal  0.345070      0.115532   0.345070
# 363       N2       Occipital  0.295775      0.123178   0.295775
# 403       N3      Prefrontal  0.236111      0.128020   0.236111
# 404       N3         Frontal  0.180556      0.078099   0.180556
# 405       N3    Left Frontal  0.208333      0.084515   0.208333
# 406       N3   Right Frontal  0.284722      0.084524   0.284722
# 407       N3         Central  0.263889      0.102770   0.263889
# 408       N3    Left Central  0.208333      0.122209   0.208333
# 409       N3   Right Central  0.284722      0.085891   0.284722
# 410       N3   Left Temporal  0.277778      0.106821   0.277778
# 411       N3  Right Temporal  0.236111      0.104377   0.236111
# 412       N3        Parietal  0.208333      0.052414   0.208333
# 413       N3   Left Parietal  0.166667      0.052889   0.166667
# 414       N3  Right Parietal  0.243056      0.103798   0.243056
# 415       N3       Occipital  0.131944      0.085891   0.131944
# 455      REM      Prefrontal  0.376812      0.145637   0.376812
# 456      REM         Frontal  0.391304      0.198682   0.391304
# 457      REM    Left Frontal  0.347826      0.132749   0.347826
# 458      REM   Right Frontal  0.405797      0.123470   0.405797
# 459      REM         Central  0.289855      0.142997   0.289855
# 460      REM    Left Central  0.362319      0.109488   0.362319
# 461      REM   Right Central  0.391304      0.150300   0.391304
# 462      REM   Left Temporal  0.340580      0.092357   0.340580
# 463      REM  Right Temporal  0.384058      0.151908   0.384058
# 464      REM        Parietal  0.333333      0.109201   0.333333
# 465      REM   Left Parietal  0.413043      0.119336   0.413043
# 466      REM  Right Parietal  0.384058      0.124965   0.384058
# 467      REM       Occipital  0.442029      0.129104   0.442029
# 507       EC      Prefrontal  0.245283      0.138167   0.245283
# 508       EC         Frontal  0.179245      0.122166   0.179245
# 509       EC    Left Frontal  0.292453      0.129847   0.292453
# 510       EC   Right Frontal  0.311321      0.099742   0.311321
# 511       EC         Central  0.311321      0.116925   0.311321
# 512       EC    Left Central  0.264151      0.140320   0.264151
# 513       EC   Right Central  0.188679      0.113544   0.188679
# 514       EC   Left Temporal  0.226415      0.089860   0.226415
# 515       EC  Right Temporal  0.292453      0.090566   0.292453
# 516       EC        Parietal  0.188679      0.086743   0.188679
# 517       EC   Left Parietal  0.207547      0.100102   0.207547
# 518       EC  Right Parietal  0.292453      0.096580   0.292453
# 519       EC       Occipital  0.273585      0.125964   0.273585
#
#      Precision_std    Recall  Recall_std  TS processing
# 39        0.110123  0.485915    0.110123  shorter_expts
# 40        0.109688  0.394366    0.109688  shorter_expts
# 41        0.130084  0.422535    0.130084  shorter_expts
# 42        0.077109  0.422535    0.077109  shorter_expts
# 43        0.142517  0.387324    0.142517  shorter_expts
# 44        0.071840  0.352113    0.071840  shorter_expts
# 45        0.156317  0.492958    0.156317  shorter_expts
# 46        0.076365  0.338028    0.076365  shorter_expts
# 47        0.106596  0.359155    0.106596  shorter_expts
# 48        0.141451  0.359155    0.141451  shorter_expts
# 49        0.137175  0.330986    0.137175  shorter_expts
# 50        0.120377  0.408451    0.120377  shorter_expts
# 51        0.098040  0.380282    0.098040  shorter_expts
# 91        0.133973  0.284615    0.133973  shorter_expts
# 92        0.098891  0.261538    0.098891  shorter_expts
# 93        0.125469  0.276923    0.125469  shorter_expts
# 94        0.078750  0.261538    0.078750  shorter_expts
# 95        0.079128  0.269231    0.079128  shorter_expts
# 96        0.064144  0.223077    0.064144  shorter_expts
# 97        0.105031  0.269231    0.105031  shorter_expts
# 98        0.070774  0.200000    0.070774  shorter_expts
# 99        0.121852  0.300000    0.121852  shorter_expts
# 100       0.105031  0.269231    0.105031  shorter_expts
# 101       0.103890  0.207692    0.103890  shorter_expts
# 102       0.084943  0.330769    0.084943  shorter_expts
# 103       0.092665  0.276923    0.092665  shorter_expts
# 143       0.131260  0.275362    0.131260  shorter_expts
# 144       0.081312  0.210145    0.081312  shorter_expts
# 145       0.095579  0.239130    0.095579  shorter_expts
# 146       0.087957  0.362319    0.087957  shorter_expts
# 147       0.080950  0.152174    0.080950  shorter_expts
# 148       0.083062  0.202899    0.083062  shorter_expts
# 149       0.158255  0.311594    0.158255  shorter_expts
# 150       0.058872  0.246377    0.058872  shorter_expts
# 151       0.168575  0.304348    0.168575  shorter_expts
# 152       0.053617  0.159420    0.053617  shorter_expts
# 153       0.088214  0.297101    0.088214  shorter_expts
# 154       0.135241  0.282609    0.135241  shorter_expts
# 155       0.054600  0.166667    0.054600  shorter_expts
# 195       0.146004  0.456522    0.146004  shorter_expts
# 196       0.180093  0.369565    0.180093  shorter_expts
# 197       0.110802  0.427536    0.110802  shorter_expts
# 198       0.149810  0.442029    0.149810  shorter_expts
# 199       0.083136  0.333333    0.083136  shorter_expts
# 200       0.144465  0.384058    0.144465  shorter_expts
# 201       0.175014  0.485507    0.175014  shorter_expts
# 202       0.130327  0.398551    0.130327  shorter_expts
# 203       0.097670  0.376812    0.097670  shorter_expts
# 204       0.131678  0.333333    0.131678  shorter_expts
# 205       0.186858  0.442029    0.186858  shorter_expts
# 206       0.151628  0.391304    0.151628  shorter_expts
# 207       0.119465  0.376812    0.119465  shorter_expts
# 247       0.083485  0.210000    0.083485  shorter_expts
# 248       0.090453  0.270000    0.090453  shorter_expts
# 249       0.142489  0.330000    0.142489  shorter_expts
# 250       0.075210  0.220000    0.075210  shorter_expts
# 251       0.102494  0.340000    0.102494  shorter_expts
# 252       0.145297  0.410000    0.145297  shorter_expts
# 253       0.101005  0.370000    0.101005  shorter_expts
# 254       0.119342  0.330000    0.119342  shorter_expts
# 255       0.075210  0.280000    0.075210  shorter_expts
# 256       0.133333  0.180000    0.133333  shorter_expts
# 257       0.164838  0.310000    0.164838  shorter_expts
# 258       0.164838  0.410000    0.164838  shorter_expts
# 259       0.046057  0.370000    0.046057  shorter_expts
# 299       0.077595  0.316901    0.077595    full length
# 300       0.128131  0.366197    0.128131    full length
# 301       0.079194  0.323944    0.079194    full length
# 302       0.089140  0.316901    0.089140    full length
# 303       0.150811  0.359155    0.150811    full length
# 304       0.090572  0.309859    0.090572    full length
# 305       0.158102  0.401408    0.158102    full length
# 306       0.095538  0.295775    0.095538    full length
# 307       0.117944  0.309859    0.117944    full length
# 308       0.065207  0.309859    0.065207    full length
# 309       0.129963  0.366197    0.129963    full length
# 310       0.091015  0.316901    0.091015    full length
# 311       0.079825  0.338028    0.079825    full length
# 351       0.107668  0.394366    0.107668    full length
# 352       0.108197  0.274648    0.108197    full length
# 353       0.125877  0.330986    0.125877    full length
# 354       0.143252  0.274648    0.143252    full length
# 355       0.118658  0.309859    0.118658    full length
# 356       0.093934  0.295775    0.093934    full length
# 357       0.092505  0.253521    0.092505    full length
# 358       0.084669  0.295775    0.084669    full length
# 359       0.125155  0.281690    0.125155    full length
# 360       0.101936  0.338028    0.101936    full length
# 361       0.111067  0.295775    0.111067    full length
# 362       0.115532  0.345070    0.115532    full length
# 363       0.123178  0.295775    0.123178    full length
# 403       0.128020  0.236111    0.128020    full length
# 404       0.078099  0.180556    0.078099    full length
# 405       0.084515  0.208333    0.084515    full length
# 406       0.084524  0.284722    0.084524    full length
# 407       0.102770  0.263889    0.102770    full length
# 408       0.122209  0.208333    0.122209    full length
# 409       0.085891  0.284722    0.085891    full length
# 410       0.106821  0.277778    0.106821    full length
# 411       0.104377  0.236111    0.104377    full length
# 412       0.052414  0.208333    0.052414    full length
# 413       0.052889  0.166667    0.052889    full length
# 414       0.103798  0.243056    0.103798    full length
# 415       0.085891  0.131944    0.085891    full length
# 455       0.145637  0.376812    0.145637    full length
# 456       0.198682  0.391304    0.198682    full length
# 457       0.132749  0.347826    0.132749    full length
# 458       0.123470  0.405797    0.123470    full length
# 459       0.142997  0.289855    0.142997    full length
# 460       0.109488  0.362319    0.109488    full length
# 461       0.150300  0.391304    0.150300    full length
# 462       0.092357  0.340580    0.092357    full length
# 463       0.151908  0.384058    0.151908    full length
# 464       0.109201  0.333333    0.109201    full length
# 465       0.119336  0.413043    0.119336    full length
# 466       0.124965  0.384058    0.124965    full length
# 467       0.129104  0.442029    0.129104    full length
# 507       0.138167  0.245283    0.138167    full length
# 508       0.122166  0.179245    0.122166    full length
# 509       0.129847  0.292453    0.129847    full length
# 510       0.099742  0.311321    0.099742    full length
# 511       0.116925  0.311321    0.116925    full length
# 512       0.140320  0.264151    0.140320    full length
# 513       0.113544  0.188679    0.113544    full length
# 514       0.089860  0.226415    0.089860    full length
# 515       0.090566  0.292453    0.090566    full length
# 516       0.086743  0.188679    0.086743    full length
# 517       0.100102  0.207547    0.100102    full length
# 518       0.096580  0.292453    0.096580    full length
# 519       0.125964  0.273585    0.125964    full length

# %%
regional_means, eeg_type_means = {} , {}
for region in regions:
    regional_means[region] = round(rocket_results[rocket_results['Brain Region'] == region].mean(numeric_only= True)['Accuracy'],3)

for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
    eeg_type_means[eeg_type] = round(rocket_results[rocket_results['EEG Type'] == eeg_type].mean(numeric_only= True)['Accuracy'],3)

print(regional_means)
print('\n')
print(eeg_type_means)
# Out:
# {'Prefrontal': 0.329, 'Frontal': 0.289, 'Left Frontal': 0.32, 'Right Frontal': 0.33, 'Central': 0.301, 'Left Central': 0.301, 'Right Central': 0.345, 'Left Temporal': 0.295, 'Right Temporal': 0.313, 'Parietal': 0.268, 'Left Parietal': 0.303, 'Right Parietal': 0.34, 'Occipital': 0.305}
#
#
# {'EC': 0.281, 'N1': 0.364, 'N2': 0.286, 'N3': 0.236, 'REM': 0.387}

# %%
pd.DataFrame(regional_means, index = ['mean_acc']).T.sort_values(by = ['mean_acc']).T
# Out:
#           Parietal  Frontal  Left Temporal  Central  Left Central  \
# mean_acc     0.268    0.289          0.295    0.301         0.301
#
#           Left Parietal  Occipital  Right Temporal  Left Frontal  Prefrontal  \
# mean_acc          0.303      0.305           0.313          0.32       0.329
#
#           Right Frontal  Right Parietal  Right Central
# mean_acc           0.33            0.34          0.345

# %%
pd.DataFrame(eeg_type_means, index = ['mean_acc']).T.sort_values(by = ['mean_acc']).T
# Out:
#              N3     EC     N2     N1    REM
# mean_acc  0.236  0.281  0.286  0.364  0.387

# %%
#1. generate the dfs 
regional_acc_distribution , eeg_type_distribution = {} , {}

for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
    eeg_type_distribution[eeg_type] = rocket_results[rocket_results['EEG Type'] == eeg_type]['Accuracy'].values

for region in regions:
    regional_acc_distribution[region] = rocket_results[rocket_results['Brain Region'] == region]['Accuracy'].values

eeg_type_dist = pd.DataFrame(eeg_type_distribution)
regional_acc_dist = pd.DataFrame(regional_acc_distribution)

# %%
print(stats.friedmanchisquare(*eeg_type_dist.T.values) ) 
output_results = sp.posthoc_nemenyi_friedman(eeg_type_dist.values)

column_mapping = {0: 'EC', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'REM'}
row_mapping = {0: 'EC', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'REM'}
df = output_results.rename(columns=column_mapping, index=row_mapping)
df
# Out:
# FriedmanchisquareResult(statistic=59.53846153846155, pvalue=3.6266361432616924e-12)
#            EC        N1        N2        N3    REM
# EC   1.000000  0.001525  0.900000  0.257559  0.001
# N1   0.001525  1.000000  0.005643  0.001000  0.900
# N2   0.900000  0.005643  1.000000  0.124375  0.001
# N3   0.257559  0.001000  0.124375  1.000000  0.001
# REM  0.001000  0.900000  0.001000  0.001000  1.000

# %%
print(stats.friedmanchisquare(*regional_acc_dist.T.values) ) 

output_results = sp.posthoc_nemenyi_friedman(regional_acc_dist.values)

column_mapping = {}
for i in range(len(regional_acc_dist.columns)): 
    column_mapping[i] = list(regional_acc_dist.columns)[i]
row_mapping = column_mapping    
    
df = output_results.rename(columns=column_mapping, index=row_mapping)
df
# Out:
# FriedmanchisquareResult(statistic=24.28776185226019, pvalue=0.018582919723467737)
#                 Prefrontal   Frontal  Left Frontal  Right Frontal   Central  \
# Prefrontal        1.000000  0.880709      0.900000       0.900000  0.900000
# Frontal           0.880709  1.000000      0.900000       0.735097  0.900000
# Left Frontal      0.900000  0.900000      1.000000       0.900000  0.900000
# Right Frontal     0.900000  0.735097      0.900000       1.000000  0.900000
# Central           0.900000  0.900000      0.900000       0.900000  1.000000
# Left Central      0.880709  0.900000      0.900000       0.735097  0.900000
# Right Central     0.900000  0.479500      0.900000       0.900000  0.900000
# Left Temporal     0.862506  0.900000      0.900000       0.716896  0.900000
# Right Temporal    0.900000  0.900000      0.900000       0.900000  0.900000
# Parietal          0.320205  0.900000      0.419423       0.195664  0.862506
# Left Parietal     0.900000  0.900000      0.900000       0.900000  0.900000
# Right Parietal    0.900000  0.459915      0.900000       0.900000  0.900000
# Occipital         0.900000  0.900000      0.900000       0.900000  0.900000
#
#                 Left Central  Right Central  Left Temporal  Right Temporal  \
# Prefrontal          0.880709       0.900000       0.862506        0.900000
# Frontal             0.900000       0.479500       0.900000        0.900000
# Left Frontal        0.900000       0.900000       0.900000        0.900000
# Right Frontal       0.735097       0.900000       0.716896        0.900000
# Central             0.900000       0.900000       0.900000        0.900000
# Left Central        1.000000       0.479500       0.900000        0.900000
# Right Central       0.479500       1.000000       0.459915        0.900000
# Left Temporal       0.900000       0.459915       1.000000        0.900000
# Right Temporal      0.900000       0.900000       0.900000        1.000000
# Parietal            0.900000       0.067612       0.900000        0.826107
# Left Parietal       0.900000       0.900000       0.900000        0.900000
# Right Parietal      0.459915       0.900000       0.439834        0.900000
# Occipital           0.900000       0.900000       0.900000        0.900000
#
#                 Parietal  Left Parietal  Right Parietal  Occipital
# Prefrontal      0.320205            0.9        0.900000   0.900000
# Frontal         0.900000            0.9        0.459915   0.900000
# Left Frontal    0.419423            0.9        0.900000   0.900000
# Right Frontal   0.195664            0.9        0.900000   0.900000
# Central         0.862506            0.9        0.900000   0.900000
# Left Central    0.900000            0.9        0.459915   0.900000
# Right Central   0.067612            0.9        0.900000   0.900000
# Left Temporal   0.900000            0.9        0.439834   0.900000
# Right Temporal  0.826107            0.9        0.900000   0.900000
# Parietal        1.000000            0.9        0.061963   0.789702
# Left Parietal   0.900000            1.0        0.900000   0.900000
# Right Parietal  0.061963            0.9        1.000000   0.900000
# Occipital       0.789702            0.9        0.900000   1.000000
