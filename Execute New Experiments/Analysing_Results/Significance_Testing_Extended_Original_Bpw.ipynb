# %%
from IPython.utils import io
import pandas as pd
import os
from pathlib import Path
from matplotlib import pyplot as plt
from scipy.signal import find_peaks
import numpy as np
import seaborn as sns
import time
import joblib
from os.path import exists
import shutil
import sys
import time
import matplotlib.patches as mpatches


from sklearn.model_selection import train_test_split
#From my EEG package 
import run_expts
import constants
import calculate_results

from scipy import stats
import scikit_posthocs as sp

#Let me see as many results as I want to see
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# Out:
#    random_state                                             y_true  \
# 0             1  [[0, 0, 0, 0, 0, 1, 1, 3, 3, 3, 3], [0, 0, 1, ...
# 1             2  [[0, 0, 0, 0, 0, 1, 1, 2, 2, 2, 3], [0, 0, 0, ...
#
#                          Prefrontal_Dr_C_I_F_y_preds  \
# 0  [[3, 3, 3, 0, 0, 0, 2, 2, 2, 3, 1], [0, 1, 0, ...
# 1  [[3, 1, 3, 3, 3, 1, 3, 3, 0, 3, 3], [3, 0, 0, ...
#
#                             Frontal_Dr_C_I_F_y_preds  \
# 0  [[3, 1, 3, 1, 0, 1, 3, 3, 3, 0, 1], [2, 1, 0, ...
# 1  [[1, 3, 3, 3, 3, 3, 3, 3, 3, 0, 3], [3, 0, 3, ...
#
#                        Left Frontal_Dr_C_I_F_y_preds  \
# 0  [[3, 0, 3, 1, 0, 0, 3, 3, 1, 3, 1], [0, 1, 3, ...
# 1  [[1, 3, 3, 0, 0, 3, 3, 0, 3, 3, 3], [3, 0, 0, ...
#
#                       Right Frontal_Dr_C_I_F_y_preds  \
# 0  [[3, 0, 3, 1, 3, 0, 2, 3, 1, 3, 3], [0, 1, 3, ...
# 1  [[3, 1, 3, 0, 0, 0, 1, 0, 0, 3, 3], [1, 1, 0, ...
#
#                             Central_Dr_C_I_F_y_preds  \
# 0  [[3, 3, 3, 3, 3, 0, 3, 3, 3, 3, 1], [3, 1, 3, ...
# 1  [[1, 3, 0, 3, 3, 3, 3, 3, 3, 0, 3], [3, 3, 1, ...
#
#                        Left Central_Dr_C_I_F_y_preds  \
# 0  [[2, 3, 0, 0, 3, 3, 1, 3, 3, 3, 2], [0, 0, 3, ...
# 1  [[0, 3, 2, 0, 3, 3, 3, 0, 0, 3, 0], [3, 1, 3, ...
#
#                       Right Central_Dr_C_I_F_y_preds  \
# 0  [[2, 3, 2, 1, 0, 0, 3, 3, 1, 3, 3], [0, 0, 3, ...
# 1  [[3, 3, 0, 0, 3, 3, 0, 0, 3, 3, 3], [3, 1, 3, ...
#
#                       Left Temporal_Dr_C_I_F_y_preds  \
# 0  [[1, 3, 2, 0, 0, 0, 3, 3, 1, 3, 3], [0, 0, 0, ...
# 1  [[0, 3, 3, 0, 3, 3, 0, 0, 3, 3, 3], [3, 1, 0, ...
#
#                      Right Temporal_Dr_C_I_F_y_preds  \
# 0  [[2, 0, 2, 0, 2, 3, 1, 3, 3, 3, 3], [1, 1, 0, ...
# 1  [[3, 3, 0, 0, 0, 3, 1, 1, 3, 0, 0], [3, 1, 1, ...
#
#                            Parietal_Dr_C_I_F_y_preds  \
# 0  [[2, 3, 3, 3, 2, 0, 3, 1, 1, 3, 3], [0, 1, 3, ...
# 1  [[3, 3, 0, 3, 0, 0, 3, 0, 3, 0, 0], [3, 0, 0, ...
#
#                       Left Parietal_Dr_C_I_F_y_preds  \
# 0  [[2, 1, 2, 0, 2, 3, 3, 3, 0, 3, 0], [1, 1, 3, ...
# 1  [[1, 1, 0, 3, 0, 3, 3, 0, 3, 0, 3], [3, 0, 3, ...
#
#                      Right Parietal_Dr_C_I_F_y_preds  \
# 0  [[3, 1, 3, 1, 0, 3, 1, 1, 1, 3, 3], [0, 0, 1, ...
# 1  [[3, 3, 0, 0, 0, 3, 0, 0, 3, 0, 0], [3, 1, 1, ...
#
#                           Occipital_Dr_C_I_F_y_preds
# 0  [[3, 3, 3, 1, 3, 1, 3, 3, 3, 0, 0], [0, 1, 0, ...
# 1  [[3, 3, 0, 3, 3, 3, 3, 0, 3, 0, 0], [0, 1, 1, ...

# %%
with io.capture_output() as captured:
    per_fold_metrics = calculate_results.calc_per_fold_metrics(pd.read_hdf(save_path , key='df', mode='r'), 'non binary')
    df_overall = calculate_results.overall_weighted_metrics(per_fold_metrics, 'non binary')
df_overall
# Out:
#    Prefrontal_Dr_C_I_F_acc_mean  Prefrontal_Dr_C_I_F_acc_std  \
# 0                      0.188679                     0.060949
#
#    Prefrontal_Dr_C_I_F_prec_mean  Prefrontal_Dr_C_I_F_prec_std  \
# 0                       0.142242                      0.075318
#
#    Prefrontal_Dr_C_I_F_recall_mean  Prefrontal_Dr_C_I_F_recall_std  \
# 0                          0.22048                        0.115391
#
#    Frontal_Dr_C_I_F_acc_mean  Frontal_Dr_C_I_F_acc_std  \
# 0                   0.235849                  0.143069
#
#    Frontal_Dr_C_I_F_prec_mean  Frontal_Dr_C_I_F_prec_std  \
# 0                    0.215383                   0.165728
#
#    Frontal_Dr_C_I_F_recall_mean  Frontal_Dr_C_I_F_recall_std  \
# 0                      0.268054                     0.153112
#
#    Left Frontal_Dr_C_I_F_acc_mean  Left Frontal_Dr_C_I_F_acc_std  \
# 0                        0.264151                       0.099093
#
#    Left Frontal_Dr_C_I_F_prec_mean  Left Frontal_Dr_C_I_F_prec_std  \
# 0                          0.25537                        0.138124
#
#    Left Frontal_Dr_C_I_F_recall_mean  Left Frontal_Dr_C_I_F_recall_std  \
# 0                           0.275337                          0.127584
#
#    Right Frontal_Dr_C_I_F_acc_mean  Right Frontal_Dr_C_I_F_acc_std  \
# 0                         0.235849                        0.115626
#
#    Right Frontal_Dr_C_I_F_prec_mean  Right Frontal_Dr_C_I_F_prec_std  \
# 0                          0.192178                         0.126412
#
#    Right Frontal_Dr_C_I_F_recall_mean  Right Frontal_Dr_C_I_F_recall_std  \
# 0                            0.252005                           0.149846
#
#    Central_Dr_C_I_F_acc_mean  Central_Dr_C_I_F_acc_std  \
# 0                   0.245283                  0.153316
#
#    Central_Dr_C_I_F_prec_mean  Central_Dr_C_I_F_prec_std  \
# 0                    0.161616                   0.102096
#
#    Central_Dr_C_I_F_recall_mean  Central_Dr_C_I_F_recall_std  \
# 0                      0.261135                     0.153279
#
#    Left Central_Dr_C_I_F_acc_mean  Left Central_Dr_C_I_F_acc_std  \
# 0                        0.245283                       0.164748
#
#    Left Central_Dr_C_I_F_prec_mean  Left Central_Dr_C_I_F_prec_std  \
# 0                         0.186074                        0.193572
#
#    Left Central_Dr_C_I_F_recall_mean  Left Central_Dr_C_I_F_recall_std  \
# 0                           0.229049                          0.140573
#
#    Right Central_Dr_C_I_F_acc_mean  Right Central_Dr_C_I_F_acc_std  \
# 0                         0.216981                        0.120618
#
#    Right Central_Dr_C_I_F_prec_mean  Right Central_Dr_C_I_F_prec_std  \
# 0                          0.162806                         0.088039
#
#    Right Central_Dr_C_I_F_recall_mean  Right Central_Dr_C_I_F_recall_std  \
# 0                            0.215813                           0.129184
#
#    Left Temporal_Dr_C_I_F_acc_mean  Left Temporal_Dr_C_I_F_acc_std  \
# 0                         0.216981                        0.175573
#
#    Left Temporal_Dr_C_I_F_prec_mean  Left Temporal_Dr_C_I_F_prec_std  \
# 0                          0.139988                         0.134216
#
#    Left Temporal_Dr_C_I_F_recall_mean  Left Temporal_Dr_C_I_F_recall_std  \
# 0                             0.19913                            0.17752
#
#    Right Temporal_Dr_C_I_F_acc_mean  Right Temporal_Dr_C_I_F_acc_std  \
# 0                          0.273585                         0.170881
#
#    Right Temporal_Dr_C_I_F_prec_mean  Right Temporal_Dr_C_I_F_prec_std  \
# 0                           0.202669                          0.186408
#
#    Right Temporal_Dr_C_I_F_recall_mean  Right Temporal_Dr_C_I_F_recall_std  \
# 0                             0.202493                            0.115101
#
#    Parietal_Dr_C_I_F_acc_mean  Parietal_Dr_C_I_F_acc_std  \
# 0                    0.207547                   0.116862
#
#    Parietal_Dr_C_I_F_prec_mean  Parietal_Dr_C_I_F_prec_std  \
# 0                      0.15639                     0.11664
#
#    Parietal_Dr_C_I_F_recall_mean  Parietal_Dr_C_I_F_recall_std  \
# 0                       0.208294                      0.119219
#
#    Left Parietal_Dr_C_I_F_acc_mean  Left Parietal_Dr_C_I_F_acc_std  \
# 0                         0.235849                         0.13625
#
#    Left Parietal_Dr_C_I_F_prec_mean  Left Parietal_Dr_C_I_F_prec_std  \
# 0                          0.213606                          0.08871
#
#    Left Parietal_Dr_C_I_F_recall_mean  Left Parietal_Dr_C_I_F_recall_std  \
# 0                            0.233137                           0.103979
#
#    Right Parietal_Dr_C_I_F_acc_mean  Right Parietal_Dr_C_I_F_acc_std  \
# 0                          0.264151                         0.158842
#
#    Right Parietal_Dr_C_I_F_prec_mean  Right Parietal_Dr_C_I_F_prec_std  \
# 0                           0.208356                          0.173272
#
#    Right Parietal_Dr_C_I_F_recall_mean  Right Parietal_Dr_C_I_F_recall_std  \
# 0                             0.285478                            0.179221
#
#    Occipital_Dr_C_I_F_acc_mean  Occipital_Dr_C_I_F_acc_std  \
# 0                     0.216981                    0.099365
#
#    Occipital_Dr_C_I_F_prec_mean  Occipital_Dr_C_I_F_prec_std  \
# 0                      0.219093                     0.138047
#
#    Occipital_Dr_C_I_F_recall_mean  Occipital_Dr_C_I_F_recall_std
# 0                        0.236293                       0.133499

# %%
clf_list = ['Rocket', 'C_I_F', 'Dr_C_I_F']

#Results dictionary structure : {model : {expt_type : {folder : results_df }}}
results_dict = {}
for clf in clf_list:
    results_dict[clf] = {1 : {} , 2 : {} , 3: {} , 4 : {}}

core_path = '/export/sphere/ebirah/ko20929/RBD_files/notebooks/frequency_analysis/constructed_data/band_power_time_series/expt_dfs/'

folders = ['N1_customised_40_expt_files', 'N2_120_expt_files_v2', 'N3_82_expt_files', 'REM_19_expt_files', 'EC_8_expts',
           'N1_full_expts', 'N2_full_expts', 'N3_full_expts', 'REM_full_expts', 'EC_full_expts']

files_not_found = []

for num in [1,2,3,4]:
    for folder in folders:
        for clf in clf_list:
            try:
                #first term is the parent directory
                save_path = os.path.dirname(os.getcwd()) + '/Results/Results_2/' + clf + 'expt_type_' + str(num) + '_' + folder + 'int_df.h5'
                results_df = pd.read_hdf(save_path , key='df', mode='r')
            except FileNotFoundError:
                files_not_found.append(save_path)
                continue
                
            res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)           
            results_dict[clf][num][folder] = res_df
            
#Put results in a Df structure that is easy to plot etc....  
#Defining the dataframe dictionary to be filled up

expt_info = [ '1. PD vs HC', '2. (PD , PD+RBD) vs HC', '3. (PD + PD&RBD) vs HC vs RBD  multiclass', 
             '4. PD vs PD+RBD vs RBD vs HC  multiclass' ]

df_cols = ['Expt_type num', 'Folder', 'Classifier Name', 'Classifier', 'EEG Type',
       'Brain Region', 'Accuracy', 'Accuracy_std', 'TS processing']

df_dict = {}
for col in df_cols:
    df_dict[col] = []

regions = constants.regions

for clf in clf_list:
    for folder in folders:
        #Define EEG type from folder
        for eeg_type in ['N1' , 'N2' , 'N3' , 'REM' , 'EC']:
            if folder.startswith(eeg_type):
                eeg_type_res = eeg_type
        if 'full' in folder: 
            proc = 'full length'
        else:
            proc = 'shorter_expts'
        for expt_num in [1,2,3,4]:
            #Fill up the results_dict with the appropriate values
            #Grab accuracy and std performance for each region
            try:
                mean_df = pd.DataFrame(results_dict[clf][expt_num][folder].mean(axis = 0) ).T
            
            except KeyError:
                continue
            for region in regions:
                #For each region take mean accuracy and std
                region_cols = [col for col in mean_df.columns if region in col]
                acc_col = [col for col in region_cols if 'acc' in col]
                std_col = [col for col in region_cols if 'std' in col]
                region_acc = mean_df[acc_col].values[0][0]
                region_acc_std = mean_df[std_col].values[0][0]
                
                #Now fill up the dataframe
                df_dict['Expt_type num'].append(expt_num)
                df_dict['Folder'].append(folder)
                df_dict['Classifier Name'].append(clf)
                df_dict['Classifier'].append(clf)
                df_dict['EEG Type'].append(eeg_type_res)
                df_dict['Brain Region'].append(region)
                df_dict['Accuracy'].append(region_acc)
                df_dict['Accuracy_std'].append(region_acc_std)
                df_dict['TS processing'].append(proc)

results_df = pd.DataFrame(df_dict)

# %%
results_df.sort_values(by = ['Accuracy'], ascending = False).head(20)
# Out:
#       Expt_type num                       Folder Classifier Name Classifier  \
# 267               1                N1_full_expts          Rocket     Rocket
# 1264              2                   EC_8_expts        Dr_C_I_F   Dr_C_I_F
# 3                 1  N1_customised_40_expt_files          Rocket     Rocket
# 266               1                N1_full_expts          Rocket     Rocket
# 1523              2                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 1001              2                EC_full_expts           C_I_F      C_I_F
# 1                 1  N1_customised_40_expt_files          Rocket     Rocket
# 261               1                N1_full_expts          Rocket     Rocket
# 12                1  N1_customised_40_expt_files          Rocket     Rocket
# 264               1                N1_full_expts          Rocket     Rocket
# 1260              1                   EC_8_expts        Dr_C_I_F   Dr_C_I_F
# 730               1                   EC_8_expts           C_I_F      C_I_F
# 272               1                N1_full_expts          Rocket     Rocket
# 268               1                N1_full_expts          Rocket     Rocket
# 265               1                N1_full_expts          Rocket     Rocket
# 1524              2                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 1004              2                EC_full_expts           C_I_F      C_I_F
# 1521              2                EC_full_expts        Dr_C_I_F   Dr_C_I_F
# 263               1                N1_full_expts          Rocket     Rocket
# 260               1                N1_full_expts          Rocket     Rocket
#
#      EEG Type    Brain Region  Accuracy  Accuracy_std  TS processing
# 267        N1   Left Temporal  0.762500      0.086299    full length
# 1264       EC   Right Frontal  0.752381      0.201547  shorter_expts
# 3          N1   Right Frontal  0.725000      0.138388  shorter_expts
# 266        N1   Right Central  0.725000      0.119658    full length
# 1523       EC    Left Frontal  0.723214      0.087477    full length
# 1001       EC      Prefrontal  0.721429      0.106624    full length
# 1          N1         Frontal  0.712500      0.109779  shorter_expts
# 261        N1         Frontal  0.712500      0.136237    full length
# 12         N1       Occipital  0.712500      0.146653  shorter_expts
# 264        N1         Central  0.712500      0.110508    full length
# 1260       EC       Occipital  0.700000      0.128990  shorter_expts
# 730        EC    Left Frontal  0.700000      0.181980  shorter_expts
# 272        N1       Occipital  0.700000      0.138738    full length
# 268        N1  Right Temporal  0.700000      0.154779    full length
# 265        N1    Left Central  0.700000      0.110508    full length
# 1524       EC   Right Frontal  0.694643      0.115135    full length
# 1004       EC   Right Frontal  0.694643      0.157447    full length
# 1521       EC      Prefrontal  0.694643      0.132617    full length
# 263        N1   Right Frontal  0.687500      0.143541    full length
# 260        N1      Prefrontal  0.687500      0.138627    full length

# %%
results_df = results_df[results_df['Classifier'] == 'Rocket']
print('Keeping only the Rocket Results')
# Out:
# Keeping only the Rocket Results

# %% [markdown]
# ## This portion of the notebook plots accuracy by region (to view trends)

# %%
results_df_sorted = results_df.sort_values(by = ['Accuracy'], ascending = False)
results_df_sorted.head(12)
# Out:
#      Expt_type num                       Folder Classifier Name Classifier  \
# 267              1                N1_full_expts          Rocket     Rocket
# 266              1                N1_full_expts          Rocket     Rocket
# 3                1  N1_customised_40_expt_files          Rocket     Rocket
# 12               1  N1_customised_40_expt_files          Rocket     Rocket
# 1                1  N1_customised_40_expt_files          Rocket     Rocket
# 261              1                N1_full_expts          Rocket     Rocket
# 264              1                N1_full_expts          Rocket     Rocket
# 272              1                N1_full_expts          Rocket     Rocket
# 265              1                N1_full_expts          Rocket     Rocket
# 268              1                N1_full_expts          Rocket     Rocket
# 263              1                N1_full_expts          Rocket     Rocket
# 260              1                N1_full_expts          Rocket     Rocket
#
#     EEG Type    Brain Region  Accuracy  Accuracy_std  TS processing
# 267       N1   Left Temporal    0.7625      0.086299    full length
# 266       N1   Right Central    0.7250      0.119658    full length
# 3         N1   Right Frontal    0.7250      0.138388  shorter_expts
# 12        N1       Occipital    0.7125      0.146653  shorter_expts
# 1         N1         Frontal    0.7125      0.109779  shorter_expts
# 261       N1         Frontal    0.7125      0.136237    full length
# 264       N1         Central    0.7125      0.110508    full length
# 272       N1       Occipital    0.7000      0.138738    full length
# 265       N1    Left Central    0.7000      0.110508    full length
# 268       N1  Right Temporal    0.7000      0.154779    full length
# 263       N1   Right Frontal    0.6875      0.143541    full length
# 260       N1      Prefrontal    0.6875      0.138627    full length

# %%
expt_results['Accuracy'].max()
# Out:
# 0.49238095238095236

# %%
fig = plt.figure()
fig = plt.figure(figsize=(15,5),dpi=100)

for i in [1,2,3,4]:
    expt_num = i
    expt_results = results_df[results_df['Expt_type num'] == expt_num].copy()
    expt_results.sort_values(by=['Brain Region','Accuracy'], ascending = False)
    
    ax = fig.add_subplot(1,4,i)
    
    plt.title('Accuracy vs Brain Region \n' + expt_info[expt_num-1])
    
    #Define colours for the different data types
    colors = {'EC':'tab:blue', 'N1':'tab:orange', 'N2':'tab:green', 'N3':'tab:red', 'REM':'tab:purple'}
#     plt.scatter(expt_results['Brain Region'].values, expt_results['Accuracy'].values,
#                     c = expt_results['EEG Type'].map(colors))

    #Plot one data point per region / data type combination - average the performance across short and long processing
    for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
        for region in regions:
            acc = expt_results[(expt_results['Brain Region'] == region) & (expt_results['EEG Type'] == eeg_type)].mean(numeric_only = True)['Accuracy']
            plt.scatter(region, acc,
                    c = colors[eeg_type])
    
   
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
    plt.xlabel('Brain Region')
    plt.ylabel('Accuracy')
    plt.ylim((expt_results['Accuracy'].min() - 0.05 , expt_results['Accuracy'].max() + 0.1))
    plt.grid()

    plt.tight_layout()

#Custom Legend, because standard legend wouldn't work for some reason
patches = []
for key, val in colors.items():
    patches.append(mpatches.Patch(color= val, label=key) )

# plt.legend(handles=patches, framealpha = 0.1)
plt.legend(loc = 'upper center', ncol = 3 ,  handles=patches, framealpha = 0.4)
    
plt.tight_layout()

#Do the plots again for data type accuracy distribution
fig = plt.figure()
fig = plt.figure(figsize=(15,5),dpi=100)

for i in [1,2,3,4]:
    expt_num = i
    expt_results = results_df[results_df['Expt_type num'] == expt_num].copy()
    expt_results.sort_values(by=['Brain Region','Accuracy'], ascending = False)
    
    ax = fig.add_subplot(1,4,i)
    
    plt.title('Accuracy vs Brain Region \n' + expt_info[expt_num-1])
    
    #Define colours for the different data types
    colors = {'EC':'tab:blue', 'N1':'tab:orange', 'N2':'tab:green', 'N3':'tab:red', 'REM':'tab:purple'}
#     plt.scatter(expt_results['Brain Region'].values, expt_results['Accuracy'].values,
#                     c = expt_results['EEG Type'].map(colors))

    #Plot one data point per region / data type combination - average the performance across short and long processing
    for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
        for region in regions:
            acc = expt_results[(expt_results['Brain Region'] == region) & (expt_results['EEG Type'] == eeg_type)].mean(numeric_only = True)['Accuracy']
            plt.scatter(eeg_type, acc,
                    c = colors[eeg_type])
    
   
    plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
    plt.xlabel('EEG Type')
    plt.ylabel('Accuracy')
    plt.ylim((expt_results['Accuracy'].min() - 0.05 , expt_results['Accuracy'].max() + 0.1))
    plt.grid()

    plt.tight_layout()

plt.tight_layout()


# plt.savefig('classifier_accuracy_original_epoch_bpw.png', dpi=200)

# %% [markdown]
# ## Do statistical significance tests

# %%
results_df = results_df[results_df['Classifier'] == 'Rocket']
rocket_results = results_df[results_df['Expt_type num'] == 4] 
rocket_results
# Out:
#      Expt_type num                       Folder Classifier Name Classifier  \
# 39               4  N1_customised_40_expt_files          Rocket     Rocket
# 40               4  N1_customised_40_expt_files          Rocket     Rocket
# 41               4  N1_customised_40_expt_files          Rocket     Rocket
# 42               4  N1_customised_40_expt_files          Rocket     Rocket
# 43               4  N1_customised_40_expt_files          Rocket     Rocket
# 44               4  N1_customised_40_expt_files          Rocket     Rocket
# 45               4  N1_customised_40_expt_files          Rocket     Rocket
# 46               4  N1_customised_40_expt_files          Rocket     Rocket
# 47               4  N1_customised_40_expt_files          Rocket     Rocket
# 48               4  N1_customised_40_expt_files          Rocket     Rocket
# 49               4  N1_customised_40_expt_files          Rocket     Rocket
# 50               4  N1_customised_40_expt_files          Rocket     Rocket
# 51               4  N1_customised_40_expt_files          Rocket     Rocket
# 91               4         N2_120_expt_files_v2          Rocket     Rocket
# 92               4         N2_120_expt_files_v2          Rocket     Rocket
# 93               4         N2_120_expt_files_v2          Rocket     Rocket
# 94               4         N2_120_expt_files_v2          Rocket     Rocket
# 95               4         N2_120_expt_files_v2          Rocket     Rocket
# 96               4         N2_120_expt_files_v2          Rocket     Rocket
# 97               4         N2_120_expt_files_v2          Rocket     Rocket
# 98               4         N2_120_expt_files_v2          Rocket     Rocket
# 99               4         N2_120_expt_files_v2          Rocket     Rocket
# 100              4         N2_120_expt_files_v2          Rocket     Rocket
# 101              4         N2_120_expt_files_v2          Rocket     Rocket
# 102              4         N2_120_expt_files_v2          Rocket     Rocket
# 103              4         N2_120_expt_files_v2          Rocket     Rocket
# 143              4             N3_82_expt_files          Rocket     Rocket
# 144              4             N3_82_expt_files          Rocket     Rocket
# 145              4             N3_82_expt_files          Rocket     Rocket
# 146              4             N3_82_expt_files          Rocket     Rocket
# 147              4             N3_82_expt_files          Rocket     Rocket
# 148              4             N3_82_expt_files          Rocket     Rocket
# 149              4             N3_82_expt_files          Rocket     Rocket
# 150              4             N3_82_expt_files          Rocket     Rocket
# 151              4             N3_82_expt_files          Rocket     Rocket
# 152              4             N3_82_expt_files          Rocket     Rocket
# 153              4             N3_82_expt_files          Rocket     Rocket
# 154              4             N3_82_expt_files          Rocket     Rocket
# 155              4             N3_82_expt_files          Rocket     Rocket
# 195              4            REM_19_expt_files          Rocket     Rocket
# 196              4            REM_19_expt_files          Rocket     Rocket
# 197              4            REM_19_expt_files          Rocket     Rocket
# 198              4            REM_19_expt_files          Rocket     Rocket
# 199              4            REM_19_expt_files          Rocket     Rocket
# 200              4            REM_19_expt_files          Rocket     Rocket
# 201              4            REM_19_expt_files          Rocket     Rocket
# 202              4            REM_19_expt_files          Rocket     Rocket
# 203              4            REM_19_expt_files          Rocket     Rocket
# 204              4            REM_19_expt_files          Rocket     Rocket
# 205              4            REM_19_expt_files          Rocket     Rocket
# 206              4            REM_19_expt_files          Rocket     Rocket
# 207              4            REM_19_expt_files          Rocket     Rocket
# 247              4                   EC_8_expts          Rocket     Rocket
# 248              4                   EC_8_expts          Rocket     Rocket
# 249              4                   EC_8_expts          Rocket     Rocket
# 250              4                   EC_8_expts          Rocket     Rocket
# 251              4                   EC_8_expts          Rocket     Rocket
# 252              4                   EC_8_expts          Rocket     Rocket
# 253              4                   EC_8_expts          Rocket     Rocket
# 254              4                   EC_8_expts          Rocket     Rocket
# 255              4                   EC_8_expts          Rocket     Rocket
# 256              4                   EC_8_expts          Rocket     Rocket
# 257              4                   EC_8_expts          Rocket     Rocket
# 258              4                   EC_8_expts          Rocket     Rocket
# 259              4                   EC_8_expts          Rocket     Rocket
# 299              4                N1_full_expts          Rocket     Rocket
# 300              4                N1_full_expts          Rocket     Rocket
# 301              4                N1_full_expts          Rocket     Rocket
# 302              4                N1_full_expts          Rocket     Rocket
# 303              4                N1_full_expts          Rocket     Rocket
# 304              4                N1_full_expts          Rocket     Rocket
# 305              4                N1_full_expts          Rocket     Rocket
# 306              4                N1_full_expts          Rocket     Rocket
# 307              4                N1_full_expts          Rocket     Rocket
# 308              4                N1_full_expts          Rocket     Rocket
# 309              4                N1_full_expts          Rocket     Rocket
# 310              4                N1_full_expts          Rocket     Rocket
# 311              4                N1_full_expts          Rocket     Rocket
# 351              4                N2_full_expts          Rocket     Rocket
# 352              4                N2_full_expts          Rocket     Rocket
# 353              4                N2_full_expts          Rocket     Rocket
# 354              4                N2_full_expts          Rocket     Rocket
# 355              4                N2_full_expts          Rocket     Rocket
# 356              4                N2_full_expts          Rocket     Rocket
# 357              4                N2_full_expts          Rocket     Rocket
# 358              4                N2_full_expts          Rocket     Rocket
# 359              4                N2_full_expts          Rocket     Rocket
# 360              4                N2_full_expts          Rocket     Rocket
# 361              4                N2_full_expts          Rocket     Rocket
# 362              4                N2_full_expts          Rocket     Rocket
# 363              4                N2_full_expts          Rocket     Rocket
# 403              4                N3_full_expts          Rocket     Rocket
# 404              4                N3_full_expts          Rocket     Rocket
# 405              4                N3_full_expts          Rocket     Rocket
# 406              4                N3_full_expts          Rocket     Rocket
# 407              4                N3_full_expts          Rocket     Rocket
# 408              4                N3_full_expts          Rocket     Rocket
# 409              4                N3_full_expts          Rocket     Rocket
# 410              4                N3_full_expts          Rocket     Rocket
# 411              4                N3_full_expts          Rocket     Rocket
# 412              4                N3_full_expts          Rocket     Rocket
# 413              4                N3_full_expts          Rocket     Rocket
# 414              4                N3_full_expts          Rocket     Rocket
# 415              4                N3_full_expts          Rocket     Rocket
# 455              4               REM_full_expts          Rocket     Rocket
# 456              4               REM_full_expts          Rocket     Rocket
# 457              4               REM_full_expts          Rocket     Rocket
# 458              4               REM_full_expts          Rocket     Rocket
# 459              4               REM_full_expts          Rocket     Rocket
# 460              4               REM_full_expts          Rocket     Rocket
# 461              4               REM_full_expts          Rocket     Rocket
# 462              4               REM_full_expts          Rocket     Rocket
# 463              4               REM_full_expts          Rocket     Rocket
# 464              4               REM_full_expts          Rocket     Rocket
# 465              4               REM_full_expts          Rocket     Rocket
# 466              4               REM_full_expts          Rocket     Rocket
# 467              4               REM_full_expts          Rocket     Rocket
# 507              4                EC_full_expts          Rocket     Rocket
# 508              4                EC_full_expts          Rocket     Rocket
# 509              4                EC_full_expts          Rocket     Rocket
# 510              4                EC_full_expts          Rocket     Rocket
# 511              4                EC_full_expts          Rocket     Rocket
# 512              4                EC_full_expts          Rocket     Rocket
# 513              4                EC_full_expts          Rocket     Rocket
# 514              4                EC_full_expts          Rocket     Rocket
# 515              4                EC_full_expts          Rocket     Rocket
# 516              4                EC_full_expts          Rocket     Rocket
# 517              4                EC_full_expts          Rocket     Rocket
# 518              4                EC_full_expts          Rocket     Rocket
# 519              4                EC_full_expts          Rocket     Rocket
#
#     EEG Type    Brain Region  Accuracy  Accuracy_std  TS processing
# 39        N1      Prefrontal  0.486667      0.107963  shorter_expts
# 40        N1         Frontal  0.393333      0.087055  shorter_expts
# 41        N1    Left Frontal  0.422381      0.127829  shorter_expts
# 42        N1   Right Frontal  0.423810      0.074190  shorter_expts
# 43        N1         Central  0.386190      0.137607  shorter_expts
# 44        N1    Left Central  0.352381      0.070624  shorter_expts
# 45        N1   Right Central  0.492381      0.154266  shorter_expts
# 46        N1   Left Temporal  0.338095      0.060186  shorter_expts
# 47        N1  Right Temporal  0.360476      0.100213  shorter_expts
# 48        N1        Parietal  0.357619      0.138231  shorter_expts
# 49        N1   Left Parietal  0.330476      0.122328  shorter_expts
# 50        N1  Right Parietal  0.406667      0.098476  shorter_expts
# 51        N1       Occipital  0.378571      0.095790  shorter_expts
# 91        N2      Prefrontal  0.284615      0.127710  shorter_expts
# 92        N2         Frontal  0.261538      0.096787  shorter_expts
# 93        N2    Left Frontal  0.276923      0.117829  shorter_expts
# 94        N2   Right Frontal  0.261538      0.069867  shorter_expts
# 95        N2         Central  0.269231      0.078446  shorter_expts
# 96        N2    Left Central  0.223077      0.062010  shorter_expts
# 97        N2   Right Central  0.269231      0.099223  shorter_expts
# 98        N2   Left Temporal  0.200000      0.062010  shorter_expts
# 99        N2  Right Temporal  0.300000      0.113053  shorter_expts
# 100       N2        Parietal  0.269231      0.101380  shorter_expts
# 101       N2   Left Parietal  0.207692      0.100762  shorter_expts
# 102       N2  Right Parietal  0.330769      0.084077  shorter_expts
# 103       N2       Occipital  0.276923      0.088333  shorter_expts
# 143       N3      Prefrontal  0.274725      0.129543  shorter_expts
# 144       N3         Frontal  0.209890      0.075068  shorter_expts
# 145       N3    Left Frontal  0.238462      0.091927  shorter_expts
# 146       N3   Right Frontal  0.361538      0.071482  shorter_expts
# 147       N3         Central  0.151099      0.077705  shorter_expts
# 148       N3    Left Central  0.202198      0.075700  shorter_expts
# 149       N3   Right Central  0.311538      0.148143  shorter_expts
# 150       N3   Left Temporal  0.246703      0.056462  shorter_expts
# 151       N3  Right Temporal  0.304945      0.165077  shorter_expts
# 152       N3        Parietal  0.159341      0.048739  shorter_expts
# 153       N3   Left Parietal  0.297253      0.086622  shorter_expts
# 154       N3  Right Parietal  0.280220      0.119863  shorter_expts
# 155       N3       Occipital  0.165934      0.049576  shorter_expts
# 195      REM      Prefrontal  0.457143      0.136849  shorter_expts
# 196      REM         Frontal  0.368681      0.166437  shorter_expts
# 197      REM    Left Frontal  0.428022      0.095736  shorter_expts
# 198      REM   Right Frontal  0.442308      0.136546  shorter_expts
# 199      REM         Central  0.332418      0.080488  shorter_expts
# 200      REM    Left Central  0.384066      0.133153  shorter_expts
# 201      REM   Right Central  0.483516      0.173715  shorter_expts
# 202      REM   Left Temporal  0.398352      0.129893  shorter_expts
# 203      REM  Right Temporal  0.375824      0.097354  shorter_expts
# 204      REM        Parietal  0.332418      0.120652  shorter_expts
# 205      REM   Left Parietal  0.440659      0.181907  shorter_expts
# 206      REM  Right Parietal  0.389560      0.147534  shorter_expts
# 207      REM       Occipital  0.378022      0.114682  shorter_expts
# 247       EC      Prefrontal  0.210000      0.080613  shorter_expts
# 248       EC         Frontal  0.270000      0.088407  shorter_expts
# 249       EC    Left Frontal  0.330000      0.131794  shorter_expts
# 250       EC   Right Frontal  0.220000      0.074833  shorter_expts
# 251       EC         Central  0.340000      0.080613  shorter_expts
# 252       EC    Left Central  0.410000      0.137013  shorter_expts
# 253       EC   Right Central  0.370000      0.098310  shorter_expts
# 254       EC   Left Temporal  0.330000      0.114772  shorter_expts
# 255       EC  Right Temporal  0.280000      0.061911  shorter_expts
# 256       EC        Parietal  0.180000      0.113485  shorter_expts
# 257       EC   Left Parietal  0.310000      0.156074  shorter_expts
# 258       EC  Right Parietal  0.410000      0.141726  shorter_expts
# 259       EC       Occipital  0.370000      0.044495  shorter_expts
# 299       N1      Prefrontal  0.316667      0.068445    full length
# 300       N1         Frontal  0.367143      0.124022    full length
# 301       N1    Left Frontal  0.324286      0.064666    full length
# 302       N1   Right Frontal  0.318095      0.084947    full length
# 303       N1         Central  0.358095      0.148117    full length
# 304       N1    Left Central  0.308571      0.079525    full length
# 305       N1   Right Central  0.402381      0.152282    full length
# 306       N1   Left Temporal  0.294762      0.083213    full length
# 307       N1  Right Temporal  0.310952      0.108984    full length
# 308       N1        Parietal  0.310000      0.063350    full length
# 309       N1   Left Parietal  0.366190      0.112537    full length
# 310       N1  Right Parietal  0.317143      0.083743    full length
# 311       N1       Occipital  0.339048      0.072351    full length
# 351       N2      Prefrontal  0.396667      0.092151    full length
# 352       N2         Frontal  0.275238      0.093678    full length
# 353       N2    Left Frontal  0.332381      0.116213    full length
# 354       N2   Right Frontal  0.273810      0.118946    full length
# 355       N2         Central  0.311429      0.117320    full length
# 356       N2    Left Central  0.296190      0.088896    full length
# 357       N2   Right Central  0.254286      0.090952    full length
# 358       N2   Left Temporal  0.296667      0.078443    full length
# 359       N2  Right Temporal  0.282857      0.124246    full length
# 360       N2        Parietal  0.337619      0.097230    full length
# 361       N2   Left Parietal  0.297143      0.093424    full length
# 362       N2  Right Parietal  0.346667      0.110052    full length
# 363       N2       Occipital  0.296190      0.091373    full length
# 403       N3      Prefrontal  0.238095      0.118201    full length
# 404       N3         Frontal  0.180476      0.066197    full length
# 405       N3    Left Frontal  0.209048      0.083786    full length
# 406       N3   Right Frontal  0.284762      0.080418    full length
# 407       N3         Central  0.262381      0.097846    full length
# 408       N3    Left Central  0.209048      0.117733    full length
# 409       N3   Right Central  0.283333      0.085707    full length
# 410       N3   Left Temporal  0.279048      0.096749    full length
# 411       N3  Right Temporal  0.235714      0.096812    full length
# 412       N3        Parietal  0.208095      0.050288    full length
# 413       N3   Left Parietal  0.165714      0.042033    full length
# 414       N3  Right Parietal  0.242857      0.103131    full length
# 415       N3       Occipital  0.132381      0.076418    full length
# 455      REM      Prefrontal  0.374176      0.144169    full length
# 456      REM         Frontal  0.389011      0.194207    full length
# 457      REM    Left Frontal  0.346154      0.128799    full length
# 458      REM   Right Frontal  0.403297      0.117279    full length
# 459      REM         Central  0.289011      0.132805    full length
# 460      REM    Left Central  0.361538      0.105592    full length
# 461      REM   Right Central  0.390659      0.146325    full length
# 462      REM   Left Temporal  0.340659      0.081991    full length
# 463      REM  Right Temporal  0.382418      0.144856    full length
# 464      REM        Parietal  0.331868      0.098043    full length
# 465      REM   Left Parietal  0.410989      0.106314    full length
# 466      REM  Right Parietal  0.382418      0.122318    full length
# 467      REM       Occipital  0.440110      0.128396    full length
# 507       EC      Prefrontal  0.247273      0.131417    full length
# 508       EC         Frontal  0.177273      0.122028    full length
# 509       EC    Left Frontal  0.292727      0.124280    full length
# 510       EC   Right Frontal  0.310000      0.097310    full length
# 511       EC         Central  0.312727      0.077514    full length
# 512       EC    Left Central  0.260909      0.139203    full length
# 513       EC   Right Central  0.189091      0.105736    full length
# 514       EC   Left Temporal  0.228182      0.088384    full length
# 515       EC  Right Temporal  0.292727      0.090411    full length
# 516       EC        Parietal  0.189091      0.071660    full length
# 517       EC   Left Parietal  0.207273      0.096677    full length
# 518       EC  Right Parietal  0.291818      0.091801    full length
# 519       EC       Occipital  0.274545      0.126254    full length

# %%
regional_means, eeg_type_means = {} , {}
for region in regions:
    regional_means[region] = round(rocket_results[rocket_results['Brain Region'] == region].mean(numeric_only= True)['Accuracy'],3)

for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
    eeg_type_means[eeg_type] = round(rocket_results[rocket_results['EEG Type'] == eeg_type].mean(numeric_only= True)['Accuracy'],3)

print(regional_means)
print('\n')
print(eeg_type_means)
# Out:
# {'Prefrontal': 0.329, 'Frontal': 0.289, 'Left Frontal': 0.32, 'Right Frontal': 0.33, 'Central': 0.301, 'Left Central': 0.301, 'Right Central': 0.345, 'Left Temporal': 0.295, 'Right Temporal': 0.313, 'Parietal': 0.268, 'Left Parietal': 0.303, 'Right Parietal': 0.34, 'Occipital': 0.305}
#
#
# {'EC': 0.281, 'N1': 0.364, 'N2': 0.286, 'N3': 0.236, 'REM': 0.387}

# %%
pd.DataFrame(regional_means, index = ['mean_acc']).T.sort_values(by = ['mean_acc']).T
# Out:
#           Parietal  Frontal  Left Temporal  Central  Left Central  \
# mean_acc     0.268    0.289          0.295    0.301         0.301
#
#           Left Parietal  Occipital  Right Temporal  Left Frontal  Prefrontal  \
# mean_acc          0.303      0.305           0.313          0.32       0.329
#
#           Right Frontal  Right Parietal  Right Central
# mean_acc           0.33            0.34          0.345

# %%
pd.DataFrame(eeg_type_means, index = ['mean_acc']).T.sort_values(by = ['mean_acc']).T
# Out:
#              N3     EC     N2     N1    REM
# mean_acc  0.236  0.281  0.286  0.364  0.387

# %%
#1. generate the dfs 
regional_acc_distribution , eeg_type_distribution = {} , {}

for eeg_type in ['EC', 'N1', 'N2', 'N3', 'REM']:
    eeg_type_distribution[eeg_type] = rocket_results[rocket_results['EEG Type'] == eeg_type]['Accuracy'].values

for region in regions:
    regional_acc_distribution[region] = rocket_results[rocket_results['Brain Region'] == region]['Accuracy'].values

eeg_type_dist = pd.DataFrame(eeg_type_distribution)
regional_acc_dist = pd.DataFrame(regional_acc_distribution)

# %%
print(stats.friedmanchisquare(*eeg_type_dist.T.values) ) 
output_results = sp.posthoc_nemenyi_friedman(eeg_type_dist.values)

column_mapping = {0: 'EC', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'REM'}
row_mapping = {0: 'EC', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'REM'}
df = output_results.rename(columns=column_mapping, index=row_mapping)
df
# Out:
# FriedmanchisquareResult(statistic=59.53846153846155, pvalue=3.6266361432616924e-12)
#            EC        N1        N2        N3    REM
# EC   1.000000  0.001525  0.900000  0.257559  0.001
# N1   0.001525  1.000000  0.005643  0.001000  0.900
# N2   0.900000  0.005643  1.000000  0.124375  0.001
# N3   0.257559  0.001000  0.124375  1.000000  0.001
# REM  0.001000  0.900000  0.001000  0.001000  1.000

# %%
print(stats.friedmanchisquare(*regional_acc_dist.T.values) ) 

output_results = sp.posthoc_nemenyi_friedman(regional_acc_dist.values)

column_mapping = {}
for i in range(len(regional_acc_dist.columns)): 
    column_mapping[i] = list(regional_acc_dist.columns)[i]
row_mapping = column_mapping    
    
df = output_results.rename(columns=column_mapping, index=row_mapping)
df
# Out:
# FriedmanchisquareResult(statistic=24.28776185226019, pvalue=0.018582919723467737)
#                 Prefrontal   Frontal  Left Frontal  Right Frontal   Central  \
# Prefrontal        1.000000  0.880709      0.900000       0.900000  0.900000
# Frontal           0.880709  1.000000      0.900000       0.735097  0.900000
# Left Frontal      0.900000  0.900000      1.000000       0.900000  0.900000
# Right Frontal     0.900000  0.735097      0.900000       1.000000  0.900000
# Central           0.900000  0.900000      0.900000       0.900000  1.000000
# Left Central      0.880709  0.900000      0.900000       0.735097  0.900000
# Right Central     0.900000  0.479500      0.900000       0.900000  0.900000
# Left Temporal     0.862506  0.900000      0.900000       0.716896  0.900000
# Right Temporal    0.900000  0.900000      0.900000       0.900000  0.900000
# Parietal          0.320205  0.900000      0.419423       0.195664  0.862506
# Left Parietal     0.900000  0.900000      0.900000       0.900000  0.900000
# Right Parietal    0.900000  0.459915      0.900000       0.900000  0.900000
# Occipital         0.900000  0.900000      0.900000       0.900000  0.900000
#
#                 Left Central  Right Central  Left Temporal  Right Temporal  \
# Prefrontal          0.880709       0.900000       0.862506        0.900000
# Frontal             0.900000       0.479500       0.900000        0.900000
# Left Frontal        0.900000       0.900000       0.900000        0.900000
# Right Frontal       0.735097       0.900000       0.716896        0.900000
# Central             0.900000       0.900000       0.900000        0.900000
# Left Central        1.000000       0.479500       0.900000        0.900000
# Right Central       0.479500       1.000000       0.459915        0.900000
# Left Temporal       0.900000       0.459915       1.000000        0.900000
# Right Temporal      0.900000       0.900000       0.900000        1.000000
# Parietal            0.900000       0.067612       0.900000        0.826107
# Left Parietal       0.900000       0.900000       0.900000        0.900000
# Right Parietal      0.459915       0.900000       0.439834        0.900000
# Occipital           0.900000       0.900000       0.900000        0.900000
#
#                 Parietal  Left Parietal  Right Parietal  Occipital
# Prefrontal      0.320205            0.9        0.900000   0.900000
# Frontal         0.900000            0.9        0.459915   0.900000
# Left Frontal    0.419423            0.9        0.900000   0.900000
# Right Frontal   0.195664            0.9        0.900000   0.900000
# Central         0.862506            0.9        0.900000   0.900000
# Left Central    0.900000            0.9        0.459915   0.900000
# Right Central   0.067612            0.9        0.900000   0.900000
# Left Temporal   0.900000            0.9        0.439834   0.900000
# Right Temporal  0.826107            0.9        0.900000   0.900000
# Parietal        1.000000            0.9        0.061963   0.789702
# Left Parietal   0.900000            1.0        0.900000   0.900000
# Right Parietal  0.061963            0.9        1.000000   0.900000
# Occipital       0.789702            0.9        0.900000   1.000000
