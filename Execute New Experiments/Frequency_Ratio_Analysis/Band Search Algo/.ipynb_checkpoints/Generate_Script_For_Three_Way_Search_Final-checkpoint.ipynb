# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

## Use decision tree as a rough way for splitting based on that feature
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
from sklearn import tree

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
import run_expts

from constants import regions

# %%
1500 --> # Let us load the top 1,500 column combinations

# %%
reduced_slide_list = [ (0.5, 0.5), (1, 0.5), (2, 0.5), (3, 0.5), (4, 0.5), (6, 0.5), (8, 0.5), (10, 1), (12, 1), (14, 1)]
super_reduced_slide_list = [ (0.5, 0.5), (2, 0.5), (3, 0.5), (4, 1), (6, 1), (8, 1), (10, 1), (14, 1)]

# %%
#A ratio as an explicit feature
width_slide_list = [(0.5,0.5)] 
for window_width in range(1, 15 ):
    width_slide_list.append((window_width, 0.5) )

# %%
sys.argv[1] = 1
sys.argv[2] = 1

# %%
t1 = time.time()

# 1 Data type is defined by script input ______________________________________________________
d_num = int( sys.argv[1] )
data_type = ['N2', 'N3','REM', 'Wake', 'N1'][d_num]
expt_num = int(sys.argv[2])


for region in regions:
    #2. Load the data based on data type ___________________________________________________________
    df = joblib.load(os.path.join(os.path.abspath('..'), data_type + '_psd_normalised_data.pkl') )
    
    single_region_df = df[[col for col in df.columns if col.endswith('_' + region)]]
    frequency_vals  = np.arange(0.5,40.125, 0.125)
    single_region_df.columns = frequency_vals
    
    folder = '/user/home/ko20929/work/RBD_using_custom_package/Blue_pebble/'
    paths = joblib.load(folder + data_type + '_paths.pkl')
    
    groups = pd.Series(paths['s_p_id'])
    s_class_list = pd.Series(paths['s_class_list'])
    y = s_class_list.map({'HC': 0 , 'PD' : 1 , 'PD+RBD' : 2 , 'RBD' : 3})
    
    #3 Generate the frequency band search space ____________________________________________________
    width_slide_list = [(0.5,0.5)] 
    for window_width in range(1, 15 ):
        width_slide_list.append((window_width, 0.5) )
    
    #4 Calculate all of the features ________________________________________________________________
    feature_dfs = []
    
    for window_width_hz, window_slide_hz in width_slide_list:
        description = 'window width : ' + str(window_width_hz) + ' .  window stride : ' + str(window_slide_hz)
        
        #1.Set Window width in Hz and Window Slide in Hz
        # window_width_hz = 3
        window_len = (window_width_hz/0.125)+1
        assert window_len%1 == 0
        window_len = int(window_len)
        
        # window_slide_hz = 0.5 
        window_slide_len = window_slide_hz/0.125 
        assert window_slide_len%1 == 0
        window_slide_len = int(window_slide_len)
        
        
        #2.Calculate band values and store in dataframe calculated_df
        
        # Start of the window is the middle_freq value minus window_width_hz/2 
        # End of the window is the middle freq value plus window_width_hz/2
        window_len
        
        middle_freq = []
        final_cols = []
        
        i = 0
        while i < len(frequency_vals) - window_len:
            middle_freq.append( frequency_vals[i:i+window_len].mean() )
            band_vals = single_region_df.iloc[:,i:i+window_len].mean(axis = 1) #For every row calculate the mean for the appropriate elements
            
            final_cols.append(band_vals)
            
            # scaled_psd.append( psd_values[i:i+factor].mean() )
            i+= window_slide_len
        
        calculated_df = pd.DataFrame(final_cols).T
        calculated_df.columns = middle_freq
        
        calculated_df.columns = [ str(col) + '_width_' + str(window_width_hz) for col in calculated_df.columns]
        
        
        #3.Calculate Information Gain Based on Features
        #Change to binary HC vs PD / PD+RBD ---> Generate expt specific X,y,groups 
        X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(calculated_df,y,groups,expt_num)
    
        feature_dfs.append(X_expt)
            
    #5 Concatenate all feature_dfs into a single dataframe_________________________________________________________________
    X_expt_concatenated = pd.concat(feature_dfs, axis=1)

    #HERE I NEED TO EDIT: 
    #1. Col combos become three col combos
    #2. This is done for the top n dual results combine with a defined set of third 'windows' ok? 
    
    cols_list = list(X_expt_concatenated.columns)
    
    col_combos = []
    for col_1 in cols_list:
        ind = cols_list.index(col_1)
        for col_2 in cols_list[ind+1:]:
            col_combos.append([ col_1 , col_2 ] )

t2 = time.time()

t2-t1
# Out:
# 11.105643033981323

# %%
#1 Load the appropriate scores and column combos files
f_name =  'Results/' + data_type + '_' + region +  '_expt_' + str(expt_num) + '_scores.pkl'
scores = joblib.load(f_name)

f_name =  'Results/' + 'N2' + '_' + region + '_expt_' + str(expt_num) + '_col_combos.pkl'
coL_combos = joblib.load(f_name)

# %%
#2. Determine the top n column combos
n = 1500
top_n_indices = list(np.argsort(np.array(scores))[-n:])
top_n_scores = np.array(scores)[top_n_indices]

top_n_col_combos = np.array(col_combos)[top_n_indices]
top_n_col_combos = [list(val) for val in top_n_col_combos]

# %%
#3. Create a new set of combos consisting of three cols
# Combine each of the cols in top_n_col_combos with a third column from my reduced cols list

# %%
#3 Generate the reduced cols list 
reduced_slide_list = [ (0.5, 0.5), (1, 0.5), (2, 0.5), (3, 0.5), (4, 0.5), (6, 0.5), (8, 0.5), (10, 1), (12, 1), (14, 1)]
reduced_cols_list = []
for window_width_hz, window_slide_hz in reduced_slide_list:
    description = 'window width : ' + str(window_width_hz) + ' .  window stride : ' + str(window_slide_hz)
        
    #1.Set Window width in Hz and Window Slide in Hz
    # window_width_hz = 3
    window_len = (window_width_hz/0.125)+1
    assert window_len%1 == 0
    window_len = int(window_len)
    
    # window_slide_hz = 0.5 
    window_slide_len = window_slide_hz/0.125 
    assert window_slide_len%1 == 0
    window_slide_len = int(window_slide_len)

    #2. Calculate band values and store in dataframe calculated_df
    middle_freq = []

    i = 0

    while i < len(frequency_vals) - window_len:
        middle_freq.append( frequency_vals[i:i+window_len].mean() )
        # scaled_psd.append( psd_values[i:i+factor].mean() )
        i+= window_slide_len

    cols_list = [str(col) + '_width_' + str(window_width_hz) for col in middle_freq]
    reduced_cols_list += cols_list

# %%
top_n_col_combos
three_col_combos_list = []
for two_combo in top_n_col_combos:
    for col in reduced_cols_list:
        three_col = two_combo + [col]
        three_col_combos_list.append(three_col)

# %%
three_col_combos_list
# Out:
# [['9.5_width_1', '20.5_width_12', '0.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '1.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '1.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '2.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '2.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '3.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '3.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '4.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '4.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '5.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '5.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '6.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '6.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '7.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '7.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '8.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '8.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '9.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '9.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '10.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '10.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '11.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '11.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '12.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '12.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '13.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '13.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '14.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '14.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '15.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '15.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '16.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '16.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '17.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '17.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '18.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '18.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '19.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '19.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '20.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '20.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '21.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '21.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '22.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '22.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '23.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '23.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '24.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '24.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '25.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '25.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '26.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '26.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '27.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '27.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '28.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '28.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '29.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '29.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '30.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '30.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '31.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '31.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '32.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '32.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '33.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '33.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '34.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '34.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '35.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '35.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '36.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '36.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '37.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '37.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '38.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '38.75_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '39.25_width_0.5'],
#  ['9.5_width_1', '20.5_width_12', '1.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '1.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '2.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '2.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '3.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '3.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '4.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '4.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '5.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '6.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '7.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '8.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '9.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '10.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '11.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '12.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '13.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '14.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '15.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '16.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '17.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '18.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '19.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '20.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '21.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '22.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '23.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '24.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '25.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '26.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '27.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '28.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '29.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '30.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '31.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '32.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '33.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '34.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '35.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '35.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '36.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '36.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '37.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '37.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '38.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '38.5_width_1'],
#  ['9.5_width_1', '20.5_width_12', '39.0_width_1'],
#  ['9.5_width_1', '20.5_width_12', '1.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '2.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '2.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '3.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '3.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '4.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '4.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '5.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '6.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '7.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '8.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '9.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '10.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '11.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '12.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '13.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '14.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '15.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '16.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '17.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '18.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '19.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '20.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '21.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '22.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '23.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '24.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '25.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '26.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '27.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '28.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '29.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '30.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '31.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '32.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '33.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '34.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '35.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '35.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '36.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '36.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '37.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '37.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '38.0_width_2'],
#  ['9.5_width_1', '20.5_width_12', '38.5_width_2'],
#  ['9.5_width_1', '20.5_width_12', '2.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '2.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '3.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '3.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '4.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '4.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '5.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '6.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '7.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '8.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '9.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '10.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '11.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '12.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '13.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '14.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '15.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '16.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '17.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '18.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '19.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '20.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '21.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '22.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '23.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '24.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '25.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '26.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '27.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '28.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '29.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '30.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '31.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '32.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '33.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '34.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '35.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '35.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '36.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '36.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '37.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '37.5_width_3'],
#  ['9.5_width_1', '20.5_width_12', '38.0_width_3'],
#  ['9.5_width_1', '20.5_width_12', '2.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '3.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '3.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '4.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '4.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '5.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '6.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '7.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '8.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '9.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '10.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '11.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '12.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '13.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '14.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '15.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '16.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '17.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '18.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '19.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '20.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '21.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '22.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '23.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '24.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '25.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '26.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '27.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '28.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '29.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '30.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '31.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '32.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '33.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '34.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '35.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '35.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '36.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '36.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '37.0_width_4'],
#  ['9.5_width_1', '20.5_width_12', '37.5_width_4'],
#  ['9.5_width_1', '20.5_width_12', '3.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '4.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '4.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '5.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '6.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '7.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '8.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '9.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '10.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '11.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '12.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '13.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '14.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '15.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '16.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '17.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '18.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '19.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '20.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '21.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '22.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '23.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '24.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '25.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '26.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '27.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '28.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '29.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '30.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '31.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '32.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '33.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '34.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '35.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '35.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '36.0_width_6'],
#  ['9.5_width_1', '20.5_width_12', '36.5_width_6'],
#  ['9.5_width_1', '20.5_width_12', '4.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '5.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '6.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '7.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '8.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '9.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '10.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '11.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '12.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '13.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '14.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '15.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '16.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '17.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '18.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '19.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '20.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '21.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '22.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '23.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '24.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '25.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '26.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '27.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '28.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '29.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '30.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '31.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '32.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '33.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '34.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '35.0_width_8'],
#  ['9.5_width_1', '20.5_width_12', '35.5_width_8'],
#  ['9.5_width_1', '20.5_width_12', '5.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '34.5_width_10'],
#  ['9.5_width_1', '20.5_width_12', '6.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '33.5_width_12'],
#  ['9.5_width_1', '20.5_width_12', '7.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '8.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '9.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '10.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '11.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '12.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '13.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '14.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '15.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '16.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '17.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '18.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '19.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '20.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '21.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '22.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '23.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '24.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '25.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '26.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '27.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '28.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '29.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '30.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '31.5_width_14'],
#  ['9.5_width_1', '20.5_width_12', '32.5_width_14'],
#  ['9.75_width_0.5', '12.5_width_5', '0.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '1.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '1.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '2.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '2.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '3.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '3.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '4.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '4.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '5.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '5.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '6.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '6.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '7.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '7.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '8.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '8.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '9.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '9.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '10.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '10.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '11.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '11.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '12.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '12.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '13.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '13.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '14.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '14.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '15.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '15.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '16.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '16.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '17.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '17.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '18.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '18.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '19.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '19.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '20.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '20.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '21.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '21.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '22.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '22.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '23.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '23.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '24.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '24.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '25.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '25.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '26.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '26.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '27.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '27.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '28.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '28.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '29.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '29.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '30.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '30.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '31.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '31.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '32.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '32.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '33.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '33.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '34.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '34.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '35.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '35.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '36.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '36.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '37.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '37.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '38.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '38.75_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '39.25_width_0.5'],
#  ['9.75_width_0.5', '12.5_width_5', '1.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '1.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '2.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '2.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '3.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '3.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '4.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '4.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '5.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '5.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '6.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '6.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '7.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '7.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '8.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '8.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '9.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '9.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '10.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '10.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '11.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '11.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '12.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '12.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '13.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '13.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '14.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '14.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '15.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '15.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '16.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '16.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '17.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '17.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '18.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '18.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '19.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '19.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '20.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '20.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '21.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '21.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '22.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '22.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '23.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '23.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '24.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '24.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '25.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '25.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '26.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '26.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '27.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '27.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '28.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '28.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '29.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '29.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '30.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '30.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '31.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '31.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '32.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '32.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '33.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '33.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '34.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '34.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '35.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '35.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '36.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '36.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '37.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '37.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '38.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '38.5_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '39.0_width_1'],
#  ['9.75_width_0.5', '12.5_width_5', '1.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '2.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '2.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '3.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '3.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '4.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '4.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '5.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '5.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '6.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '6.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '7.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '7.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '8.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '8.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '9.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '9.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '10.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '10.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '11.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '11.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '12.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '12.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '13.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '13.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '14.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '14.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '15.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '15.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '16.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '16.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '17.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '17.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '18.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '18.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '19.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '19.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '20.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '20.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '21.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '21.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '22.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '22.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '23.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '23.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '24.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '24.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '25.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '25.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '26.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '26.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '27.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '27.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '28.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '28.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '29.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '29.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '30.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '30.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '31.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '31.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '32.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '32.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '33.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '33.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '34.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '34.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '35.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '35.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '36.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '36.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '37.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '37.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '38.0_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '38.5_width_2'],
#  ['9.75_width_0.5', '12.5_width_5', '2.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '2.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '3.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '3.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '4.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '4.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '5.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '5.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '6.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '6.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '7.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '7.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '8.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '8.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '9.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '9.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '10.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '10.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '11.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '11.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '12.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '12.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '13.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '13.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '14.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '14.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '15.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '15.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '16.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '16.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '17.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '17.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '18.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '18.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '19.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '19.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '20.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '20.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '21.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '21.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '22.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '22.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '23.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '23.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '24.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '24.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '25.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '25.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '26.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '26.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '27.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '27.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '28.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '28.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '29.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '29.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '30.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '30.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '31.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '31.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '32.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '32.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '33.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '33.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '34.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '34.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '35.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '35.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '36.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '36.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '37.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '37.5_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '38.0_width_3'],
#  ['9.75_width_0.5', '12.5_width_5', '2.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '3.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '3.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '4.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '4.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '5.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '5.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '6.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '6.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '7.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '7.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '8.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '8.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '9.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '9.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '10.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '10.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '11.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '11.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '12.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '12.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '13.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '13.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '14.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '14.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '15.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '15.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '16.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '16.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '17.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '17.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '18.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '18.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '19.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '19.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '20.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '20.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '21.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '21.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '22.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '22.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '23.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '23.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '24.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '24.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '25.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '25.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '26.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '26.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '27.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '27.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '28.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '28.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '29.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '29.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '30.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '30.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '31.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '31.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '32.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '32.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '33.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '33.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '34.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '34.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '35.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '35.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '36.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '36.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '37.0_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '37.5_width_4'],
#  ['9.75_width_0.5', '12.5_width_5', '3.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '4.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '4.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '5.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '5.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '6.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '6.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '7.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '7.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '8.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '8.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '9.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '9.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '10.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '10.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '11.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '11.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '12.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '12.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '13.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '13.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '14.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '14.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '15.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '15.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '16.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '16.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '17.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '17.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '18.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '18.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '19.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '19.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '20.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '20.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '21.0_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '21.5_width_6'],
#  ['9.75_width_0.5', '12.5_width_5', '22.0_width_6'],
#  ...]
