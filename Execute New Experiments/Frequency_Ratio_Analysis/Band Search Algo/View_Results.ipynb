# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

## Use decision tree as a rough way for splitting based on that feature
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
from sklearn import tree

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
import run_expts

# %%
from constants import regions

# %%
t1 = time.time()

# 1 Data type is defined by script input ______________________________________________________
data_types = ['N2', 'N3','REM', 'Wake', 'N1']
expt_nums = [1,2]

max_scores = []

for data_type in ['N2', 'N3','REM', 'Wake', 'N1']:
    for expt_num in expt_nums:
        for region in regions:
            try:
                # f_name =  'Results/' + data_type + '_expt_' + str(expt_num) + '_scores.pkl'
                f_name =  'Results/' + data_type + '_' + region +  '_expt_' + str(expt_num) + '_scores.pkl'
                scores = joblib.load(f_name)
                max_score = np.array(scores).max()
                max_scores.append( (max_score, f_name) )
            except:
                pass
        # f_name =  'Results/' + data_type + '_expt_' + str(expt_num) + '_col_combos.pkl'
        # coL_combos = joblib.load(f_name)

t2 = time.time()

t2-t1
# Out:
# 188.2818374633789

# %%
max_scores
# Out:
# [(0.8292682926829268, 'Results/N2_Prefrontal_expt_1_scores.pkl'),
#  (0.9024390243902439, 'Results/N2_Frontal_expt_1_scores.pkl'),
#  (0.8780487804878049, 'Results/N2_Left Frontal_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N2_Right Frontal_expt_1_scores.pkl'),
#  (0.8780487804878049, 'Results/N2_Central_expt_1_scores.pkl'),
#  (0.8536585365853658, 'Results/N2_Left Central_expt_1_scores.pkl'),
#  (0.8536585365853658, 'Results/N2_Right Central_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N2_Left Temporal_expt_1_scores.pkl'),
#  (0.8780487804878049, 'Results/N2_Right Temporal_expt_1_scores.pkl'),
#  (0.8536585365853658, 'Results/N2_Parietal_expt_1_scores.pkl'),
#  (0.8780487804878049, 'Results/N2_Left Parietal_expt_1_scores.pkl'),
#  (0.7804878048780488, 'Results/N2_Right Parietal_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N2_Occipital_expt_1_scores.pkl'),
#  (0.8085106382978723, 'Results/N2_Prefrontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N2_Frontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N2_Left Frontal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/N2_Right Frontal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/N2_Central_expt_2_scores.pkl'),
#  (0.8723404255319149, 'Results/N2_Left Central_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N2_Right Central_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N2_Left Temporal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/N2_Right Temporal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N2_Parietal_expt_2_scores.pkl'),
#  (0.8297872340425532, 'Results/N2_Left Parietal_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/N2_Right Parietal_expt_2_scores.pkl'),
#  (0.8292682926829268, 'Results/N3_Prefrontal_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N3_Frontal_expt_1_scores.pkl'),
#  (0.8048780487804879, 'Results/N3_Left Frontal_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N3_Right Frontal_expt_1_scores.pkl'),
#  (0.8536585365853658, 'Results/N3_Central_expt_1_scores.pkl'),
#  (0.7804878048780488, 'Results/N3_Left Central_expt_1_scores.pkl'),
#  (0.7804878048780488, 'Results/N3_Right Central_expt_1_scores.pkl'),
#  (0.7804878048780488, 'Results/N3_Left Temporal_expt_1_scores.pkl'),
#  (0.8048780487804879, 'Results/N3_Right Temporal_expt_1_scores.pkl'),
#  (0.8048780487804879, 'Results/N3_Parietal_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N3_Left Parietal_expt_1_scores.pkl'),
#  (0.7804878048780488, 'Results/N3_Right Parietal_expt_1_scores.pkl'),
#  (0.8292682926829268, 'Results/N3_Occipital_expt_1_scores.pkl'),
#  (0.7708333333333334, 'Results/N3_Prefrontal_expt_2_scores.pkl'),
#  (0.7708333333333334, 'Results/N3_Frontal_expt_2_scores.pkl'),
#  (0.75, 'Results/N3_Left Frontal_expt_2_scores.pkl'),
#  (0.75, 'Results/N3_Right Frontal_expt_2_scores.pkl'),
#  (0.8125, 'Results/N3_Central_expt_2_scores.pkl'),
#  (0.7916666666666666, 'Results/N3_Left Central_expt_2_scores.pkl'),
#  (0.7708333333333334, 'Results/N3_Right Central_expt_2_scores.pkl'),
#  (0.7916666666666666, 'Results/N3_Left Temporal_expt_2_scores.pkl'),
#  (0.75, 'Results/N3_Right Temporal_expt_2_scores.pkl'),
#  (0.7708333333333334, 'Results/N3_Parietal_expt_2_scores.pkl'),
#  (0.75, 'Results/N3_Left Parietal_expt_2_scores.pkl'),
#  (0.7708333333333334, 'Results/N3_Right Parietal_expt_2_scores.pkl'),
#  (0.85, 'Results/REM_Prefrontal_expt_1_scores.pkl'),
#  (0.825, 'Results/REM_Frontal_expt_1_scores.pkl'),
#  (0.8, 'Results/REM_Left Frontal_expt_1_scores.pkl'),
#  (0.825, 'Results/REM_Right Frontal_expt_1_scores.pkl'),
#  (0.875, 'Results/REM_Central_expt_1_scores.pkl'),
#  (0.85, 'Results/REM_Left Central_expt_1_scores.pkl'),
#  (0.825, 'Results/REM_Right Central_expt_1_scores.pkl'),
#  (0.825, 'Results/REM_Left Temporal_expt_1_scores.pkl'),
#  (0.8, 'Results/REM_Right Temporal_expt_1_scores.pkl'),
#  (0.85, 'Results/REM_Parietal_expt_1_scores.pkl'),
#  (0.825, 'Results/REM_Left Parietal_expt_1_scores.pkl'),
#  (0.825, 'Results/REM_Right Parietal_expt_1_scores.pkl'),
#  (0.8, 'Results/REM_Occipital_expt_1_scores.pkl'),
#  (0.8297872340425532, 'Results/REM_Prefrontal_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/REM_Frontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/REM_Left Frontal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/REM_Right Frontal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/REM_Central_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/REM_Left Central_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/REM_Right Central_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/REM_Left Temporal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/REM_Right Temporal_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/REM_Parietal_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/REM_Left Parietal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/REM_Right Parietal_expt_2_scores.pkl'),
#  (0.8666666666666667, 'Results/Wake_Prefrontal_expt_1_scores.pkl'),
#  (0.8333333333333334, 'Results/Wake_Frontal_expt_1_scores.pkl'),
#  (0.9, 'Results/Wake_Left Frontal_expt_1_scores.pkl'),
#  (0.8666666666666667, 'Results/Wake_Right Frontal_expt_1_scores.pkl'),
#  (0.8666666666666667, 'Results/Wake_Central_expt_1_scores.pkl'),
#  (0.8333333333333334, 'Results/Wake_Left Central_expt_1_scores.pkl'),
#  (0.8666666666666667, 'Results/Wake_Right Central_expt_1_scores.pkl'),
#  (0.9, 'Results/Wake_Left Temporal_expt_1_scores.pkl'),
#  (0.8666666666666667, 'Results/Wake_Right Temporal_expt_1_scores.pkl'),
#  (0.8666666666666667, 'Results/Wake_Parietal_expt_1_scores.pkl'),
#  (0.8, 'Results/Wake_Left Parietal_expt_1_scores.pkl'),
#  (0.8333333333333334, 'Results/Wake_Right Parietal_expt_1_scores.pkl'),
#  (0.8333333333333334, 'Results/Wake_Occipital_expt_1_scores.pkl'),
#  (0.868421052631579, 'Results/Wake_Prefrontal_expt_2_scores.pkl'),
#  (0.8421052631578947, 'Results/Wake_Frontal_expt_2_scores.pkl'),
#  (0.868421052631579, 'Results/Wake_Left Frontal_expt_2_scores.pkl'),
#  (0.8421052631578947, 'Results/Wake_Right Frontal_expt_2_scores.pkl'),
#  (0.7631578947368421, 'Results/Wake_Central_expt_2_scores.pkl'),
#  (0.7631578947368421, 'Results/Wake_Left Central_expt_2_scores.pkl'),
#  (0.8157894736842105, 'Results/Wake_Right Central_expt_2_scores.pkl'),
#  (0.8157894736842105, 'Results/Wake_Left Temporal_expt_2_scores.pkl'),
#  (0.8157894736842105, 'Results/Wake_Right Temporal_expt_2_scores.pkl'),
#  (0.7894736842105263, 'Results/Wake_Parietal_expt_2_scores.pkl'),
#  (0.7631578947368421, 'Results/Wake_Left Parietal_expt_2_scores.pkl'),
#  (0.7894736842105263, 'Results/Wake_Right Parietal_expt_2_scores.pkl'),
#  (0.8, 'Results/N1_Prefrontal_expt_1_scores.pkl'),
#  (0.85, 'Results/N1_Frontal_expt_1_scores.pkl'),
#  (0.85, 'Results/N1_Left Frontal_expt_1_scores.pkl'),
#  (0.875, 'Results/N1_Right Frontal_expt_1_scores.pkl'),
#  (0.875, 'Results/N1_Central_expt_1_scores.pkl'),
#  (0.85, 'Results/N1_Left Central_expt_1_scores.pkl'),
#  (0.825, 'Results/N1_Right Central_expt_1_scores.pkl'),
#  (0.85, 'Results/N1_Left Temporal_expt_1_scores.pkl'),
#  (0.825, 'Results/N1_Right Temporal_expt_1_scores.pkl'),
#  (0.825, 'Results/N1_Parietal_expt_1_scores.pkl'),
#  (0.85, 'Results/N1_Left Parietal_expt_1_scores.pkl'),
#  (0.85, 'Results/N1_Right Parietal_expt_1_scores.pkl'),
#  (0.825, 'Results/N1_Occipital_expt_1_scores.pkl'),
#  (0.8085106382978723, 'Results/N1_Prefrontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N1_Frontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N1_Left Frontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N1_Right Frontal_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N1_Central_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N1_Left Central_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/N1_Right Central_expt_2_scores.pkl'),
#  (0.7872340425531915, 'Results/N1_Left Temporal_expt_2_scores.pkl'),
#  (0.7659574468085106, 'Results/N1_Right Temporal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/N1_Parietal_expt_2_scores.pkl'),
#  (0.8297872340425532, 'Results/N1_Left Parietal_expt_2_scores.pkl'),
#  (0.8085106382978723, 'Results/N1_Right Parietal_expt_2_scores.pkl')]

# %% [markdown]
# ### Load selected scores

# %%
filter_val = 0.87
f_name =  'Results/' + 'N2' + '_Left Central' + '_expt_' + str(2) + '_col_combos.pkl'
coL_combos = joblib.load(f_name)
col_combos_filtered = [list(val) for val in  np.array(coL_combos)[np.array(scores) > filter_val] ]
print( len(col_combos_filtered ))
scores = joblib.load('Results/N2_Frontal_expt_1_scores.pkl')
scores_filtered = np.array(scores)[np.array(scores) > filter_val]
# Out:
# 38

# %%
scores_filtered
# Out:
# array([0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.90243902, 0.87804878, 0.87804878, 0.90243902,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878])

# %%
scores_filtered
# Out:
# array([0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.90243902, 0.87804878, 0.87804878, 0.90243902,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878, 0.87804878, 0.87804878,
#        0.87804878, 0.87804878, 0.87804878])

# %%
y = s_class_list.map({'HC': 0 , 'PD' : 1 , 'PD+RBD' : 2 , 'RBD' : 3})

# %%
num_to_class = {0 : 'HC', 1 : 'PD',  2 : 'PD+RBD', 3 : 'RBD'}

# %%
y_expt.map(num_to_class).values
# Out:
# array(['HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC',
#        'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC', 'HC',
#        'HC', 'HC', 'HC', 'HC', 'PD', 'PD', 'PD', 'PD', 'PD', 'PD', 'PD',
#        'PD', 'PD', 'PD', 'PD', 'PD', 'PD', 'PD', 'PD'], dtype=object)

# %% [markdown]
# ### Load the PSD and calculate the features to then plot them

# %%
expt_num = 2
data_type = 'N2'
df = joblib.load(os.path.join(os.path.abspath('..'), data_type + '_psd_normalised_data.pkl') )

single_region_df = df[[col for col in df.columns if col.endswith('_Left Central')]]
frequency_vals  = np.arange(0.5,40.125, 0.125)
single_region_df.columns = frequency_vals

folder = '/user/home/ko20929/work/RBD_using_custom_package/Blue_pebble/'
paths = joblib.load(folder + data_type + '_paths.pkl')

groups = pd.Series(paths['s_p_id'])
s_class_list = pd.Series(paths['s_class_list'])
y = s_class_list.map({'HC': 0 , 'PD' : 1 , 'PD+RBD' : 2 , 'RBD' : 3})

# %%
width_slide_list = [(0.5,0.5)] 
for window_width in range(1, 15 ):
    width_slide_list.append((window_width, 0.5) )

# %%
t3 = time.time()

results_dfs = []
feature_dfs = []

j = 0 #counter to populate feature dict dataframes

for window_width_hz, window_slide_hz in width_slide_list:
    description = 'window width : ' + str(window_width_hz) + ' .  window stride : ' + str(window_slide_hz)
    
    #1.Set Window width in Hz and Window Slide in Hz
    # window_width_hz = 3
    window_len = (window_width_hz/0.125)+1
    assert window_len%1 == 0
    window_len = int(window_len)
    
    # window_slide_hz = 0.5 
    window_slide_len = window_slide_hz/0.125 
    assert window_slide_len%1 == 0
    window_slide_len = int(window_slide_len)
    
    
    #2.Calculate band values and store in dataframe calculated_df
    
    # Start of the window is the middle_freq value minus window_width_hz/2 
    # End of the window is the middle freq value plus window_width_hz/2
    window_len
    
    middle_freq = []
    final_cols = []
    
    i = 0
    while i < len(frequency_vals) - window_len:
        middle_freq.append( frequency_vals[i:i+window_len].mean() )
        band_vals = single_region_df.iloc[:,i:i+window_len].mean(axis = 1) #For every row calculate the mean for the appropriate elements
        
        final_cols.append(band_vals)
        
        # scaled_psd.append( psd_values[i:i+factor].mean() )
        i+= window_slide_len
    
    calculated_df = pd.DataFrame(final_cols).T
    calculated_df.columns = middle_freq
    
    calculated_df.columns = [ str(col) + '_width_' + str(window_width_hz) for col in calculated_df.columns]
    
    
    #3.Calculate Information Gain Based on Features
    #Change to binary HC vs PD / PD+RBD ---> Generate expt specific X,y,groups 
    
    X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(calculated_df,y,groups,expt_num)

    feature_dfs.append(X_expt)

X_expt_concatenated = pd.concat(feature_dfs, axis=1)

t4 = time.time()
t4-t3
# Out:
# 0.5178713798522949

# %%
X_expt_concatenated
# Out:
#     0.75_width_0.5  1.25_width_0.5  1.75_width_0.5  2.25_width_0.5  \
# 0         0.039390        0.025381        0.018745        0.015583
# 1         0.043759        0.027398        0.018841        0.015608
# 2         0.050165        0.030628        0.024384        0.019865
# 3         0.047235        0.029417        0.019599        0.014019
# 4         0.044981        0.033232        0.021720        0.015164
# 5         0.048537        0.030094        0.020110        0.014347
# 61       0.000103       0.000101       0.000099       0.000097       0.000095
# 62       0.000219       0.000212       0.000205       0.000198       0.000191
# 63       0.000109       0.000103       0.000097       0.000092       0.000087
# 64       0.000092       0.000087       0.000082       0.000077       0.000071
# 65       0.000135       0.000128       0.000122       0.000116       0.000111
# 66       0.000205       0.000194       0.000183       0.000173       0.000164
# 67       0.000082       0.000080       0.000077       0.000075       0.000073
# 68       0.000382       0.000367       0.000352       0.000337       0.000322
# 69       0.000332       0.000320       0.000307       0.000295       0.000282
# 70       0.000053       0.000051       0.000049       0.000047       0.000045
#
#     31.5_width_14  32.0_width_14  32.5_width_14
# 0        0.000273       0.000266       0.000260
# 1        0.000244       0.000239       0.000234
# 2        0.000060       0.000058       0.000055
# 3        0.000087       0.000082       0.000078
# 4        0.000064       0.000060       0.000057
# 5        0.000172       0.000161       0.000150
# 6        0.000089       0.000084       0.000079
# 7        0.000095       0.000090       0.000086
# 8        0.000106       0.000101       0.000095
# 9        0.000118       0.000114       0.000110
# 10       0.000083       0.000081       0.000078
# 11       0.000214       0.000207       0.000201
# 12       0.000204       0.000199       0.000193
# 13       0.000098       0.000093       0.000089
# 14       0.000092       0.000087       0.000082
# 15       0.000117       0.000112       0.000107
# 16       0.000095       0.000092       0.000089
# 17       0.000258       0.000242       0.000227
# 18       0.000127       0.000122       0.000118
# 19       0.000125       0.000121       0.000117
# 20       0.000072       0.000068       0.000065
# 21       0.000077       0.000073       0.000069
# 22       0.000147       0.000138       0.000130
# 23       0.000118       0.000114       0.000111
# 24       0.000104       0.000099       0.000095
# 25       0.000100       0.000094       0.000089
# 50       0.000125       0.000117       0.000109
# 51       0.000148       0.000138       0.000129
# 52       0.000056       0.000053       0.000051
# 53       0.000195       0.000188       0.000181
# 54       0.000158       0.000151       0.000145
# 55       0.000057       0.000054       0.000052
# 56       0.000207       0.000197       0.000188
# 57       0.000259       0.000245       0.000232
# 58       0.000091       0.000085       0.000080
# 59       0.000208       0.000196       0.000185
# 60       0.000159       0.000149       0.000141
# 61       0.000093       0.000091       0.000089
# 62       0.000185       0.000178       0.000172
# 63       0.000083       0.000079       0.000075
# 64       0.000068       0.000064       0.000060
# 65       0.000105       0.000101       0.000096
# 66       0.000155       0.000147       0.000139
# 67       0.000071       0.000069       0.000068
# 68       0.000309       0.000296       0.000283
# 69       0.000271       0.000261       0.000250
# 70       0.000043       0.000042       0.000040
#
# [47 rows x 974 columns]

# %% [markdown]
# ### Scatter plot features with the best scores

# %%
fig = plt.figure()
fig = plt.figure(figsize=(20,50),dpi=200)

for num in range(33):
    ax = fig.add_subplot(11,3,num+1)
    plt.scatter(X_expt_concatenated[col_combos_filtered[num][0]], X_expt_concatenated[col_combos_filtered[num][1]] , c = y_expt.values ) #label = y_expt.map(num_to_class).values  )
    plt.xlabel(col_combos_filtered[num][0],)
    plt.ylabel(col_combos_filtered[num][1])
    plt.grid()
    plt.tight_layout()

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 30-Jan-24 15:49:16 | WARNING | No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
