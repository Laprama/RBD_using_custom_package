# %%
from IPython.utils import io
import pandas as pd
import os
from pathlib import Path
from matplotlib import pyplot as plt
from scipy.signal import find_peaks
import numpy as np
import seaborn as sns
import time
import joblib
from os.path import exists
import shutil
import sys
import time

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
    
#From my EEG package 
import run_expts
import constants


#Let me see as many results as I want to see
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 20)

# %%
groups
# Out:
#     Fp1_DN_HistogramMode_5  Fp1_DN_HistogramMode_10  \
# 0                 6.431152                 1.981088
# 1                 5.847820                 2.878111
# 2               -23.120010               -12.296121
# 3                14.227444                 4.553551
# 4                -1.094439                 5.852149
# ..                     ...                      ...
# 51                5.696133                 2.390115
# 52               -0.609127                 2.654985
# 53                3.729443                -0.829666
# 54                5.556511                -9.560163
# 55              -10.288067                -4.327383
#
#     Fp1_SB_BinaryStats_diff_longstretch0  Fp1_DN_OutlierInclude_p_001_mdrmd  \
# 0                                   79.0                          -0.000922
# 1                                  107.0                          -0.043178
# 2                                  284.0                          -0.030010
# 3                                  204.0                           0.081484
# 4                                  169.0                           0.107227
# ..                                   ...                                ...
# 51                                 159.0                          -0.149564
# 52                                  95.0                           0.091518
# 53                                 152.0                          -0.190927
# 54                                 185.0                           0.231823
# 55                                  97.0                           0.109270
#
#     Fp1_DN_OutlierInclude_n_001_mdrmd  Fp1_CO_f1ecac  Fp1_CO_FirstMin_ac  \
# 0                           -0.000043            6.0                16.0
# 1                           -0.044650            8.0                18.0
# 2                           -0.139355           29.0               122.0
# 3                            0.099961           37.0                14.0
# 4                            0.072331           31.0                16.0
# ..                                ...            ...                 ...
# 51                          -0.124264            6.0                14.0
# 52                           0.084738            5.0                 5.0
# 53                          -0.143537            7.0                15.0
# 54                           0.201816            4.0                 4.0
# 55                           0.067864            3.0                 4.0
#
#     Fp1_SP_Summaries_welch_rect_area_5_1  \
# 0                              63.775317
# 1                              31.813945
# 2                             530.420328
# 3                             222.429637
# 4                              76.085271
# ..                                   ...
# 51                             47.237489
# 52                             42.100568
# 53                             72.617439
# 54                             93.754766
# 55                             85.929612
#
#     Fp1_SP_Summaries_welch_rect_centroid  Fp1_FC_LocalSimple_mean3_stderr  \
# 0                               0.188009                         7.022472
# 1                               0.171614                         2.524346
# 2                               0.032885                         5.888387
# 3                               0.020133                         4.486776
# 4                               0.049471                         4.402563
# ..                                   ...                              ...
# 51                              0.235993                         3.932522
# 52                              0.239349                         4.780232
# 53                              0.197884                         4.308705
# 54                              0.068358                         8.514457
# 55                              0.516760                        11.227330
#
#     ...  Oz_SB_BinaryStats_mean_longstretch1  Oz_SB_MotifThree_quantile_hh  \
# 0   ...                                 13.0                      1.947563
# 1   ...                                 24.0                      1.662810
# 2   ...                                 23.0                      1.557094
# 3   ...                                 20.0                      1.681230
# 4   ...                                 18.0                      1.894260
# ..  ...                                  ...                           ...
# 51  ...                                 21.0                      1.726625
# 52  ...                                 20.0                      1.780693
# 53  ...                                 21.0                      1.642674
# 54  ...                                 20.0                      1.799573
# 55  ...                                 23.0                      1.768540
#
#     Oz_FC_LocalSimple_mean1_tauresrat  \
# 0                            0.111111
# 1                            0.272727
# 2                            0.102564
# 3                            0.375000
# 4                            0.666667
# ..                                ...
# 51                           0.428571
# 52                           0.375000
# 53                           0.571429
# 54                           0.200000
# 55                           0.214286
#
#     Oz_CO_Embed2_Dist_tau_d_expfit_meandiff  \
# 0                                  0.019322
# 1                                  0.065149
# 2                                  0.045291
# 3                                  0.041792
# 4                                  0.009321
# ..                                      ...
# 51                                 0.042341
# 52                                 0.032510
# 53                                 0.039004
# 54                                 0.026589
# 55                                 0.032536
#
#     Oz_SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1  \
# 0                                        0.46
# 1                                        0.46
# 2                                        0.44
# 3                                        0.54
# 4                                        0.52
# ..                                        ...
# 51                                       0.46
# 52                                       0.48
# 53                                       0.48
# 54                                       0.42
# 55                                       0.44
#
#     Oz_SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1  \
# 0                                             0.24
# 1                                             0.24
# 2                                             0.48
# 3                                             0.18
# 4                                             0.54
# ..                                             ...
# 51                                            0.20
# 52                                            0.50
# 53                                            0.20
# 54                                            0.44
# 55                                            0.46
#
#     Oz_SB_TransitionMatrix_3ac_sumdiagcov  Oz_PD_PeriodicityWang_th0_01  \
# 0                                0.000243                          29.0
# 1                                0.000195                          35.0
# 2                                0.000152                          25.0
# 3                                0.000293                          25.0
# 4                                0.000145                           6.0
# ..                                    ...                           ...
# 51                               0.000087                          25.0
# 52                               0.000167                          24.0
# 53                               0.000287                          26.0
# 54                               0.000180                           6.0
# 55                               0.000061                           6.0
#
#     Oz_StandardDeviation   Oz_Mean
# 0               8.920532  0.005542
# 1               6.614500 -0.001662
# 2              10.656027  0.011851
# 3               8.777325  0.004510
# 4              11.135686  0.009649
# ..                   ...       ...
# 51              9.399973 -0.000901
# 52              9.467021  0.000678
# 53              9.344512  0.001569
# 54              9.581137  0.020620
# 55              8.813626 -0.002328
#
# [56 rows x 1368 columns]

# %%
#This path also has Wakeful data in it
load_path = '/export/sphere/ebirah/ko20929/RBD_using_custom_package/Execute New Experiments/Catch_22_features/'

data_types =  ['Wake', 'N1' , 'REM']
dtype = data_types[0]

X = pd.read_hdf(load_path + dtype +  '_c_22_feautures.h5', key='df', mode='r')
y = pd.read_hdf(load_path + dtype +  '_y.h5', key='df', mode='r') 
groups = pd.read_hdf(load_path + dtype +  '_groups.h5', key='df', mode='r')

#1.Generate expt specific X,y,groups
# X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, 1 )

# %%
# This code generates a region to features dictionary - this will enable us to run expts regionally as before
regional_features_dict = {}

region_channel_dict = constants.region_to_channel_dict

for region, region_channels in region_channel_dict.items():
    region_features = []
    for channel in region_channels:
        region_features += [feature for feature in X_expt.columns if  feature.startswith(channel) ]
    regional_features_dict[region] = region_features

#Default subsets dictionary ---> run_expts.gen_subsets_dict()

#New subsets dictionary ---> regional_features_dict

# %%
t1 = time.time()
results_df = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt, {'RF' : RandomForestClassifier()} , return_df = True , subset_names_and_cols = regional_features_dict, random_states = [1,2] )
t2 = time.time()
t2 - t1
# Out:
# 18.911641359329224

# %%
results_df
res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)   
res_df[[col for col in res_df.columns if 'acc' in col]]
# Out:
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0               0.50           0.575                0.400
# 1               0.55           0.650                0.575
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0                 0.550           0.525                0.675
# 1                 0.675           0.525                0.625
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0                 0.625                 0.525                  0.475
# 1                 0.600                 0.700                  0.625
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0             0.65                 0.600                  0.550
# 1             0.65                 0.575                  0.575
#
#    Occipital_RF_acc
# 0             0.625
# 1             0.575

# %%
regions = constants.regions

t0 = time.time()
for region in regions:
    X_subset = X_expt[regional_features_dict[region]]
    X_train, X_test, y_train, y_test = train_test_split(X_subset , y_expt, test_size=0.2)

    clf = RandomForestClassifier()

    t1 = time.time()

    clf.fit(X_train, y_train)
    y_preds = clf.predict(X_test)

    acc = accuracy_score(y_preds , y_test )

    t2 = time.time()
    
    print(region)
    print(t2-t1)
    print(acc)
    
t3 = time.time()

print(t3-t0)
# Out:
# Prefrontal
# 0.2577075958251953
# 0.875
# Frontal
# 0.31958532333374023
# 0.25
# Left Frontal
# 0.1328744888305664
# 0.5
# Right Frontal
# 0.13219594955444336
# 0.625
# Central
# 0.14075016975402832
# 0.625
# Left Central
# 0.13478422164916992
# 0.625
# Right Central
# 0.13546109199523926
# 0.875
# Left Temporal
# 0.14210224151611328
# 0.625
# Right Temporal
# 0.2317802906036377
# 0.625
# Parietal
# 0.14610004425048828
# 0.625
# Left Parietal
# 0.13360881805419922
# 0.75
# Right Parietal
# 0.1640770435333252
# 0.75
# Occipital
# 0.13273358345031738
# 0.75
# 2.2350594997406006
