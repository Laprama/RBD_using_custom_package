# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
import run_expts

#TS Fresh Parameter Settings
from tsfresh.feature_extraction import ComprehensiveFCParameters
from tsfresh.feature_extraction import MinimalFCParameters
from tsfresh.feature_extraction import EfficientFCParameters
from tsfresh.feature_extraction import extract_features

# Set display options to show all rows and columns
pd.set_option('display.max_rows', 50)  # Show rows
pd.set_option('display.max_columns', 160)  # Show columns

# %%
#Settings for the script will be 
#Data type 
data_types = ['Wake','N1', 'N2', 'N3', 'REM']
#power_bands to use 
['delta' , 'theta' , 'alpha', 'sigma', 'beta', 'gamma' , 'all of them']
#TS Fresh Settings - Minimal vs Efficient Features -----> efficient is huege no. of feats 777*(7+8) vs 
#Minimal which is 10*(7+8)
#Default will be minimal BPW +
# Out:
# ['delta', 'theta', 'alpha', 'sigma', 'beta', 'gamma', 'all of them']

# %%
data_type = 'REM'

# %%
power_bands = {'delta' : (0.5,4) , 'theta' : (4,8) , 'alpha' : (8,12) , 'sigma' : (12,16) , 'beta' : (16,30) , 'gamma' : (30,40) }
power_band_names = [val for val in power_bands.keys()]
folder = '/user/home/ko20929/work/RBD_using_custom_package/Blue_pebble/Connectivity/'
X = pd.read_hdf(folder + data_type+ '_coherence_df.h5')
X = X.reset_index(drop = True)

# %%
X = X[[col for col in X.columns if 'alpha' in col]]

# %%
list(X.columns)
# Out:
# ['alpha_Fp1_Fpz',
#  'alpha_Fp1_Fp2',
#  'alpha_Fp1_F1',
#  'alpha_Fp1_Fz',
#  'alpha_Fp1_F2',
#  'alpha_Fp1_AF7',
#  'alpha_Fp1_F7',
#  'alpha_Fp1_F5',
#  'alpha_Fp1_F3',
#  'alpha_Fp1_AF8',
#  'alpha_Fp1_F8',
#  'alpha_Fp1_F6',
#  'alpha_Fp1_F4',
#  'alpha_Fp1_FCz',
#  'alpha_Fp1_FC1',
#  'alpha_Fp1_FC2',
#  'alpha_Fp1_Cz',
#  'alpha_Fp1_C1',
#  'alpha_Fp1_C2',
#  'alpha_Fp1_CP1',
#  'alpha_Fp1_CP2',
#  'alpha_Fp1_FC5',
#  'alpha_Fp1_FC3',
#  'alpha_Fp1_C5',
#  'alpha_Fp1_C3',
#  'alpha_Fp1_CP5',
#  'alpha_Fp1_CP3',
#  'alpha_Fp1_FC6',
#  'alpha_Fp1_FC4',
#  'alpha_Fp1_C6',
#  'alpha_Fp1_C4',
#  'alpha_Fp1_CP6',
#  'alpha_Fp1_CP4',
#  'alpha_Fp1_TP7',
#  'alpha_Fp1_T7',
#  'alpha_Fp1_FT7',
#  'alpha_Fp1_FT9',
#  'alpha_Fp1_TP8',
#  'alpha_Fp1_T8',
#  'alpha_Fp1_FT8',
#  'alpha_Fp1_FT10',
#  'alpha_Fp1_P1',
#  'alpha_Fp1_P2',
#  'alpha_Fp1_Pz',
#  'alpha_Fp1_P3',
#  'alpha_Fp1_P5',
#  'alpha_Fp1_P7',
#  'alpha_Fp1_PO7',
#  'alpha_Fp1_P4',
#  'alpha_Fp1_P6',
#  'alpha_Fp1_P8',
# ...
