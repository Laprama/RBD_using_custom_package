# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GroupShuffleSplit


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
import run_expts

# Set display options to show all rows and columns
pd.set_option('display.max_rows', 50)  # Show rows
pd.set_option('display.max_columns', 160)  # Show columns
# Out:
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/antropy/fractal.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit((types.Array(types.float64, 1, "C", readonly=True), types.int32))
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package yasa is out of date. Your version is 0.6.3, the latest is 0.6.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# #### Loading band power and max frequencies data

# %%
# This is 195 features for the entire brain per data type .... without breaking into regions so I think it's fine to use all of the data in one go

# %%
load_path_bpw = '/user/home/ko20929/work/RBD_using_custom_package/Data/freq_6_second_files/'
load_path_max_freqs = '/user/home/ko20929/work/RBD_using_custom_package/Execute New Experiments/Baseline_Extensions/Gen_New_Features/generated_feats/'

data_types = ['Wake','N1', 'N2', 'N3', 'REM']
loaded_data = {}

for data_type in data_types:
    X_y_groups = {}
    
    X_bpw = pd.read_hdf(load_path_bpw + data_type +  'six_second_freq_df.h5', key='df', mode='r')
    y = pd.read_hdf(load_path_bpw + data_type +  '_y.h5', key='df', mode='r') 
    groups = pd.read_hdf(load_path_bpw + data_type +  '_groups.h5', key='df', mode='r')
    X_bpw, y , groups = X_bpw.reset_index(drop = True) , y.reset_index(drop = True) , groups.reset_index(drop = True)
    
    X_max_freqs = pd.read_hdf(load_path_max_freqs + data_type +  'six_second_max_freq_stats_df.h5', key='df', mode='r')
    X_max_freqs = X_max_freqs.reset_index(drop = True)

    X = pd.concat([X_bpw , X_max_freqs], axis = 1)

    # Replace time sereis data with mean of the data ______________________________________________________________________________________________________

    # Defining a function to replace time series of values with their mean
    def function(x):
        return x.values.mean()
        
    #Construct the static features
    static_features_df = X.apply(np.vectorize(function))
    X = static_features_df.copy()

    X_y_groups['X'] = X
    X_y_groups['y'] = y
    X_y_groups['groups'] = groups
    
    loaded_data[data_type] = X_y_groups

# %%
loaded_data.keys()
# Out:
# dict_keys(['Wake', 'N1', 'N2', 'N3', 'REM'])

# %%
loaded_data['Wake']['X']
# Out:
#     Delta_Central  Theta_Central  Alpha_Central  Sigma_Central  Beta_Central  \
# 0        0.133839       0.349842       0.223800       0.112196      0.152331
# 1        0.209880       0.564024       0.105579       0.052171      0.060141
# 2        0.303676       0.188532       0.310088       0.056726      0.124494
# 3        0.166427       0.086765       0.472722       0.080898      0.181904
# 4        0.171234       0.094046       0.259718       0.152456      0.290218
# ..            ...            ...            ...            ...           ...
# 51       0.211913       0.084482       0.431411       0.050837      0.180203
# 52       0.304466       0.097360       0.306815       0.054801      0.179928
# 53       0.145509       0.111105       0.260159       0.133603      0.331871
# 54       0.319096       0.357313       0.188012       0.056639      0.063409
# 55       0.337297       0.392561       0.135687       0.056704      0.060928
# 55              0.262259              0.336223              0.148751  ...
#
#     First_Max_Value_Left Frontal  First_Max_Freq_Left Frontal  \
# 0                       0.062604                     6.668750
# 1                       0.172114                     7.099185
# 2                       0.157881                     2.242424
# 3                       0.200826                     8.019531
# 4                       0.073791                     7.175000
# ..                           ...                          ...
# 51                      0.156177                     7.561047
# 52                      0.114775                     6.144022
# 53                      0.127812                     8.861111
# 54                      0.086333                     4.176250
# 55                      0.095260                     2.928779
#
#     Second_Max_Value_Left Frontal  Second_Max_Freq_Left Frontal  \
# 0                        0.046442                      7.333333
# 1                        0.123900                      7.073370
# 2                        0.098969                      2.634470
# 3                        0.148779                      7.898438
# 4                        0.057728                      7.837500
# ..                            ...                           ...
# 51                       0.107756                      7.231105
# 52                       0.087362                      6.491848
# 53                       0.081845                      8.753472
# 54                       0.063262                      4.921250
# 55                       0.066106                      3.494186
#
#     Third_Max_Value_Left Frontal  Third_Max_Freq_Left Frontal  \
# 0                       0.034497                     7.700000
# 1                       0.079931                     6.736413
# 2                       0.073916                     2.810606
# 3                       0.091818                     8.339844
# 4                       0.045313                     8.485417
# ..                           ...                          ...
# 51                      0.075345                     7.008721
# 52                      0.060053                     5.392663
# 53                      0.058281                     9.026042
# 54                      0.049863                     5.152500
# 55                      0.049300                     3.500000
#
#     Fourth_Max_Value_Left Frontal  Fourth_Max_Freq_Left Frontal  \
# 0                        0.027875                      7.508333
# 1                        0.059835                      6.040761
# 2                        0.058688                      3.395833
# 3                        0.061279                      8.484375
# 4                        0.036434                      8.458333
# ..                            ...                           ...
# 51                       0.053212                      6.909884
# 52                       0.047377                      5.574728
# 53                       0.041966                      9.309028
# 54                       0.042130                      5.972500
# 55                       0.039703                      4.257267
#
#     First_Max_Value_Left Parietal  First_Max_Freq_Left Parietal  \
# 0                        0.097826                      8.204167
# 1                        0.244304                      7.207880
# 2                        0.089932                      4.810606
# 3                        0.216102                      9.503906
# 4                        0.058037                     10.116667
# ..                            ...                           ...
# 51                       0.186076                      9.723837
# 52                       0.134701                      8.679348
# 53                       0.130294                      9.595486
# 54                       0.066731                      6.572500
# 55                       0.063279                      5.918605
#
#     Second_Max_Value_Left Parietal  Second_Max_Freq_Left Parietal  \
# 0                         0.074119                       8.197917
# 1                         0.166080                       7.220109
# 2                         0.064502                       5.662879
# 3                         0.152440                       9.507812
# 4                         0.041451                      10.056250
# ..                             ...                            ...
# 51                        0.133102                       9.840116
# 52                        0.101768                       9.343750
# 53                        0.091524                       9.446181
# 54                        0.049572                       7.276250
# 55                        0.049166                       6.745640
#
#     Third_Max_Value_Left Parietal  Third_Max_Freq_Left Parietal  \
# 0                        0.055237                      8.379167
# 1                        0.112787                      7.133152
# 2                        0.051307                      5.795455
# 3                        0.089398                      9.500000
# 4                        0.033262                     10.556250
# ..                            ...                           ...
# 51                       0.092021                      9.870640
# 52                       0.075097                      9.381793
# 53                       0.063065                     10.092014
# 54                       0.040952                      7.217500
# 55                       0.040969                      6.595930
#
#     Fourth_Max_Value_Left Parietal  Fourth_Max_Freq_Left Parietal  \
# 0                         0.047772                       8.635417
# 1                         0.076274                       6.918478
# 2                         0.043614                       6.433712
# 3                         0.058109                       9.292969
# 4                         0.028345                      11.102083
# ..                             ...                            ...
# 51                        0.064288                       9.904070
# 52                        0.056160                       9.698370
# 53                        0.046344                       9.817708
# 54                        0.035930                       7.636250
# 55                        0.035086                       6.526163
#
#     First_Max_Value_Left Temporal  First_Max_Freq_Left Temporal  \
# 0                        0.079548                      6.306250
# 1                        0.130278                      7.077446
# 2                        0.094408                      3.736742
# 3                        0.132600                      8.578125
# 4                        0.035811                     18.164583
# ..                            ...                           ...
# 51                       0.140140                      9.005814
# 52                       0.100394                      7.504076
# 53                       0.104572                      9.645833
# 54                       0.082681                      4.106250
# 55                       0.065555                      5.159884
#
#     Second_Max_Value_Left Temporal  Second_Max_Freq_Left Temporal  \
# 0                         0.061548                       6.179167
# 1                         0.094023                       7.052989
# 2                         0.067766                       4.255682
# 3                         0.098263                       8.984375
# 4                         0.028749                      19.527083
# ..                             ...                            ...
# 51                        0.099880                       8.719477
# 52                        0.074402                       7.373641
# 53                        0.067928                       9.840278
# 54                        0.063411                       4.736250
# 55                        0.048323                       5.485465
#
#     Third_Max_Value_Left Temporal  Third_Max_Freq_Left Temporal  \
# 0                        0.046373                      6.281250
# 1                        0.064189                      7.004076
# 2                        0.052156                      4.481061
# 3                        0.060445                      9.128906
# 4                        0.024519                     21.037500
# ..                            ...                           ...
# 51                       0.070805                      8.623547
# 52                       0.052731                      7.994565
# 53                       0.048620                      9.850694
# 54                       0.050046                      4.860000
# 55                       0.040659                      5.765988
#
#     Fourth_Max_Value_Left Temporal  Fourth_Max_Freq_Left Temporal  \
# 0                         0.037314                       6.243750
# 1                         0.049068                       6.616848
# 2                         0.043045                       5.373106
# 3                         0.041378                       8.445312
# 4                         0.021515                      21.575000
# ..                             ...                            ...
# 51                        0.049221                       7.889535
# 52                        0.041874                       8.157609
# 53                        0.036538                      10.024306
# 54                        0.041513                       5.221250
# 55                        0.034973                       6.232558
#
#     First_Max_Value_Occipital  First_Max_Freq_Occipital  \
# 0                    0.084592                  8.395833
# 1                    0.169328                  7.059783
# 2                    0.104939                  4.028409
# 3                    0.193487                  9.066406
# 4                    0.059612                 13.333333
# ..                        ...                       ...
# 51                   0.198112                 10.111919
# 52                   0.136010                  9.214674
# 53                   0.176390                  9.161458
# 54                   0.056215                  8.033750
# 55                   0.065268                  5.107558
#
#     Second_Max_Value_Occipital  Second_Max_Freq_Occipital  \
# 0                     0.064236                   8.275000
# 1                     0.120037                   7.066576
# 2                     0.070879                   4.897727
# 3                     0.134208                   9.281250
# 4                     0.045598                  14.322917
# ..                         ...                        ...
# 51                    0.139331                   9.921512
# 52                    0.100092                   9.430707
# 53                    0.117291                   9.138889
# 54                    0.044900                   8.493750
# 55                    0.049762                   5.729651
#
#     Third_Max_Value_Occipital  Third_Max_Freq_Occipital  \
# 0                    0.048051                  8.314583
# 1                    0.080278                  6.736413
# 2                    0.059940                  4.693182
# 3                    0.081485                  9.101562
# 4                    0.034269                 16.916667
# ..                        ...                       ...
# 51                   0.088826                  9.757267
# 52                   0.065555                  9.300272
# 53                   0.079523                  9.123264
# 54                   0.037264                  8.745000
# 55                   0.039873                  6.620640
#
#     Fourth_Max_Value_Occipital  Fourth_Max_Freq_Occipital  \
# 0                     0.039658                   8.247917
# 1                     0.054574                   6.297554
# 2                     0.050036                   4.988636
# 3                     0.056737                   8.683594
# 4                     0.027849                  17.033333
# ..                         ...                        ...
# 51                    0.053715                  10.133721
# 52                    0.047621                  10.429348
# 53                    0.055570                   9.189236
# 54                    0.031915                  10.012500
# 55                    0.034772                   6.972384
#
#     First_Max_Value_Parietal  First_Max_Freq_Parietal  \
# 0                   0.105479                 9.219444
# 1                   0.217070                 7.150362
# 2                   0.110642                 5.181818
# 3                   0.260387                 9.625000
# 4                   0.122604                 8.536111
# ..                       ...                      ...
# 51                  0.234296                 9.678295
# 52                  0.160871                 8.202899
# 53                  0.223099                 9.090278
# 54                  0.094351                 4.596667
# 55                  0.092199                 3.899225
#
#     Second_Max_Value_Parietal  Second_Max_Freq_Parietal  \
# 0                    0.074508                  9.130556
# 1                    0.149769                  7.012681
# 2                    0.078639                  5.247475
# 3                    0.175235                  9.583333
# 4                    0.094618                  8.622222
# ..                        ...                       ...
# 51                   0.162853                  9.676357
# 52                   0.114986                  8.380435
# 53                   0.136284                  8.946759
# 54                   0.070393                  5.176667
# 55                   0.065891                  4.447674
#
#     Third_Max_Value_Parietal  Third_Max_Freq_Parietal  \
# 0                   0.058022                 8.855556
# 1                   0.099038                 6.967391
# 2                   0.060831                 5.825758
# 3                   0.104419                 9.666667
# 4                   0.070255                 8.794444
# ..                       ...                      ...
# 51                  0.101688                 9.329457
# 52                  0.075410                 8.123188
# 53                  0.088367                 8.615741
# 54                  0.055002                 5.581667
# 55                  0.053154                 4.501938
#
#     Fourth_Max_Value_Parietal  Fourth_Max_Freq_Parietal  \
# 0                    0.048266                  8.769444
# 1                    0.063694                  6.259058
# 2                    0.051626                  5.608586
# 3                    0.059651                  9.442708
# 4                    0.052292                  8.636111
# ..                        ...                       ...
# 51                   0.064199                  8.885659
# 52                   0.056424                  8.413043
# 53                   0.051644                  9.287037
# 54                   0.046882                  6.143333
# 55                   0.045627                  4.633721
#
#     First_Max_Value_Prefrontal  First_Max_Freq_Prefrontal  \
# 0                     0.082266                   3.180556
# 1                     0.167471                   7.032609
# 2                     0.191831                   1.828283
# 3                     0.195944                   6.968750
# 4                     0.119668                   5.150000
# ..                         ...                        ...
# 51                    0.151403                   7.443798
# 52                    0.091022                   6.628623
# 53                    0.112317                   8.310185
# 54                    0.073767                   8.795000
# 55                    0.076731                   7.486434
#
#     Second_Max_Value_Prefrontal  Second_Max_Freq_Prefrontal  \
# 0                      0.064003                    3.158333
# 1                      0.122748                    6.789855
# 2                      0.118719                    2.070707
# 3                      0.142216                    6.802083
# 4                      0.089692                    5.147222
#
#     First_Max_Value_Right Temporal  First_Max_Freq_Right Temporal  \
# 0                         0.165548                       7.091667
# 1                         0.162562                       7.051630
# 2                         0.112941                       4.056818
# 3                         0.130406                       8.257812
# 4                         0.047191                      10.262500
# ..                             ...                            ...
# 51                        0.124295                       8.248547
# 52                        0.074790                       7.222826
# 53                        0.086661                      10.208333
# 54                        0.083816                       4.171250
# 55                        0.078312                       4.476744
#
#     Second_Max_Value_Right Temporal  Second_Max_Freq_Right Temporal  \
# 0                          0.102380                        6.854167
# 1                          0.113811                        6.881793
# 2                          0.073313                        4.388258
# 3                          0.088295                        8.476562
# 4                          0.037014                       10.987500
# ..                              ...                             ...
# 51                         0.088222                        8.101744
# 52                         0.055187                        7.699728
# 53                         0.060008                        9.614583
# 54                         0.060947                        4.958750
# 55                         0.053400                        5.202035
#
#     Third_Max_Value_Right Temporal  Third_Max_Freq_Right Temporal  \
# 0                         0.054708                       7.147917
# 1                         0.078727                       6.809783
# 2                         0.053761                       5.217803
# 3                         0.059935                       7.804688
# 4                         0.030537                      13.675000
# ..                             ...                            ...
# 51                        0.062540                       7.933140
# 52                        0.040246                       8.119565
# 53                        0.043575                       9.541667
# 54                        0.048713                       5.283750
# 55                        0.044973                       5.446221
#
#     Fourth_Max_Value_Right Temporal  Fourth_Max_Freq_Right Temporal
# 0                          0.036373                        7.106250
# 1                          0.055516                        6.489130
# 2                          0.046395                        5.289773
# 3                          0.045209                        8.234375
# 4                          0.025879                       13.568750
# ..                              ...                             ...
# 51                         0.047655                        7.042151
# 52                         0.033203                        8.830163
# 53                         0.033997                       10.463542
# 54                         0.042257                        5.565000
# 55                         0.039145                        5.476744
#
# [56 rows x 195 columns]

# %% [markdown]
# ##### Looking at brain regions

# %%
region_channel_dict = constants.region_to_channel_dict
regions = list(region_channel_dict.keys())
print( regions )
# Out:
# ['Prefrontal', 'Frontal', 'Left Frontal', 'Right Frontal', 'Central', 'Left Central', 'Right Central', 'Left Temporal', 'Right Temporal', 'Parietal', 'Left Parietal', 'Right Parietal', 'Occipital']

# %%
# I want to select Prefrontal , Central , Left Temporal , Right Temporal , Occipital 
selected_regions = ['Prefrontal' , 'Central' , 'Left Temporal' , 'Right Temporal' , 'Occipital' ]
selected_regions
# Out:
# ['Prefrontal', 'Central', 'Left Temporal', 'Right Temporal', 'Occipital']

# %%
selected_columns = [col for col in X.columns if any(col.endswith(region) for region in selected_regions)]

# %% [markdown]
# #### Calculate Global brain measures for BPW and Max Freqs (Test)

# %%
X_test = static_features_df.copy()
X_test.head()

bpw_max_freq_cols = [col[:-len('_Left Central')] for col in X_test.columns if 'Left Central' in col]
# ['Delta', 'Theta', 'Alpha', 'Sigma', 'Beta', 'Gamma', 'TotalAbsPow', 'First_Max_Value', 'First_Max_Freq', 
# 'Second_Max_Value', 'Second_Max_Freq', 'Third_Max_Value', 'Third_Max_Freq', 'Fourth_Max_Value', 'Fourth_Max_Freq']

for feat_col in bpw_max_freq_cols:
    feat_cols = [col for col in X_test.columns if col.startswith(feat_col)]

X_test[feat_col + '_Global'] = X_test[feat_cols].mean(axis = 1)

# %%
print(bpw_max_freq_cols)
# Out:
# ['Delta', 'Theta', 'Alpha', 'Sigma', 'Beta', 'Gamma', 'TotalAbsPow', 'First_Max_Value', 'First_Max_Freq', 'Second_Max_Value', 'Second_Max_Freq', 'Third_Max_Value', 'Third_Max_Freq', 'Fourth_Max_Value', 'Fourth_Max_Freq']

# %% [markdown]
# ### Experiment with Bandpower and Max Frequency data

# %%
#I think the regions combined data is by far the best performing
# Max Freq and BPW across the brain gets bad performance

# %%
#Experiments dict for using all of the features:
all_data_dict = {'All_regions' : selected_regions , 'All_regions_2' : selected_regions}
all_data_dict = {'All_regions' : selected_columns , 'All_regions_2' : selected_columns}

# %%
#Run Experiments, can choose 1-4
t1 = time.time()

all_expt_results = {}

for expt_num in [2] :
    expt_results = {}
    # ['Wake', 'N1', 'N2', 'N3', 'REM']
    for data_type in ['Wake', 'N1', 'N2', 'N3', 'REM']:
        X_y_groups = loaded_data[data_type]
        
        X = X_y_groups['X']
        y = X_y_groups['y'] 
        groups = X_y_groups['groups'] 

                   
        #1.Generate expt specific X,y,groups
        X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, expt_num )

        # clf_dict =  {'RF' : RandomForestClassifier(random_state = 5) , 'DT' : DecisionTreeClassifier() , 'Ada_B' : AdaBoostClassifier(random_state = 5)}
        
        clf_dict =  {'Ada_B' : AdaBoostClassifier(random_state = 5) }
        
        results_df_all_feats = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt,  clf_dict , return_df = True , subset_names_and_cols = all_data_dict, random_states = [1,2] )
        
        expt_results[data_type] = {'all_feats' : results_df_all_feats}
    
    all_expt_results[expt_num] = expt_results

t2 = time.time()

t2-t1
# Out:
# 8.315662384033203

# %%
for data_type in ['Wake', 'N1', 'N2', 'N3', 'REM']:
    print(data_type)
    results_df_all_feats = expt_results[data_type]['all_feats']
    res_df = run_expts.generate_subset_acc_std(results_df_all_feats, return_df = True)
    display(res_df)
# Out:
# Wake
#    random_state  All_regions_Ada_B_acc  All_regions_Ada_B_std  \
# 0             1               0.735714               0.121323
# 1             2               0.732143               0.097153
#
#    All_regions_2_Ada_B_acc  All_regions_2_Ada_B_std
# 0                 0.735714                 0.121323
# 1                 0.732143                 0.097153
# N1
#    random_state  All_regions_Ada_B_acc  All_regions_Ada_B_std  \
# 0             1               0.411111               0.141247
# 1             2               0.273333               0.099281
#
#    All_regions_2_Ada_B_acc  All_regions_2_Ada_B_std
# 0                 0.411111                 0.141247
# 1                 0.273333                 0.099281
# N2
#    random_state  All_regions_Ada_B_acc  All_regions_Ada_B_std  \
# 0             1               0.528889               0.094959
# 1             2               0.553333               0.118092
#
#    All_regions_2_Ada_B_acc  All_regions_2_Ada_B_std
# 0                 0.528889                 0.094959
# 1                 0.553333                 0.118092
# N3
#    random_state  All_regions_Ada_B_acc  All_regions_Ada_B_std  \
# 0             1               0.373333               0.100025
# 1             2               0.308889               0.138849
#
#    All_regions_2_Ada_B_acc  All_regions_2_Ada_B_std
# 0                 0.373333                 0.100025
# 1                 0.308889                 0.138849
# REM
#    random_state  All_regions_Ada_B_acc  All_regions_Ada_B_std  \
# 0             1               0.595556               0.102944
# 1             2               0.440000               0.148341
#
#    All_regions_2_Ada_B_acc  All_regions_2_Ada_B_std
# 0                 0.595556                 0.102944
# 1                 0.440000                 0.148341

# %% [markdown]
# #### Try PLI experiment (reminding myself how to generate connectivity features)

# %%
all_data_dict = {'All_regions' : list(X_connectivity.columns) }
all_data_dict
# Out:
# {'All_regions': ['beta_Fp1_Fpz',
#   'beta_Fp1_Fp2',
#   'beta_Fp1_F1',
#   'beta_Fp1_Fz',
#   'beta_Fp1_F2',
#   'beta_Fp1_AF7',
#   'beta_Fp1_F7',
#   'beta_Fp1_F5',
#   'beta_Fp1_F3',
#   'beta_Fp1_AF8',
#   'beta_Fp1_F8',
#   'beta_Fp1_F6',
#   'beta_Fp1_F4',
#   'beta_Fp1_FCz',
#   'beta_Fp1_FC1',
#   'beta_Fp1_FC2',
#   'beta_Fp1_Cz',
#   'beta_Fp1_C1',
#   'beta_Fp1_C2',
#   'beta_Fp1_CP1',
#   'beta_Fp1_CP2',
#   'beta_Fp1_FC5',
#   'beta_Fp1_FC3',
#   'beta_Fp1_C5',
#   'beta_Fp1_C3',
#   'beta_Fp1_CP5',
#   'beta_Fp1_CP3',
#   'beta_Fp1_FC6',
#   'beta_Fp1_FC4',
#   'beta_Fp1_C6',
#   'beta_Fp1_C4',
#   'beta_Fp1_CP6',
#   'beta_Fp1_CP4',
#   'beta_Fp1_TP7',
#   'beta_Fp1_T7',
#   'beta_Fp1_FT7',
#   'beta_Fp1_FT9',
#   'beta_Fp1_TP8',
#   'beta_Fp1_T8',
#   'beta_Fp1_FT8',
#   'beta_Fp1_FT10',
#   'beta_Fp1_P1',
#   'beta_Fp1_P2',
#   'beta_Fp1_Pz',
#   'beta_Fp1_P3',
#   'beta_Fp1_P5',
#   'beta_Fp1_P7',
#   'beta_Fp1_PO7',
#   'beta_Fp1_P4',
#   'beta_Fp1_P6',
#   'beta_Fp1_P8',
#   'beta_Fp1_PO8',
#   'beta_Fp1_POz',
#   'beta_Fp1_O1',
#   'beta_Fp1_O2',
#   'beta_Fp1_Oz',
#   'beta_Fpz_Fp2',
#   'beta_Fpz_F1',
#   'beta_Fpz_Fz',
#   'beta_Fpz_F2',
#   'beta_Fpz_AF7',
#   'beta_Fpz_F7',
#   'beta_Fpz_F5',
#   'beta_Fpz_F3',
#   'beta_Fpz_AF8',
#   'beta_Fpz_F8',
#   'beta_Fpz_F6',
#   'beta_Fpz_F4',
#   'beta_Fpz_FCz',
#   'beta_Fpz_FC1',
#   'beta_Fpz_FC2',
#   'beta_Fpz_Cz',
#   'beta_Fpz_C1',
#   'beta_Fpz_C2',
#   'beta_Fpz_CP1',
#   'beta_Fpz_CP2',
#   'beta_Fpz_FC5',
#   'beta_Fpz_FC3',
#   'beta_Fpz_C5',
#   'beta_Fpz_C3',
#   'beta_Fpz_CP5',
#   'beta_Fpz_CP3',
#   'beta_Fpz_FC6',
#   'beta_Fpz_FC4',
#   'beta_Fpz_C6',
#   'beta_Fpz_C4',
#   'beta_Fpz_CP6',
#   'beta_Fpz_CP4',
#   'beta_Fpz_TP7',
#   'beta_Fpz_T7',
#   'beta_Fpz_FT7',
#   'beta_Fpz_FT9',
#   'beta_Fpz_TP8',
#   'beta_Fpz_T8',
#   'beta_Fpz_FT8',
#   'beta_Fpz_FT10',
#   'beta_Fpz_P1',
#   'beta_Fpz_P2',
#   'beta_Fpz_Pz',
#   'beta_Fpz_P3',
#   'beta_Fpz_P5',
#   'beta_Fpz_P7',
#   'beta_Fpz_PO7',
#   'beta_Fpz_P4',
#   'beta_Fpz_P6',
#   'beta_Fpz_P8',
#   'beta_Fpz_PO8',
#   'beta_Fpz_POz',
#   'beta_Fpz_O1',
#   'beta_Fpz_O2',
#   'beta_Fpz_Oz',
#   'beta_Fp2_F1',
#   'beta_Fp2_Fz',
#   'beta_Fp2_F2',
#   'beta_Fp2_AF7',
#   'beta_Fp2_F7',
#   'beta_Fp2_F5',
#   'beta_Fp2_F3',
#   'beta_Fp2_AF8',
#   'beta_Fp2_F8',
#   'beta_Fp2_F6',
#   'beta_Fp2_F4',
#   'beta_Fp2_FCz',
#   'beta_Fp2_FC1',
#   'beta_Fp2_FC2',
#   'beta_Fp2_Cz',
#   'beta_Fp2_C1',
#   'beta_Fp2_C2',
#   'beta_Fp2_CP1',
#   'beta_Fp2_CP2',
#   'beta_Fp2_FC5',
#   'beta_Fp2_FC3',
#   'beta_Fp2_C5',
#   'beta_Fp2_C3',
#   'beta_Fp2_CP5',
#   'beta_Fp2_CP3',
#   'beta_Fp2_FC6',
#   'beta_Fp2_FC4',
#   'beta_Fp2_C6',
#   'beta_Fp2_C4',
#   'beta_Fp2_CP6',
#   'beta_Fp2_CP4',
#   'beta_Fp2_TP7',
#   'beta_Fp2_T7',
#   'beta_Fp2_FT7',
#   'beta_Fp2_FT9',
#   'beta_Fp2_TP8',
#   'beta_Fp2_T8',
#   'beta_Fp2_FT8',
#   'beta_Fp2_FT10',
#   'beta_Fp2_P1',
#   'beta_Fp2_P2',
#   'beta_Fp2_Pz',
#   'beta_Fp2_P3',
#   'beta_Fp2_P5',
#   'beta_Fp2_P7',
#   'beta_Fp2_PO7',
#   'beta_Fp2_P4',
#   'beta_Fp2_P6',
#   'beta_Fp2_P8',
#   'beta_Fp2_PO8',
#   'beta_Fp2_POz',
#   'beta_Fp2_O1',
#   'beta_Fp2_O2',
#   'beta_Fp2_Oz',
#   'beta_F1_Fz',
#   'beta_F1_F2',
#   'beta_F1_AF7',
#   'beta_F1_F7',
#   'beta_F1_F5',
#   'beta_F1_F3',
#   'beta_F1_AF8',
#   'beta_F1_F8',
#   'beta_F1_F6',
#   'beta_F1_F4',
#   'beta_F1_FCz',
#   'beta_F1_FC1',
#   'beta_F1_FC2',
#   'beta_F1_Cz',
#   'beta_F1_C1',
#   'beta_F1_C2',
#   'beta_F1_CP1',
#   'beta_F1_CP2',
#   'beta_F1_FC5',
#   'beta_F1_FC3',
#   'beta_F1_C5',
#   'beta_F1_C3',
#   'beta_F1_CP5',
#   'beta_F1_CP3',
#   'beta_F1_FC6',
#   'beta_F1_FC4',
#   'beta_F1_C6',
#   'beta_F1_C4',
#   'beta_F1_CP6',
#   'beta_F1_CP4',
#   'beta_F1_TP7',
#   'beta_F1_T7',
#   'beta_F1_FT7',
#   'beta_F1_FT9',
#   'beta_F1_TP8',
#   'beta_F1_T8',
#   'beta_F1_FT8',
#   'beta_F1_FT10',
#   'beta_F1_P1',
#   'beta_F1_P2',
#   'beta_F1_Pz',
#   'beta_F1_P3',
#   'beta_F1_P5',
#   'beta_F1_P7',
#   'beta_F1_PO7',
#   'beta_F1_P4',
#   'beta_F1_P6',
#   'beta_F1_P8',
#   'beta_F1_PO8',
#   'beta_F1_POz',
#   'beta_F1_O1',
#   'beta_F1_O2',
#   'beta_F1_Oz',
#   'beta_Fz_F2',
#   'beta_Fz_AF7',
#   'beta_Fz_F7',
#   'beta_Fz_F5',
#   'beta_Fz_F3',
#   'beta_Fz_AF8',
#   'beta_Fz_F8',
#   'beta_Fz_F6',
#   'beta_Fz_F4',
#   'beta_Fz_FCz',
#   'beta_Fz_FC1',
#   'beta_Fz_FC2',
#   'beta_Fz_Cz',
#   'beta_Fz_C1',
#   'beta_Fz_C2',
#   'beta_Fz_CP1',
#   'beta_Fz_CP2',
#   'beta_Fz_FC5',
#   'beta_Fz_FC3',
#   'beta_Fz_C5',
#   'beta_Fz_C3',
#   'beta_Fz_CP5',
#   'beta_Fz_CP3',
#   'beta_Fz_FC6',
#   'beta_Fz_FC4',
#   'beta_Fz_C6',
#   'beta_Fz_C4',
#   'beta_Fz_CP6',
#   'beta_Fz_CP4',
#   'beta_Fz_TP7',
#   'beta_Fz_T7',
#   'beta_Fz_FT7',
#   'beta_Fz_FT9',
#   'beta_Fz_TP8',
#   'beta_Fz_T8',
#   'beta_Fz_FT8',
#   'beta_Fz_FT10',
#   'beta_Fz_P1',
#   'beta_Fz_P2',
#   'beta_Fz_Pz',
#   'beta_Fz_P3',
#   'beta_Fz_P5',
#   'beta_Fz_P7',
#   'beta_Fz_PO7',
#   'beta_Fz_P4',
#   'beta_Fz_P6',
#   'beta_Fz_P8',
#   'beta_Fz_PO8',
#   'beta_Fz_POz',
#   'beta_Fz_O1',
#   'beta_Fz_O2',
#   'beta_Fz_Oz',
#   'beta_F2_AF7',
#   'beta_F2_F7',
#   'beta_F2_F5',
#   'beta_F2_F3',
#   'beta_F2_AF8',
#   'beta_F2_F8',
#   'beta_F2_F6',
#   'beta_F2_F4',
#   'beta_F2_FCz',
#   'beta_F2_FC1',
#   'beta_F2_FC2',
#   'beta_F2_Cz',
#   'beta_F2_C1',
#   'beta_F2_C2',
#   'beta_F2_CP1',
#   'beta_F2_CP2',
#   'beta_F2_FC5',
#   'beta_F2_FC3',
#   'beta_F2_C5',
#   'beta_F2_C3',
#   'beta_F2_CP5',
#   'beta_F2_CP3',
#   'beta_F2_FC6',
#   'beta_F2_FC4',
#   'beta_F2_C6',
#   'beta_F2_C4',
#   'beta_F2_CP6',
#   'beta_F2_CP4',
#   'beta_F2_TP7',
#   'beta_F2_T7',
#   'beta_F2_FT7',
#   'beta_F2_FT9',
#   'beta_F2_TP8',
#   'beta_F2_T8',
#   'beta_F2_FT8',
#   'beta_F2_FT10',
#   'beta_F2_P1',
#   'beta_F2_P2',
#   'beta_F2_Pz',
#   'beta_F2_P3',
#   'beta_F2_P5',
#   'beta_F2_P7',
#   'beta_F2_PO7',
#   'beta_F2_P4',
#   'beta_F2_P6',
#   'beta_F2_P8',
#   'beta_F2_PO8',
#   'beta_F2_POz',
#   'beta_F2_O1',
#   'beta_F2_O2',
#   'beta_F2_Oz',
#   'beta_AF7_F7',
#   'beta_AF7_F5',
#   'beta_AF7_F3',
#   'beta_AF7_AF8',
#   'beta_AF7_F8',
#   'beta_AF7_F6',
#   'beta_AF7_F4',
#   'beta_AF7_FCz',
#   'beta_AF7_FC1',
#   'beta_AF7_FC2',
#   'beta_AF7_Cz',
#   'beta_AF7_C1',
#   'beta_AF7_C2',
#   'beta_AF7_CP1',
#   'beta_AF7_CP2',
#   'beta_AF7_FC5',
#   'beta_AF7_FC3',
#   'beta_AF7_C5',
#   'beta_AF7_C3',
#   'beta_AF7_CP5',
#   'beta_AF7_CP3',
#   'beta_AF7_FC6',
#   'beta_AF7_FC4',
#   'beta_AF7_C6',
#   'beta_AF7_C4',
#   'beta_AF7_CP6',
#   'beta_AF7_CP4',
#   'beta_AF7_TP7',
#   'beta_AF7_T7',
#   'beta_AF7_FT7',
#   'beta_AF7_FT9',
#   'beta_AF7_TP8',
#   'beta_AF7_T8',
#   'beta_AF7_FT8',
#   'beta_AF7_FT10',
#   'beta_AF7_P1',
#   'beta_AF7_P2',
#   'beta_AF7_Pz',
#   'beta_AF7_P3',
#   'beta_AF7_P5',
#   'beta_AF7_P7',
#   'beta_AF7_PO7',
#   'beta_AF7_P4',
#   'beta_AF7_P6',
#   'beta_AF7_P8',
#   'beta_AF7_PO8',
#   'beta_AF7_POz',
#   'beta_AF7_O1',
#   'beta_AF7_O2',
#   'beta_AF7_Oz',
#   'beta_F7_F5',
#   'beta_F7_F3',
#   'beta_F7_AF8',
#   'beta_F7_F8',
#   'beta_F7_F6',
#   'beta_F7_F4',
#   'beta_F7_FCz',
#   'beta_F7_FC1',
#   'beta_F7_FC2',
#   'beta_F7_Cz',
#   'beta_F7_C1',
#   'beta_F7_C2',
#   'beta_F7_CP1',
#   'beta_F7_CP2',
#   'beta_F7_FC5',
#   'beta_F7_FC3',
#   'beta_F7_C5',
#   'beta_F7_C3',
#   'beta_F7_CP5',
#   'beta_F7_CP3',
#   'beta_F7_FC6',
#   'beta_F7_FC4',
#   'beta_F7_C6',
#   'beta_F7_C4',
#   'beta_F7_CP6',
#   'beta_F3_P8',
#   'beta_F3_PO8',
#   'beta_F3_POz',
#   'beta_F3_O1',
#   'beta_F3_O2',
#   'beta_F3_Oz',
#   'beta_AF8_F8',
#   'beta_AF8_F6',
#   'beta_AF8_F4',
#   'beta_AF8_FCz',
#   'beta_AF8_FC1',
#   'beta_AF8_FC2',
#   'beta_AF8_Cz',
#   'beta_AF8_C1',
#   'beta_AF8_C2',
#   'beta_AF8_CP1',
#   'beta_AF8_CP2',
#   'beta_AF8_FC5',
#   'beta_AF8_FC3',
#   'beta_AF8_C5',
#   'beta_AF8_C3',
#   'beta_AF8_CP5',
#   'beta_AF8_CP3',
#   'beta_AF8_FC6',
#   'beta_AF8_FC4',
#   'beta_AF8_C6',
#   'beta_AF8_C4',
#   'beta_AF8_CP6',
#   'beta_AF8_CP4',
#   'beta_AF8_TP7',
#   'beta_AF8_T7',
#   'beta_AF8_FT7',
#   'beta_AF8_FT9',
#   'beta_AF8_TP8',
#   'beta_AF8_T8',
#   'beta_AF8_FT8',
#   'beta_AF8_FT10',
#   'beta_AF8_P1',
#   'beta_AF8_P2',
#   'beta_AF8_Pz',
#   'beta_AF8_P3',
#   'beta_AF8_P5',
#   'beta_AF8_P7',
#   'beta_AF8_PO7',
#   'beta_AF8_P4',
#   'beta_AF8_P6',
#   'beta_AF8_P8',
#   'beta_AF8_PO8',
#   'beta_AF8_POz',
#   'beta_AF8_O1',
#   'beta_AF8_O2',
#   'beta_AF8_Oz',
#   'beta_F8_F6',
#   'beta_F8_F4',
#   'beta_F8_FCz',
#   'beta_F8_FC1',
#   'beta_F8_FC2',
#   'beta_F8_Cz',
#   'beta_F8_C1',
#   'beta_F8_C2',
#   'beta_F8_CP1',
#   'beta_F8_CP2',
#   'beta_F8_FC5',
#   'beta_F8_FC3',
#   'beta_F8_C5',
#   'beta_F8_C3',
#   'beta_F8_CP5',
#   'beta_F8_CP3',
#   'beta_F8_FC6',
#   'beta_F8_FC4',
#   'beta_F8_C6',
#   'beta_F8_C4',
#   'beta_F8_CP6',
#   'beta_F8_CP4',
#   'beta_F8_TP7',
#   'beta_F8_T7',
#   'beta_F8_FT7',
#   'beta_F8_FT9',
#   'beta_F8_TP8',
#   'beta_F8_T8',
#   'beta_F8_FT8',
#   'beta_F8_FT10',
#   'beta_F8_P1',
#   'beta_F8_P2',
#   'beta_F8_Pz',
#   'beta_F8_P3',
#   'beta_F8_P5',
#   'beta_F8_P7',
#   'beta_F8_PO7',
#   'beta_F8_P4',
#   'beta_F8_P6',
#   'beta_F8_P8',
#   'beta_F8_PO8',
#   'beta_F8_POz',
#   'beta_F8_O1',
#   'beta_F8_O2',
#   'beta_F8_Oz',
#   'beta_F6_F4',
#   'beta_F6_FCz',
#   'beta_F6_FC1',
#   'beta_F6_FC2',
#   'beta_F6_Cz',
#   'beta_F6_C1',
#   'beta_F6_C2',
#   'beta_F6_CP1',
#   'beta_F6_CP2',
#   'beta_F6_FC5',
#   'beta_F6_FC3',
#   'beta_F6_C5',
#   'beta_F6_C3',
#   'beta_F6_CP5',
#   'beta_F6_CP3',
#   'beta_F6_FC6',
#   'beta_F6_FC4',
#   'beta_F6_C6',
#   'beta_F6_C4',
#   'beta_F6_CP6',
#   'beta_F6_CP4',
#   'beta_F6_TP7',
#   'beta_F6_T7',
#   'beta_F6_FT7',
#   'beta_F6_FT9',
#   'beta_F6_TP8',
#   'beta_F6_T8',
#   'beta_F6_FT8',
#   'beta_F6_FT10',
#   'beta_F6_P1',
#   'beta_F6_P2',
#   'beta_F6_Pz',
#   'beta_F6_P3',
#   'beta_F6_P5',
#   'beta_F6_P7',
#   'beta_F6_PO7',
#   'beta_F6_P4',
#   'beta_F6_P6',
#   'beta_F6_P8',
#   'beta_F6_PO8',
#   'beta_F6_POz',
#   'beta_F6_O1',
#   'beta_F6_O2',
#   'beta_F6_Oz',
#   'beta_F4_FCz',
#   'beta_F4_FC1',
#   'beta_F4_FC2',
#   'beta_F4_Cz',
#   'beta_F4_C1',
#   'beta_F4_C2',
#   'beta_F4_CP1',
#   'beta_F4_CP2',
#   'beta_F4_FC5',
#   'beta_F4_FC3',
#   'beta_F4_C5',
#   'beta_F4_C3',
#   'beta_F4_CP5',
#   'beta_F4_CP3',
#   'beta_F4_FC6',
#   'beta_F4_FC4',
#   'beta_F4_C6',
#   'beta_F4_C4',
#   'beta_F4_CP6',
#   'beta_F4_CP4',
#   'beta_F4_TP7',
#   'beta_F4_T7',
#   'beta_F4_FT7',
#   'beta_F4_FT9',
#   'beta_F4_TP8',
#   'beta_F4_T8',
#   'beta_F4_FT8',
#   'beta_F4_FT10',
#   'beta_F4_P1',
#   'beta_F4_P2',
#   'beta_F4_Pz',
#   'beta_F4_P3',
#   'beta_F4_P5',
#   'beta_F4_P7',
#   'beta_F4_PO7',
#   'beta_F4_P4',
#   'beta_F4_P6',
#   'beta_F4_P8',
#   'beta_F4_PO8',
#   'beta_F4_POz',
#   'beta_F4_O1',
#   'beta_F4_O2',
#   'beta_F4_Oz',
#   'beta_FCz_FC1',
#   'beta_FCz_FC2',
#   'beta_FCz_Cz',
#   'beta_FCz_C1',
#   'beta_FCz_C2',
#   'beta_FCz_CP1',
#   'beta_FCz_CP2',
#   'beta_FCz_FC5',
#   'beta_FCz_FC3',
#   'beta_FCz_C5',
#   'beta_FCz_C3',
#   'beta_FCz_CP5',
#   'beta_FCz_CP3',
#   'beta_FCz_FC6',
#   'beta_FCz_FC4',
#   'beta_FCz_C6',
#   'beta_FCz_C4',
#   'beta_FCz_CP6',
#   'beta_FCz_CP4',
#   'beta_FCz_TP7',
#   'beta_FCz_T7',
#   'beta_FCz_FT7',
#   'beta_FCz_FT9',
#   'beta_FCz_TP8',
#   'beta_FCz_T8',
#   'beta_FCz_FT8',
#   'beta_FCz_FT10',
#   'beta_FCz_P1',
#   'beta_FCz_P2',
#   'beta_FCz_Pz',
#   'beta_FCz_P3',
#   'beta_FCz_P5',
#   'beta_FCz_P7',
#   'beta_FCz_PO7',
#   'beta_FCz_P4',
#   'beta_FCz_P6',
#   'beta_FCz_P8',
#   'beta_FCz_PO8',
#   'beta_FCz_POz',
#   'beta_FCz_O1',
#   'beta_FCz_O2',
#   'beta_FCz_Oz',
#   'beta_FC1_FC2',
#   'beta_FC1_Cz',
#   'beta_FC1_C1',
#   'beta_FC1_C2',
#   'beta_FC1_CP1',
#   'beta_FC1_CP2',
#   'beta_FC1_FC5',
#   'beta_FC1_FC3',
#   'beta_FC1_C5',
#   'beta_FC1_C3',
#   'beta_FC1_CP5',
#   'beta_FC1_CP3',
#   'beta_FC1_FC6',
#   'beta_FC1_FC4',
#   'beta_FC1_C6',
#   'beta_FC1_C4',
#   'beta_FC1_CP6',
#   'beta_FC1_CP4',
#   'beta_FC1_TP7',
#   'beta_FC1_T7',
#   'beta_FC1_FT7',
#   'beta_FC1_FT9',
#   'beta_FC1_TP8',
#   'beta_FC1_T8',
#   'beta_FC1_FT8',
#   'beta_FC1_FT10',
#   'beta_FC1_P1',
#   'beta_FC1_P2',
#   'beta_FC1_Pz',
#   'beta_FC1_P3',
#   'beta_FC1_P5',
#   'beta_FC1_P7',
#   'beta_FC1_PO7',
#   'beta_FC1_P4',
#   'beta_FC1_P6',
#   'beta_FC1_P8',
#   'beta_FC1_PO8',
#   'beta_FC1_POz',
#   'beta_FC1_O1',
#   'beta_FC1_O2',
#   'beta_FC1_Oz',
#   'beta_FC2_Cz',
#   'beta_FC2_C1',
#   'beta_FC2_C2',
#   'beta_FC2_CP1',
#   'beta_FC2_CP2',
#   'beta_FC2_FC5',
#   'beta_FC2_FC3',
#   'beta_FC2_C5',
#   'beta_FC2_C3',
#   'beta_FC2_CP5',
#   'beta_FC2_CP3',
#   'beta_FC2_FC6',
#   'beta_FC2_FC4',
#   'beta_FC2_C6',
#   'beta_FC2_C4',
#   'beta_FC2_CP6',
#   'beta_FC2_CP4',
#   'beta_FC2_TP7',
#   'beta_FC2_T7',
#   'beta_FC2_FT7',
#   'beta_FC2_FT9',
#   'beta_FC2_TP8',
#   'beta_FC2_T8',
#   'beta_FC2_FT8',
#   'beta_FC2_FT10',
#   'beta_FC2_P1',
#   'beta_FC2_P2',
#   'beta_FC2_Pz',
#   'beta_FC2_P3',
#   'beta_FC2_P5',
#   'beta_FC2_P7',
#   'beta_FC2_PO7',
#   'beta_FC2_P4',
#   'beta_FC2_P6',
#   'beta_FC2_P8',
#   'beta_FC2_PO8',
#   'beta_FC2_POz',
#   'beta_FC2_O1',
#   'beta_FC2_O2',
#   'beta_FC2_Oz',
#   'beta_Cz_C1',
#   'beta_Cz_C2',
#   'beta_Cz_CP1',
#   'beta_Cz_CP2',
#   'beta_Cz_FC5',
#   'beta_Cz_FC3',
#   'beta_Cz_C5',
#   'beta_Cz_C3',
#   'beta_Cz_CP5',
#   'beta_Cz_CP3',
#   'beta_Cz_FC6',
#   'beta_Cz_FC4',
#   'beta_Cz_C6',
#   'beta_Cz_C4',
#   'beta_Cz_CP6',
#   'beta_Cz_CP4',
#   'beta_Cz_TP7',
#   'beta_Cz_T7',
#   'beta_Cz_FT7',
#   'beta_Cz_FT9',
#   'beta_Cz_TP8',
#   'beta_Cz_T8',
#   'beta_Cz_FT8',
#   'beta_Cz_FT10',
#   'beta_Cz_P1',
#   'beta_Cz_P2',
#   'beta_Cz_Pz',
#   'beta_Cz_P3',
#   'beta_Cz_P5',
#   'beta_Cz_P7',
#   'beta_Cz_PO7',
#   'beta_Cz_P4',
#   'beta_Cz_P6',
#   'beta_Cz_P8',
#   'beta_Cz_PO8',
#   'beta_Cz_POz',
#   'beta_Cz_O1',
#   'beta_Cz_O2',
#   'beta_Cz_Oz',
#   'beta_C1_C2',
#   'beta_C1_CP1',
#   'beta_C1_CP2',
#   'beta_C1_FC5',
#   'beta_C1_FC3',
#   'beta_C1_C5',
#   'beta_C1_C3',
#   'beta_C1_CP5',
#   'beta_C1_CP3',
#   'beta_C1_FC6',
#   'beta_C1_FC4',
#   'beta_C1_C6',
#   'beta_C1_C4',
#   'beta_C1_CP6',
#   'beta_C1_CP4',
#   'beta_C1_TP7',
#   'beta_C1_T7',
#   'beta_C1_FT7',
#   'beta_C1_FT9',
#   'beta_C1_TP8',
#   'beta_C1_T8',
#   'beta_C1_FT8',
#   'beta_C1_FT10',
#   'beta_C1_P1',
#   'beta_C1_P2',
#   'beta_C1_Pz',
#   'beta_C1_P3',
#   'beta_C1_P5',
#   'beta_C1_P7',
#   'beta_C1_PO7',
#   'beta_C1_P4',
#   'beta_C1_P6',
#   'beta_C1_P8',
#   'beta_C1_PO8',
#   'beta_C1_POz',
#   'beta_C1_O1',
#   'beta_C1_O2',
#   'beta_C1_Oz',
#   'beta_C2_CP1',
#   'beta_C2_CP2',
#   'beta_C2_FC5',
#   'beta_C2_FC3',
#   'beta_C2_C5',
#   'beta_C2_C3',
#   'beta_C2_CP5',
#   'beta_C2_CP3',
#   'beta_C2_FC6',
#   'beta_C2_FC4',
#   'beta_C2_C6',
#   'beta_C2_C4',
#   'beta_C2_CP6',
#   'beta_C2_CP4',
#   'beta_C2_TP7',
#   'beta_C2_T7',
#   'beta_C2_FT7',
#   'beta_C2_FT9',
#   'beta_C2_TP8',
#   'beta_C2_T8',
#   'beta_C2_FT8',
#   'beta_C2_FT10',
#   'beta_C2_P1',
#   'beta_C2_P2',
#   'beta_C2_Pz',
#   'beta_C2_P3',
#   'beta_C2_P5',
#   'beta_C2_P7',
#   'beta_C2_PO7',
#   'beta_C2_P4',
#   'beta_C2_P6',
#   'beta_C2_P8',
#   'beta_C2_PO8',
#   'beta_C2_POz',
#   'beta_C2_O1',
#   'beta_C2_O2',
#   'beta_C2_Oz',
#   'beta_CP1_CP2',
#   'beta_CP1_FC5',
#   'beta_CP1_FC3',
#   'beta_CP1_C5',
#   'beta_CP1_C3',
#   'beta_CP1_CP5',
#   'beta_CP1_CP3',
#   'beta_CP1_FC6',
#   'beta_CP1_FC4',
#   'beta_CP1_C6',
#   'beta_CP1_C4',
#   'beta_CP1_CP6',
#   'beta_CP1_CP4',
#   'beta_CP1_TP7',
#   'beta_CP1_T7',
#   'beta_CP1_FT7',
#   'beta_CP1_FT9',
#   'beta_CP1_TP8',
#   'beta_CP1_T8',
#   'beta_CP1_FT8',
#   'beta_CP1_FT10',
#   'beta_CP1_P1',
#   'beta_CP1_P2',
#   'beta_CP1_Pz',
#   'beta_CP1_P3',
#   'beta_CP1_P5',
#   'beta_CP1_P7',
#   'beta_CP1_PO7',
#   'beta_CP1_P4',
#   'beta_CP1_P6',
#   'beta_CP1_P8',
#   'beta_CP1_PO8',
#   'beta_CP1_POz',
#   'beta_CP1_O1',
#   'beta_CP1_O2',
#   'beta_CP1_Oz',
#   'beta_CP2_FC5',
#   'beta_CP2_FC3',
#   'beta_CP2_C5',
#   'beta_CP2_C3',
#   'beta_CP2_CP5',
#   'beta_CP2_CP3',
#   'beta_CP2_FC6',
#   'beta_CP2_FC4',
#   'beta_CP2_C6',
#   'beta_CP2_C4',
#   'beta_CP2_CP6',
#   'beta_CP2_CP4',
#   'beta_CP2_TP7',
#   'beta_CP2_T7',
#   'beta_CP2_FT7',
#   'beta_CP2_FT9',
#   'beta_CP2_TP8',
#   'beta_CP2_T8',
#   'beta_CP2_FT8',
#   'beta_CP2_FT10',
#   'beta_CP2_P1',
#   'beta_CP2_P2',
#   'beta_CP2_Pz',
#   'beta_CP2_P3',
#   'beta_CP2_P5',
#   'beta_CP2_P7',
#   'beta_CP2_PO7',
#   'beta_CP2_P4',
#   'beta_CP2_P6',
#   'beta_CP2_P8',
#   'beta_CP2_PO8',
#   'beta_CP2_POz',
#   'beta_CP2_O1',
#   'beta_CP2_O2',
#   ...]}

# %%
#___________load the appropriate connectivity features don't concatenate to non connectivity features until after dictionary generation
connectivity_settings = ['delta' , 'theta' , 'alpha', 'sigma', 'beta', 'gamma']
connectivity_setting = 'beta'

data_types = ['Wake', 'N1', 'N2', 'N3', 'REM']
data_type = 'N1'

connectivity_folder = '/user/home/ko20929/work/RBD_using_custom_package/Blue_pebble/Connectivity/'
X_connectivity = pd.read_hdf(connectivity_folder + data_type+ '_pli__df.h5')

#Select only the chosen connectivity columns, connectivity setting is the name of the power band
X_connectivity = X_connectivity[[col for col in X_connectivity.columns if connectivity_setting in col]]    
y = pd.read_hdf(load_path_bpw + data_type +  '_y.h5', key='df', mode='r') 
groups = pd.read_hdf(load_path_bpw + data_type +  '_groups.h5', key='df', mode='r')

# %%
X = X_connectivity
X.reset_index(drop = True)
# Out:
#     beta_Fp1_Fpz  beta_Fp1_Fp2  beta_Fp1_F1  beta_Fp1_Fz  beta_Fp1_F2  \
# 0       0.258044      0.468797     0.429497     0.346577     0.244656
# 1       0.228029      0.388955     0.304335     0.276722     0.220903
# 2       0.145784      0.163599     0.175624     0.172209     0.168646
# 3       0.269002      0.317102     0.277910     0.293943     0.301663
# 4       0.286619      0.316706     0.299287     0.314331     0.302454
# ..           ...           ...          ...          ...          ...
# 66      0.096839      0.158536     0.095560     0.157440     0.131433
# 68    0.173087     0.150057     0.172467    0.140969    0.192709    0.220283
# 69    0.240855     0.255582     0.223753    0.276010    0.214252    0.259382
# 70    0.244260     0.246239     0.242280    0.229612    0.239509    0.261679
#
#     beta_PO8_POz  beta_PO8_O1  beta_PO8_O2  beta_PO8_Oz  beta_POz_O1  \
# 0       0.268840     0.284820     0.316346     0.264954     0.274887
# 1       0.205166     0.310273     0.243765     0.187055     0.239311
# 2       0.125148     0.167607     0.137322     0.181710     0.137470
# 3       0.248812     0.233967     0.239905     0.282660     0.273753
# 4       0.336500     0.296120     0.322249     0.336500     0.317498
# ..           ...          ...          ...          ...          ...
# 66      0.094220     0.100981     0.102016     0.120592     0.100432
# 67      0.140981     0.189605     0.164454     0.134414     0.152438
# 68      0.127233     0.187339     0.141898     0.125581     0.123309
# 69      0.233254     0.272209     0.268884     0.236105     0.267933
# 70      0.258907     0.231591     0.243864     0.241489     0.232383
#
#     beta_POz_O2  beta_POz_Oz  beta_O1_O2  beta_O1_Oz  beta_O2_Oz
# 0      0.267113     0.249838    0.292593    0.264954    0.239905
# 1      0.324525     0.230701    0.204276    0.245249    0.253266
# 2      0.130790     0.171615    0.138064    0.164786    0.180968
# 3      0.289192     0.295724    0.295724    0.288005    0.257126
# 4      0.296912     0.333333    0.288203    0.327791    0.344418
# ..          ...          ...         ...         ...         ...
# 66     0.091723     0.112674    0.092941    0.122115    0.144528
# 67     0.143356     0.141260    0.176051    0.134693    0.147688
# 68     0.166684     0.160384    0.143241    0.114737    0.138180
# 69     0.235629     0.250356    0.293587    0.199050    0.247031
# 70     0.236738     0.261679    0.228424    0.232383    0.256928
#
# [71 rows x 1596 columns]

# %%
#Run Experiments, can choose 1-4
t1 = time.time()

all_expt_results = {}

for expt_num in [1] :
    expt_results = {}
    # ['Wake', 'N1', 'N2', 'N3', 'REM']
    for data_type in ['N1']:
        X_y_groups = loaded_data[data_type]
        
        X = X_y_groups['X']
        X = X_connectivity
        X = X.reset_index(drop = True)
        y = X_y_groups['y'] 
        groups = X_y_groups['groups'] 

                   
        #1.Generate expt specific X,y,groups
        X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, expt_num )

        # clf_dict =  {'RF' : RandomForestClassifier(random_state = 5) , 'DT' : DecisionTreeClassifier() , 'Ada_B' : AdaBoostClassifier(random_state = 5)}
        
        clf_dict =  { 'AdaB' : AdaBoostClassifier()  }
        
        results_df_all_feats = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt,  clf_dict , return_df = True , subset_names_and_cols = all_data_dict, random_states = [1,2] )
        
        expt_results[data_type] = {'all_feats' : results_df_all_feats}
    
    all_expt_results[expt_num] = expt_results

t2 = time.time()

t2-t1
# Out:
# 3.4730780124664307

# %%
res_df = run_expts.generate_subset_acc_std(results_df_all_feats, return_df = True)
display(res_df)
# Out:
#    random_state  All_regions_AdaB_acc  All_regions_AdaB_std
# 0             1                 0.825              0.127475
# 1             2                 0.875              0.136931

# %% [markdown]
# #### These results above seem decent, now lets combine connectivity with the frequency features and see what the result is?

# %%
#
