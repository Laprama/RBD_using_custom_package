# %%
! python execute_expts.py Wake [52,20] 0.75 Central 200 100 80 150
! python execute_expts.py Wake [52,20] 0.5 Central 200 100 80 150

! python execute_expts.py N1 [52,20] 0.75 Central 200 100 80 150
! python execute_expts.py N1 [52,20] 0.5 Central 200 100 80 150

! python execute_expts.py N2 [52,20] 0.75 Central 200 100 80 150
! python execute_expts.py N2 [52,20] 0.5 Central 200 100 80 150

! python execute_expts.py N3 [52,20] 0.75 Central 200 100 80 150
! python execute_expts.py N3 [52,20] 0.5 Central 200 100 80 150

! python execute_expts.py REM [52,20] 0.75 Central 200 100 80 150
! python execute_expts.py REM [52,20] 0.5 Central 200 100 80 150

# Increase the hop to 250
! python execute_expts.py Wake [52,20] 0.75 Central 200 250 80 150
! python execute_expts.py Wake [52,20] 0.5 Central 200 250 80 150

! python execute_expts.py N1 [52,20] 0.75 Central 200 250 80 150
! python execute_expts.py N1 [52,20] 0.5 Central 200 250 80 150

! python execute_expts.py N2 [52,20] 0.75 Central 200 250 80 150
! python execute_expts.py N2 [52,20] 0.5 Central 200 250 80 150

! python execute_expts.py N3 [52,20] 0.75 Central 200 250 80 150
! python execute_expts.py N3 [52,20] 0.5 Central 200 250 80 150

! python execute_expts.py REM [52,20] 0.75 Central 200 250 80 150
! python execute_expts.py REM [52,20] 0.5 Central 200 250 80 150
# Out:
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/antropy/fractal.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit((types.Array(types.float64, 1, "C", readonly=True), types.int32))
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package yasa is out of date. Your version is 0.6.3, the latest is 0.6.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
# script started...
# fold 1
# 75. | 24. |
# [1101 1102 1103 1104 1106 1109 1110 1111 1113 1114 1115 1116 1119 4402
#  4404 4405 4406 4407 4409 4410 4411]
# ...

# %%
# Increase the hop to 300 AND increase the g_std of the window to 400 
! python execute_expts.py Wake [52,20] 0.75 Central 400 300 80 150
! python execute_expts.py Wake [52,20] 0.5 Central 400 300 80 150

! python execute_expts.py N1 [52,20] 0.75 Central 400 300 80 150
! python execute_expts.py N1 [52,20] 0.5 Central 400 300 80 150

! python execute_expts.py N2 [52,20] 0.75 Central 400 300 80 150
! python execute_expts.py N2 [52,20] 0.5 Central 400 300 80 150

! python execute_expts.py N3 [52,20] 0.75 Central 400 300 80 150
! python execute_expts.py N3 [52,20] 0.5 Central 400 300 80 150

! python execute_expts.py REM [52,20] 0.75 Central 400 300 80 150
! python execute_expts.py REM [52,20] 0.5 Central 400 300 80 150

# Increase the segment length to 120 with hop 200
! python execute_expts.py Wake [52,20] 0.75 Central 200 200 120 150
! python execute_expts.py Wake [52,20] 0.5 Central 200 200 120 150

! python execute_expts.py N1 [52,20] 0.75 Central 200 200 120 150
! python execute_expts.py N1 [52,20] 0.5 Central 200 200 120 150

! python execute_expts.py N2 [52,20] 0.75 Central 200 200 120 150
! python execute_expts.py N2 [52,20] 0.5 Central 200 200 120 150

! python execute_expts.py N3 [52,20] 0.75 Central 200 200 120 150
! python execute_expts.py N3 [52,20] 0.5 Central 200 200 120 150

! python execute_expts.py REM [52,20] 0.75 Central 200 200 120 150
! python execute_expts.py REM [52,20] 0.5 Central 200 200 120 150
