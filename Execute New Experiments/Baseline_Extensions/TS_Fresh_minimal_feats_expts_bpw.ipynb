# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
import run_expts

#TS Fresh Parameter Settings
from tsfresh.feature_extraction import ComprehensiveFCParameters
from tsfresh.feature_extraction import MinimalFCParameters
from tsfresh.feature_extraction import EfficientFCParameters
from tsfresh.feature_extraction import extract_features
# Out:
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/antropy/fractal.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit((types.Array(types.float64, 1, "C", readonly=True), types.int32))
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package yasa is out of date. Your version is 0.6.3, the latest is 0.6.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

# %%
# Out:
#                                         Delta_Central
# 0   0     0.119395
# 1     0.115076
# 2     0.095208
# 3...
# 1   0     0.131017
# 1     0.239976
# 2     0.202804
# 3...
# 2   0     0.318531
# 1     0.451460
# 2     0.289201
# 3...
# 3   0     0.155344
# 1     0.135972
# 2     0.102962
# 3...
# 4   0     0.157144
# 1     0.174992
# 2     0.249474
# 3...
# 5   0     0.259569
# 1     0.259690
# 2     0.137632
# 3...
# 6   0     0.349313
# 1     0.387809
# 2     0.341438
# 3...
# 7   0     0.372117
# 1     0.221151
# 2     0.426803
# 3...
# 8   0     0.254625
# 1     0.360561
# 2     0.615961
# 3...
# 9   0     0.294701
# 1     0.331363
# 2     0.303480
# 3...
# 10  0     0.152170
# 1     0.129380
# 2     0.171884
# 3...
# 11  0     0.355171
# 1     0.423246
# 2     0.315088
# 3...
# 12  0     0.302774
# 1     0.456013
# 2     0.530683
# 3...
# 13  0     0.186382
# 1     0.166889
# 2     0.163018
# 3...
# 14  0     0.056289
# 1     0.114600
# 2     0.088923
# 3...
# 15  0     0.298777
# 1     0.114661
# 2     0.124351
# 3...
# 16  0     0.392756
# 1     0.452365
# 2     0.425335
# 3...
# 17  0     0.098884
# 1     0.137002
# 2     0.125190
# 3...
# 18  0     0.237025
# 1     0.218649
# 2     0.143202
# 3...
# 19  0     0.264771
# 1     0.208265
# 2     0.295315
# 3...
# 20  0     0.085615
# 1     0.103714
# 2     0.082093
# 3...
# 21  0     0.445390
# 1     0.458398
# 2     0.447664
# 3...
# 22  0     0.477895
# 1     0.379966
# 2     0.382117
# 3...
# 23  0     0.317319
# 1     0.326055
# 2     0.282624
# 3...
# 24  0     0.218815
# 1     0.153403
# 2     0.134629
# 3...
# 25  0     0.171631
# 1     0.208631
# 2     0.183101
# 3...
# 26  0     0.371337
# 1     0.296010
# 2     0.312976
# 3...
# 27  0     0.289162
# 1     0.321485
# 2     0.311700
# 3...
# 28  0     0.432389
# 1     0.299964
# 2     0.227966
# 3...
# 29  0     0.286611
# 1     0.160695
# 2     0.157056
# 3...
# 30  0     0.413759
# 1     0.248557
# 2     0.234421
# 3...
# 31  0     0.116378
# 1     0.119261
# 2     0.258459
# 3...
# 32  0     0.187546
# 1     0.222046
# 2     0.382500
# 3...
# 33  0     0.265997
# 1     0.256672
# 2     0.396281
# 3...
# 34  0     0.473686
# 1     0.295951
# 2     0.222378
# 3...
# 35  0     0.674811
# 1     0.360600
# 2     0.495468
# 3...
# 36  0     0.170811
# 1     0.134556
# 2     0.434183
# 3...
# 37  0     0.143837
# 1     0.325764
# 2     0.299395
# 3...
# 38  0     0.184660
# 1     0.233987
# 2     0.194273
# 3...
# 39  0     0.210928
# 1     0.133603
# 2     0.137366
# 3...
# 40  0    0.113909
# 1    0.131450
# 2    0.118700
# 3   ...
# 41  0     0.228269
# 1     0.165646
# 2     0.205138
# 3...
# 42  0     0.424759
# 1     0.576955
# 2     0.436331
# 3...
# 43  0     0.173293
# 1     0.203827
# 2     0.227341
# 3...
# 44  0     0.080983
# 1     0.116921
# 2     0.144441
# 3...
# 45  0     0.175013
# 1     0.252839
# 2     0.120243
# 3...
# 46  0     0.137246
# 1     0.152739
# 2     0.081876
# 3...
# 47  0     0.138634
# 1     0.146520
# 2     0.110488
# 3...
# 48  0     0.506615
# 1     0.161982
# 2     0.336958
# 3...
# 49  0     0.102441
# 1     0.158774
# 2     0.224895
# 3...
# 50  0     0.198878
# 1     0.240563
# 2     0.209572
# 3...
# 51  0     0.115544
# 1     0.121862
# 2     0.233945
# 3...
# 52  0     0.162527
# 1     0.270664
# 2     0.227408
# 3...
# 53  0     0.170454
# 1     0.116147
# 2     0.096813
# 3...
# 54  0     0.258982
# 1     0.302431
# 2     0.263695
# 3...
# 55  0     0.271574
# 1     0.487581
# 2     0.482633
# 3...

# %%
# Testing extracting minimal features so I can see what they are for my paper

load_path = '/user/home/ko20929/work/RBD_using_custom_package/Data/freq_6_second_files/'
data_types = ['Wake','N1', 'N2', 'N3', 'REM']
data_type = 'Wake'
X = pd.read_hdf(load_path + data_type +  'six_second_freq_df.h5', key='df', mode='r')

ts_fresh_df = format_eeg_data.convert_sktime_df_to_ts_fresh_format(pd.DataFrame(X.iloc[:,0]), ts_cols = list(pd.DataFrame(X.iloc[:,0]).columns))

settings = MinimalFCParameters()
extracted_ts_fresh_df = extract_features(ts_fresh_df, column_id = 'id' , column_sort = 'time',  default_fc_parameters=settings)
# Out:
# 30-Apr-24 19:06:08 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 56/56 [00:00<00:00, 371.04it/s]

# %%
len('Delta_Central__')
# Out:
# 15

# %%
cols = [ col[15:] for col in extracted_ts_fresh_df.columns ]
print(cols) 
len(cols)
# Out:
# ['sum_values', 'median', 'mean', 'length', 'standard_deviation', 'variance', 'root_mean_square', 'maximum', 'absolute_maximum', 'minimum']
# 10

# %%
clf = AdaBoostClassifier(random_state = 5)

# %%
loaded_data['Wake']['X'].equals(loaded_data['N1']['X'])
# Out:
# True

# %%
load_path = '/user/home/ko20929/work/RBD_using_custom_package/Data/freq_6_second_files/'

data_types = ['Wake','N1', 'N2', 'N3', 'REM']

loaded_data = {}

for data_type in data_types:
    print(data_type)
    X_y_groups = {}
    
    X = pd.read_hdf(load_path + data_type +  'six_second_freq_df.h5', key='df', mode='r')
    y = pd.read_hdf(load_path + data_type +  '_y.h5', key='df', mode='r') 
    groups = pd.read_hdf(load_path + data_type +  '_groups.h5', key='df', mode='r')
    X, y , groups = X.reset_index(drop = True) , y.reset_index(drop = True) , groups.reset_index(drop = True)

    #Transform the X into TS_Fresh Features___
    # 1. Convert to TS_Fresh format Dataframe 
    ts_fresh_df = format_eeg_data.convert_sktime_df_to_ts_fresh_format(X, ts_cols = list(X.columns))
    
    # 2. Extract TS_Fresh Features from the dataframe
    settings = MinimalFCParameters()
    extracted_ts_fresh_df = extract_features(ts_fresh_df, column_id = 'id' , column_sort = 'time',  default_fc_parameters=settings)

    # 3. Asign extract_ts_fresh_df to the variable X
    X = extracted_ts_fresh_df.copy()
       

    X_y_groups['X'] = X
    X_y_groups['y'] = y
    X_y_groups['groups'] = groups

    loaded_data[data_type] = X_y_groups
# Out:
# Wake
# 04-Sep-23 14:27:30 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 160/160 [00:06<00:00, 24.93it/s]
# N1
# 04-Sep-23 14:28:08 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 158/158 [00:10<00:00, 15.12it/s]
# N2
# 04-Sep-23 14:29:02 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 158/158 [00:13<00:00, 11.70it/s]
# N3
# 04-Sep-23 14:29:46 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 160/160 [00:01<00:00, 87.21it/s]
# REM
# 04-Sep-23 14:29:49 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 157/157 [00:01<00:00, 91.30it/s]

# %%
#Generate a region to features dictionary - this will enable us to run expts regionally as before
regional_features_dict = {}
region_channel_dict = constants.region_to_channel_dict
regions = list(region_channel_dict.keys())
for region in regions:
    region_features = [col for col in extracted_ts_fresh_df.dropna(axis = 1).columns if region + '_' in col]
    if len(region_features) > 0 : 
        regional_features_dict[region] = region_features

# %% [markdown]
# ## Expt 1

# %%
#Run Expt 1 experiments 

t1 = time.time()

expt_1_results = {}

for data_type in data_types:
    X_y_groups = loaded_data[data_type] 
    
    X = X_y_groups['X']
    y = X_y_groups['y'] 
    groups = X_y_groups['groups'] 
    
    #1.Generate expt specific X,y,groups
    X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, 1 )

    results_df = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt, {'RF' : RandomForestClassifier(random_state = 5) , 'SVC' : SVC(), 'Ada_B' : AdaBoostClassifier(random_state = 5)} , return_df = True , subset_names_and_cols = regional_features_dict, random_states = [1,2] )
    
    expt_1_results[data_type] = results_df

t2 = time.time()

t2-t1
# Out:
# 102.99936652183533

# %%
#Show the results
for data_type in data_types:
    print(data_type)
    results_df = expt_1_results[data_type]
    res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)
    #print the results 
    # print(res_df[[col for col in res_df.columns if 'acc' in col]].mean(axis = 0))
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'RF' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'SVC' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'Ada_B' in col]].mean(axis = 0)).T)
# Out:
# Wake
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.616667             0.6             0.666667
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.533333            0.45             0.583333
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.583333              0.516667                   0.55
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.616667              0.616667               0.566667
#
#    Occipital_RF_acc
# 0          0.666667
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0                 0.6              0.6              0.583333
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0                    0.6         0.533333                  0.55
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0                    0.6               0.566667                0.533333
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.633333               0.633333                     0.7
#
#    Occipital_SVC_acc
# 0               0.65
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0                  0.55           0.783333                     0.7
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.666667               0.55                0.616667
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                      0.6                      0.6                  0.533333
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.616667                 0.516667                  0.583333
#
#    Occipital_Ada_B_acc
# 0             0.566667
# N1
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0             0.7625          0.7125                  0.8
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0                0.7625            0.75                 0.75
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0                0.7375                0.7875                  0.725
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0            0.725                  0.75                   0.75
#
#    Occipital_RF_acc
# 0             0.775
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0                0.75            0.775                 0.775
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0                  0.775            0.725                 0.775
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0                  0.725                  0.775                    0.75
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0               0.7                   0.75                   0.675
#
#    Occipital_SVC_acc
# 0             0.7375
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0                  0.65             0.5375                  0.6875
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                   0.6375              0.525                  0.6875
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                    0.625                    0.675                    0.5375
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0              0.5625                     0.65                    0.6375
#
#    Occipital_Ada_B_acc
# 0               0.6875
# N2
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.441667        0.527778             0.513889
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.440278          0.5375             0.454167
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.486111              0.529167               0.494444
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.559722              0.545833               0.465278
#
#    Occipital_RF_acc
# 0          0.520833
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.616667         0.629167              0.629167
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.629167         0.583333              0.629167
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.629167               0.629167                0.629167
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.606944               0.629167                0.629167
#
#    Occipital_SVC_acc
# 0           0.629167
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.380556               0.45                  0.4875
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.548611           0.518056                0.431944
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.545833                      0.4                  0.473611
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0                 0.5                 0.643056                  0.365278
#
#    Occipital_Ada_B_acc
# 0             0.509722
# N3
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.569444        0.572222             0.586111
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.523611        0.583333             0.520833
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.534722                0.4625               0.536111
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.533333              0.569444               0.548611
#
#    Occipital_RF_acc
# 0          0.544444
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.541667         0.581944              0.581944
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.556944         0.629167              0.629167
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.629167               0.606944                0.629167
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.629167               0.629167                0.629167
#
#    Occipital_SVC_acc
# 0           0.629167
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.465278           0.461111                0.522222
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.434722           0.436111                0.469444
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.411111                 0.594444                     0.425
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.508333                 0.541667                      0.45
#
#    Occipital_Ada_B_acc
# 0             0.520833
# REM
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0             0.5375          0.4375               0.5125
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0                  0.45          0.5625               0.5625
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0                 0.525                   0.5                  0.375
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0              0.5                 0.525                 0.4625
#
#    Occipital_RF_acc
# 0            0.4625
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0                0.65             0.65                  0.65
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0                 0.6375             0.65                  0.65
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0                   0.65                  0.625                   0.625
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0              0.65                   0.65                  0.6375
#
#    Occipital_SVC_acc
# 0             0.6375
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0                 0.575                0.5                  0.5125
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                   0.3625             0.5625                   0.575
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                   0.5375                     0.45                      0.35
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0               0.475                     0.55                    0.4875
#
#    Occipital_Ada_B_acc
# 0                 0.55

# %% [markdown]
# ## Expt 2

# %%
#Run Expt 2 experiments 

t1 = time.time()

expt_2_results = {}

for data_type in data_types:
    X_y_groups = loaded_data[data_type]
    
    X = X_y_groups['X']
    y = X_y_groups['y'] 
    groups = X_y_groups['groups'] 
    
    #1.Generate expt specific X,y,groups
    X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, 2 )

    results_df = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt, {'RF' : RandomForestClassifier(random_state = 5) , 'SVC' : SVC(), 'Ada_B' : AdaBoostClassifier(random_state = 5)}, return_df = True , subset_names_and_cols = regional_features_dict, random_states = [1,2] )
    
    expt_2_results[data_type] = results_df

t2 = time.time()

t2-t1
# Out:
# 105.87876677513123

# %%
#Show the results
for data_type in data_types:
    print(data_type)
    results_df = expt_2_results[data_type]
    res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)
    #print the results 
    # print(res_df[[col for col in res_df.columns if 'acc' in col]].mean(axis = 0))
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'RF' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'SVC' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'Ada_B' in col]].mean(axis = 0)).T)
# Out:
# Wake
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0                0.7        0.614286             0.576786
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0                0.6375        0.391071             0.473214
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.407143              0.378571               0.351786
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.469643              0.578571               0.501786
#
#    Occipital_RF_acc
# 0          0.528571
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.601786            0.475                0.5625
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0                   0.45            0.625              0.623214
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.553571               0.460714                0.514286
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0               0.5               0.528571                0.508929
#
#    Occipital_SVC_acc
# 0           0.514286
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0                0.6625           0.607143                0.591071
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.603571           0.503571                0.407143
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.433929                 0.464286                  0.444643
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.489286                 0.476786                  0.467857
#
#    Occipital_Ada_B_acc
# 0                  0.5
# N1
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.637778        0.605556             0.681111
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.595556        0.532222             0.532222
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.575556              0.636667               0.593333
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.607778              0.593333                   0.55
#
#    Occipital_RF_acc
# 0          0.575556
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.678889              0.7                   0.7
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.701111         0.678889                  0.69
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.647778                   0.69                0.678889
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.647778               0.723333                0.627778
#
#    Occipital_SVC_acc
# 0           0.661111
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.574444           0.382222                0.507778
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.465556           0.438889                0.455556
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.378889                 0.528889                  0.477778
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.503333                 0.531111                  0.523333
#
#    Occipital_Ada_B_acc
# 0                 0.51
# N2
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.347778        0.383333             0.301111
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.422222        0.473333             0.414444
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.501111              0.481111               0.566667
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.423333              0.476667               0.404444
#
#    Occipital_RF_acc
# 0          0.511111
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.456667         0.426667              0.458889
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.496667         0.478889              0.457778
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.447778               0.487778                0.427778
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.457778               0.476667                0.487778
#
#    Occipital_SVC_acc
# 0           0.427778
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.367778               0.45                0.363333
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                     0.53           0.415556                0.488889
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.491111                 0.543333                  0.538889
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.371111                 0.487778                      0.37
#
#    Occipital_Ada_B_acc
# 0             0.553333
# N3
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.421111        0.463333                 0.48
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.477778        0.427778             0.467778
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.386667              0.416667               0.488889
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.426667              0.521111               0.471111
#
#    Occipital_RF_acc
# 0          0.508889
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.418889         0.442222              0.391111
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.468889         0.368889              0.391111
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.368889               0.368889                     0.4
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.381111                   0.35                0.388889
#
#    Occipital_SVC_acc
# 0           0.348889
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.448889           0.452222                0.545556
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.478889           0.421111                0.478889
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.364444                 0.463333                  0.381111
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.357778                 0.376667                  0.457778
#
#    Occipital_Ada_B_acc
# 0                 0.54
# REM
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.488889        0.447778             0.394444
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.468889        0.467778             0.465556
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0                  0.48              0.456667               0.381111
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.406667              0.403333               0.393333
#
#    Occipital_RF_acc
# 0          0.381111
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0                0.49             0.49                  0.52
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.458889         0.541111                  0.49
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0                   0.47               0.478889                0.488889
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.478889               0.478889                0.478889
#
#    Occipital_SVC_acc
# 0               0.51
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.511111           0.468889                0.503333
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.417778           0.491111                0.553333
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.563333                     0.54                  0.424444
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.454444                 0.445556                  0.413333
#
#    Occipital_Ada_B_acc
# 0             0.502222

# %% [markdown]
# ## Expt 3

# %%
#Run Expt 3 experiments 

t1 = time.time()

expt_3_results = {}

for data_type in data_types:
    X_y_groups = loaded_data[data_type]
    
    X = X_y_groups['X']
    y = X_y_groups['y'] 
    groups = X_y_groups['groups'] 
    
    #1.Generate expt specific X,y,groups
    X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, 3)

    results_df = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt, {'RF' : RandomForestClassifier(random_state = 5) , 'SVC' : SVC(), 'Ada_B' : AdaBoostClassifier(random_state = 5)} , return_df = True , subset_names_and_cols = regional_features_dict, random_states = [1,2] )
    
    expt_3_results[data_type] = results_df

t2 = time.time()

t2-t1
# Out:
# 1800.8339302539825

# %%
#Show the results
for data_type in data_types:
    print(data_type)
    results_df = expt_3_results[data_type]
    res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)
    #print the results 
    # print(res_df[[col for col in res_df.columns if 'acc' in col]].mean(axis = 0))
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'RF' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'SVC' in col]].mean(axis = 0)).T)
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col and 'Ada_B' in col]].mean(axis = 0)).T)
# Out:
# Wake
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.493939            0.348485              0.314394
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.355303         0.250758           0.429545             0.354545
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0               0.32197                0.366667              0.385606  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.287121              0.311364               0.303788
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.250758                0.27803                0.287121
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.313636          0.251515           0.303788
#
#    Occipital_Ada_B_acc
# 0             0.311364
#
# [1 rows x 39 columns]
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.493939        0.355303             0.354545
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.385606        0.268182             0.273485
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0                  0.25              0.250758               0.265152
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.285606              0.311364                0.27803
#
#    Occipital_RF_acc
# 0          0.251515
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.348485         0.250758               0.32197
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.250758         0.287121              0.295455
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.332576                0.27803                    0.35
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.294697               0.303788                0.287121
#
#    Occipital_SVC_acc
# 0           0.303788
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.314394           0.429545                0.366667
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.384848           0.284091                0.357576
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.284091                 0.267424                  0.249242
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.287121                 0.250758                  0.313636
#
#    Occipital_Ada_B_acc
# 0             0.311364
# N1
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.483333            0.515238              0.374286
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.408571         0.530476           0.388095             0.470952
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.585238                 0.34619              0.452381  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0             0.34619              0.372857               0.509048
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.325714               0.337619                0.472857
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.301429          0.268095           0.423333
#
#    Occipital_Ada_B_acc
# 0             0.288571
#
# [1 rows x 39 columns]
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.483333        0.408571             0.470952
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.452381        0.471429             0.414286
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.500952              0.437619               0.429524
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.401905              0.372857               0.337619
#
#    Occipital_RF_acc
# 0          0.268095
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.515238         0.530476              0.585238
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.564762         0.439048                  0.46
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.467143               0.593333                0.557619
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.479524               0.509048                0.472857
#
#    Occipital_SVC_acc
# 0           0.423333
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.374286           0.388095                 0.34619
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.309524           0.400476                0.393333
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.403333                 0.357619                  0.401429
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0             0.34619                 0.325714                  0.301429
#
#    Occipital_Ada_B_acc
# 0             0.288571
# N2
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.303333            0.205714              0.288571
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.287143         0.190476           0.343333             0.259524
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.198095                0.295238              0.280952  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.267143                  0.34               0.247143
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.324762               0.317619                0.311429
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.352381          0.366667           0.282857
#
#    Occipital_Ada_B_acc
# 0             0.276667
#
# [1 rows x 39 columns]
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.303333        0.287143             0.259524
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.280952        0.459524              0.34619
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.381905               0.29619               0.338571
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.423333                  0.34               0.317619
#
#    Occipital_RF_acc
# 0          0.366667
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.205714         0.190476              0.198095
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.225714         0.325714              0.268571
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0               0.304286               0.225714                0.232857
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.311429               0.247143                0.311429
#
#    Occipital_SVC_acc
# 0           0.282857
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.288571           0.343333                0.295238
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.239048           0.288095                0.394762
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.351905                 0.280952                  0.409048
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.267143                 0.324762                  0.352381
#
#    Occipital_Ada_B_acc
# 0             0.276667
# N3
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.220952            0.249524              0.282381
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.227143         0.248571           0.247619             0.239524
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.200476                0.289524              0.255238  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.296667              0.209048               0.201429
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.268571               0.191905                0.201905
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.248571          0.235238           0.243333
#
#    Occipital_Ada_B_acc
# 0             0.244762
#
# [1 rows x 39 columns]
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.220952        0.227143             0.239524
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.255238        0.290476             0.193333
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.248095              0.186667                0.19381
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.226667              0.209048               0.191905
#
#    Occipital_RF_acc
# 0          0.235238
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.249524         0.248571              0.200476
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.270476         0.257619              0.270476
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0                   0.25               0.174286                0.214762
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.229524               0.201429                0.201905
#
#    Occipital_SVC_acc
# 0           0.243333
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.282381           0.247619                0.289524
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.295238           0.448571                0.345714
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.269048                 0.305238                  0.207619
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0            0.296667                 0.268571                  0.248571
#
#    Occipital_Ada_B_acc
# 0             0.244762
# REM
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.428022            0.275275              0.368132
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.436264         0.231319           0.346703             0.442857
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.252747                0.427473              0.434615  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0             0.32033              0.357143               0.238462
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.347802               0.354396                0.281319
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.348901          0.305495           0.245604
#
#    Occipital_Ada_B_acc
# 0             0.379121
#
# [1 rows x 39 columns]
#    Prefrontal_RF_acc  Frontal_RF_acc  Left Frontal_RF_acc  \
# 0           0.428022        0.436264             0.442857
#
#    Right Frontal_RF_acc  Central_RF_acc  Left Central_RF_acc  \
# 0              0.434615        0.413187             0.377473
#
#    Right Central_RF_acc  Left Temporal_RF_acc  Right Temporal_RF_acc  \
# 0              0.427473               0.36978               0.356044
#
#    Parietal_RF_acc  Left Parietal_RF_acc  Right Parietal_RF_acc  \
# 0         0.340659              0.357143               0.354396
#
#    Occipital_RF_acc
# 0          0.305495
#    Prefrontal_SVC_acc  Frontal_SVC_acc  Left Frontal_SVC_acc  \
# 0            0.275275         0.231319              0.252747
#
#    Right Frontal_SVC_acc  Central_SVC_acc  Left Central_SVC_acc  \
# 0               0.224176         0.297253              0.341209
#
#    Right Central_SVC_acc  Left Temporal_SVC_acc  Right Temporal_SVC_acc  \
# 0                0.31978               0.304945                0.282967
#
#    Parietal_SVC_acc  Left Parietal_SVC_acc  Right Parietal_SVC_acc  \
# 0          0.252747               0.238462                0.281319
#
#    Occipital_SVC_acc
# 0           0.245604
#    Prefrontal_Ada_B_acc  Frontal_Ada_B_acc  Left Frontal_Ada_B_acc  \
# 0              0.368132           0.346703                0.427473
#
#    Right Frontal_Ada_B_acc  Central_Ada_B_acc  Left Central_Ada_B_acc  \
# 0                 0.421429           0.391209                0.326374
#
#    Right Central_Ada_B_acc  Left Temporal_Ada_B_acc  Right Temporal_Ada_B_acc  \
# 0                 0.369231                 0.353846                  0.369231
#
#    Parietal_Ada_B_acc  Left Parietal_Ada_B_acc  Right Parietal_Ada_B_acc  \
# 0             0.32033                 0.347802                  0.348901
#
#    Occipital_Ada_B_acc
# 0             0.379121

# %% [markdown]
# ## Expt 4

# %%
t1 = time.time()

expt_4_results = {}

for data_type in data_types:
    X_y_groups = loaded_data[data_type]
    
    X = X_y_groups['X']
    y = X_y_groups['y'] 
    groups = X_y_groups['groups'] 
    
    #1.Generate expt specific X,y,groups
    X_expt , y_expt , groups_expt, expt_info = run_expts.generate_expt_x_y_groups(X,y,groups, 4)

    results_df = run_expts.run_mv_tsc(X_expt,y_expt,groups_expt, {'RF' : RandomForestClassifier(random_state = 5) , 'SVC' : SVC(), 'Ada_B' : AdaBoostClassifier(random_state = 5)} , return_df = True , subset_names_and_cols = regional_features_dict, random_states = [1,2] )
    
    expt_4_results[data_type] = results_df

t2 = time.time()

t2-t1
# Out:
# 881.6521239280701

# %%
#Show the results
for data_type in data_types:
    print(data_type)
    results_df = expt_4_results[data_type]
    res_df = run_expts.generate_subset_acc_std(results_df, return_df = True)
    #print the results 
    # print(res_df[[col for col in res_df.columns if 'acc' in col]].mean(axis = 0))
    display(pd.DataFrame(res_df[[col for col in res_df.columns if 'acc' in col]].mean(axis = 0)).T)
# Out:
# Wake
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.367424            0.241667              0.243182
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.372727         0.249242           0.355303             0.364394
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.249242                0.365152              0.437121  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.260606              0.300758               0.276515
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.268182                  0.275                0.277273
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.232576          0.287121           0.250758
#
#    Occipital_Ada_B_acc
# 0              0.29697
#
# [1 rows x 39 columns]
# N1
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.401905            0.508095              0.345238
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.409524         0.501905           0.309524             0.409524
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0                  0.55                0.345238              0.416667  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.248571              0.333333               0.445238
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.318095               0.310952                0.450952
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.338095          0.295238           0.401905
#
#    Occipital_Ada_B_acc
# 0             0.310952
#
# [1 rows x 39 columns]
# N2
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.269048                0.24              0.330476
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.274286         0.218571           0.324286             0.169048
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0                  0.24                0.297143              0.288571  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.353333              0.319524                   0.29
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.374286               0.275238                0.311429
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.312381          0.324286           0.282857
#
#    Occipital_Ada_B_acc
# 0             0.338095
#
# [1 rows x 39 columns]
# N3
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.192381            0.229048              0.234762
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.213333         0.228571            0.25619             0.184762
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.208571                    0.29              0.267143  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0             0.23619              0.180952               0.222857
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.235238                0.20619                 0.21619
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.291429          0.187143           0.223333
#
#    Occipital_Ada_B_acc
# 0             0.270952
#
# [1 rows x 39 columns]
# REM
#    Prefrontal_RF_acc  Prefrontal_SVC_acc  Prefrontal_Ada_B_acc  \
# 0           0.392857            0.310989              0.368132
#
#    Frontal_RF_acc  Frontal_SVC_acc  Frontal_Ada_B_acc  Left Frontal_RF_acc  \
# 0        0.413187         0.274176           0.348901             0.420879
#
#    Left Frontal_SVC_acc  Left Frontal_Ada_B_acc  Right Frontal_RF_acc  ...  \
# 0              0.274176                0.313187              0.362088  ...
#
#    Parietal_Ada_B_acc  Left Parietal_RF_acc  Left Parietal_SVC_acc  \
# 0            0.341209               0.42033               0.281319
#
#    Left Parietal_Ada_B_acc  Right Parietal_RF_acc  Right Parietal_SVC_acc  \
# 0                 0.383516               0.354945                0.338462
#
#    Right Parietal_Ada_B_acc  Occipital_RF_acc  Occipital_SVC_acc  \
# 0                  0.325824           0.28956           0.295604
#
#    Occipital_Ada_B_acc
# 0             0.347802
#
# [1 rows x 39 columns]
