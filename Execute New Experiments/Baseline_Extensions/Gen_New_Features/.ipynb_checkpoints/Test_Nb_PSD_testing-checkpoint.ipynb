# %% [markdown]
# Import things to note when calculating PSD <br>
# Method to use (Welch) , Window size , overlap , etc... - Atm I have 4 second window with 50% overlap <br>
# See this website for some good info : https://sapienlabs.org/lab-talk/factors-that-impact-power-spectrum-density-estimation/#:~:text=The%20Welch%20method%20is%20another,pwelch()%20command%20in%20MATLAB. <br>
# Scroll to bottom of the page for their summary <br>

# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
# Out:
# /user/home/ko20929/.conda/envs/sktime_latest/lib/python3.11/site-packages/antropy/fractal.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @jit((types.Array(types.float64, 1, "C", readonly=True), types.int32))

# %%
#Load the data and focus on one df specifically

t1 = time.time()

paths , class_list, sleep_night_list , sleep_type_list , participant_id_list = constants.generate_paths_and_info(blue_pebble = True)

path = paths[0]

with io.capture_output() as captured:
    data_epo = mne.read_epochs(path)
    sampling_freq =  data_epo.info['sfreq']  # find sampling frequency
    channels = data_epo.ch_names  # extract channel names
    data = data_epo._data * 1e6  # convert signal from V to uV
    
# Generate dataframe with channels as columns, samples ordered by time _____________________________________________________
channels = constants.channel_list
df_full = data_epo.to_data_frame()
df = df_full[channels].copy()

df

t2 = time.time()

t2-t1
# Out:
# 0.3350491523742676

# %%
t1 = time.time()

#1.Generate the window indices 
window_indices = eeg_stat_ts.gen_window_indices(6, df , samp_freq = 256)
#2. Calculate bpw vals per window
bpw_per_win_df = eeg_stat_ts.gen_statistic_per_window(df , window_indices , stat = 'bpw')

t2 = time.time()

t2-t1
# Out:
# 0.48745059967041016

# %%
df_2 = df*2

win_s = 4
samp_freq = 256
channels = constants.channel_list

win = int(win_s * samp_freq) #Window for Welchs Periodagram
freqs, psd = welch(df_2.T.values , fs = samp_freq, nperseg=win, average='median')

fig = plt.figure()
fig = plt.figure(figsize=(20,10),dpi=100)
plt.scatter(freqs[:150] , psd[0, :][:150], marker=".")
plt.scatter(freqs[:150] , psd[20, :][:150] , marker=".")
plt.scatter(freqs[:150] , psd[30, :][:150] , marker=".")
plt.scatter(freqs[:150] , psd[40, :][:150] , marker=".")
plt.scatter(freqs[:150] , psd[50, :][:150] , marker=".")
plt.plot([1.5 ,1.5 ] , [0,140])

# %%
win_s = 4
samp_freq = 256
channels = constants.channel_list

win = int(win_s * samp_freq) #Window for Welchs Periodagram
freqs, psd = welch(df.T.values , fs = samp_freq, nperseg=win, average='median')

# %%
psd[: , index_num : ].shape
# Out:
# (57, 495)

# %%
cut_off_freq = 4.5 #Keeps this frequency and higher
index_num = np.searchsorted(freqs, cut_off_freq , side = 'left') #Left gives you index of element that is equal to or less than what you input
freqs_new = freqs[index_num : ]

# %%
row_sums = np.sum(psd, axis=1, keepdims=True)
psd_normalised = np.divide(psd, row_sums)
psd_normalised

psd = psd_normalised

fig = plt.figure()
fig = plt.figure(figsize=(20,10),dpi=100)
plt.scatter(freqs[:150] , psd[0, :][:150], marker=".")
plt.scatter(freqs[:150] , psd[20, :][:150] , marker=".")
plt.scatter(freqs[:150] , psd[30, :][:150] , marker=".")
plt.scatter(freqs[:150] , psd[40, :][:150] , marker=".")
plt.scatter(freqs[:150] , psd[50, :][:150] , marker=".")

# %% [markdown]
# ### Testing Frequency Max Values Calculation

# %%
win = int(win_s * samp_freq) #Window for Welchs Periodagram
freqs, psd = welch(df.T.values , fs = samp_freq, nperseg=win, average='median')

# %%
#Keep cut off frequency and higher
cut_off_freq = 1.25
index_num = np.searchsorted(freqs, cut_off_freq , side = 'left') #Left gives you index of element that is equal to or less than what you input
freqs = freqs[index_num : ] 
psd = psd[: , index_num : ]

# %%
row_sums = np.sum(psd, axis=1, keepdims=True)
psd_normalised = np.divide(psd, row_sums)

# %%
channel_psd_normalised = pd.DataFrame(psd_normalised, index=channels , columns=freqs) #convert psd array into dataframe

# %%
channel_psd_normalised
# Out:
#         1.25      1.50      1.75      2.00      2.25      2.50      2.75    \
# Fp1   0.061669  0.045708  0.027904  0.031676  0.029021  0.020725  0.014646
# Fpz   0.063410  0.048962  0.028507  0.027280  0.021933  0.016305  0.013501
# Fp2   0.055746  0.050399  0.032626  0.030267  0.022386  0.017107  0.014556
# F1    0.026012  0.025549  0.016471  0.016647  0.015167  0.014921  0.013543
# Fz    0.031618  0.022115  0.018062  0.012782  0.016164  0.015773  0.013081
# F2    0.040846  0.025538  0.016850  0.013815  0.014615  0.011644  0.011734
# AF7   0.060805  0.043780  0.031724  0.025167  0.028143  0.019557  0.014647
# F7    0.051354  0.043838  0.033943  0.025911  0.029442  0.017838  0.015152
# F5    0.050647  0.033020  0.021605  0.020225  0.019736  0.013541  0.011528
# F3    0.046385  0.027215  0.020486  0.016221  0.014810  0.011909  0.011480
# AF8   0.059072  0.039693  0.028391  0.023555  0.023317  0.017227  0.012691
# F8    0.050705  0.034163  0.028509  0.021809  0.022076  0.015962  0.015230
# F6    0.044883  0.036767  0.021847  0.020664  0.018339  0.015830  0.013584
# F4    0.042823  0.035363  0.020261  0.016993  0.016301  0.016175  0.015381
# FCz   0.029644  0.024628  0.021064  0.018136  0.013998  0.017265  0.018654
# FC1   0.026544  0.025836  0.016797  0.015644  0.018825  0.019191  0.015440
# FC2   0.031049  0.031599  0.019811  0.016774  0.016933  0.015069  0.015327
# Cz    0.040181  0.032210  0.028196  0.022156  0.021181  0.022692  0.019555
# C1    0.040253  0.033595  0.027299  0.022624  0.018370  0.019575  0.017922
# C2    0.046658  0.037319  0.027720  0.023045  0.021555  0.018091  0.015469
# CP1   0.045568  0.038988  0.029076  0.024609  0.021715  0.018570  0.019276
# CP2   0.054564  0.044720  0.027378  0.025291  0.018023  0.015177  0.016017
# FC5   0.048419  0.034551  0.020456  0.020817  0.021335  0.012978  0.012527
# FC3   0.027054  0.023643  0.020795  0.016303  0.016838  0.016151  0.013479
# C5    0.042665  0.021740  0.014113  0.015416  0.014134  0.011791  0.013025
# C3    0.032459  0.034603  0.024887  0.019425  0.014705  0.015533  0.013645
# CP5   0.027505  0.020709  0.015097  0.014883  0.012500  0.010808  0.011284
# CP3   0.035021  0.031008  0.021359  0.020059  0.014530  0.014385  0.012463
# FC6   0.048194  0.040269  0.024755  0.016858  0.016536  0.014418  0.012190
# FCz   1.402094e-13  1.989789e-13  1.312004e-13
# FC1   1.247509e-13  2.471954e-13  2.125884e-13
# FC2   1.539195e-13  2.704637e-13  2.342635e-13
# Cz    1.761729e-13  2.748075e-13  1.745367e-13
# C1    1.634845e-13  4.705846e-13  6.016211e-13
# C2    2.497725e-13  3.707192e-13  4.130764e-13
# CP1   2.570258e-13  2.524412e-13  1.553538e-13
# CP2   2.634476e-13  3.290795e-13  2.065461e-13
# FC5   6.166582e-13  1.151621e-12  5.672285e-13
# FC3   2.147136e-13  3.171110e-13  1.406677e-13
# C5    7.611592e-13  2.059530e-12  1.517165e-12
# C3    3.076797e-13  5.663249e-13  5.510455e-13
# CP5   8.497711e-13  7.803300e-13  3.420616e-13
# CP3   3.575659e-13  3.843065e-13  1.467776e-13
# FC6   7.227092e-13  1.103818e-12  9.882256e-13
# FC4   3.322972e-13  4.810318e-13  4.655509e-13
# C6    5.773108e-13  1.846708e-12  1.488346e-12
# C4    3.123876e-13  6.052446e-13  4.011660e-13
# CP6   3.642110e-13  6.523461e-13  4.113930e-13
# CP4   2.554597e-13  4.726681e-13  3.069960e-13
# TP7   2.390980e-12  2.661557e-12  1.027690e-12
# T7    1.268534e-12  1.858404e-12  1.033831e-12
# FT7   5.549505e-13  2.271261e-12  1.654656e-12
# FT9   7.853876e-13  1.034467e-12  6.616423e-13
# TP8   5.249040e-13  8.634028e-13  1.808375e-13
# T8    5.561076e-13  7.911849e-13  3.662487e-13
# FT8   5.957390e-13  1.286843e-12  9.203447e-13
# FT10  5.959553e-13  1.402289e-12  5.359316e-13
# P1    2.118872e-13  2.496359e-13  1.005775e-13
# P2    2.333813e-13  5.234094e-13  5.492264e-13
# Pz    2.613295e-13  3.015236e-13  6.929599e-14
# P3    2.474046e-13  2.657405e-13  1.257608e-13
# P5    7.544158e-13  9.628106e-13  3.948376e-13
# P7    2.055301e-12  1.679163e-12  3.746881e-13
# PO7   7.760348e-13  1.170995e-12  3.419462e-13
# P4    2.468963e-13  3.916922e-13  1.480809e-13
# P6    6.626093e-13  8.816455e-13  2.807831e-13
# P8    5.417139e-13  7.924621e-13  2.580366e-13
# PO8   6.878351e-13  9.245047e-13  3.209056e-13
# POz   3.046497e-13  3.851026e-13  2.390905e-13
# O1    5.023789e-13  6.567158e-13  2.194920e-13
# O2    7.332302e-13  6.649526e-13  1.885067e-13
# Oz    4.689624e-13  6.187813e-13  2.173473e-13
#
# [57 rows x 508 columns]

# %%
channel_to_region_dict = {}
for channel in constants.channel_list:
    for region in constants.regions:
        if channel in constants.region_to_channel_dict[region]:
            channel_to_region_dict[channel] = region

# %%
#From the normalised PSD Dataframe, caluclate the max power values and corresponding frequency values
# Create a new DataFrame with maximum, second-highest, third-highest, and fourth-highest values
# along with their corresponding column names

sorted_values = channel_psd_normalised.apply(lambda row: sorted(zip(row, row.index), reverse=True), axis=1)

max_values = sorted_values.apply(lambda row: row[0][0])
max_columns = sorted_values.apply(lambda row: row[0][1])

second_max_values = sorted_values.apply(lambda row: row[1][0])
second_max_columns = sorted_values.apply(lambda row: row[1][1])

third_max_values = sorted_values.apply(lambda row: row[2][0])
third_max_columns = sorted_values.apply(lambda row: row[2][1])

fourth_max_values = sorted_values.apply(lambda row: row[3][0])
fourth_max_columns = sorted_values.apply(lambda row: row[3][1])

new_df = pd.DataFrame({'First_Max_Value': max_values, 'First_Max_Freq': max_columns,
                        'Second_Max_Value': second_max_values, 'Second_Max_Freq': second_max_columns,
                        'Third_Max_Value': third_max_values, 'Third_Max_Freq': third_max_columns,
                        'Fourth_Max_Value': fourth_max_values, 'Fourth_Max_Freq': fourth_max_columns},
                       index=channel_psd_normalised.index)

# %%
new_df['Region'] = [channel_to_region_dict[channel] for channel in new_df.index]

# %%
for region in constants.regions:
    display( new_df[new_df['Region'] == region] )
# Out:
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# Fp1         0.061669            1.25          0.045708              1.5
# Fpz         0.063410            1.25          0.048962              1.5
# Fp2         0.055746            1.25          0.050399              1.5
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# Fp1         0.031676            2.00          0.029021             2.25
# Fpz         0.028507            1.75          0.027280             2.00
# Fp2         0.032626            1.75          0.030267             2.00
#
#          Region
# Fp1  Prefrontal
# Fpz  Prefrontal
# Fp2  Prefrontal
#     First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# F1         0.042436            7.00          0.033404             6.75
# Fz         0.041169            7.00          0.034326             6.75
# F2         0.040846            1.25          0.035254             6.75
#
#     Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# F1         0.031814            7.25          0.029880             6.50
# Fz         0.031618            1.25          0.030804             7.25
# F2         0.033687            7.00          0.029183             7.25
#
#      Region
# F1  Frontal
# Fz  Frontal
# F2  Frontal
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# AF7         0.060805            1.25          0.043780             1.50
# F7          0.051354            1.25          0.043838             1.50
# F5          0.050647            1.25          0.033020             1.50
# F3          0.046385            1.25          0.031283             7.25
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# AF7         0.031724            1.75          0.028143             2.25
# F7          0.033943            1.75          0.029442             2.25
# F5          0.029735            7.25          0.026425             6.50
# F3          0.030190            7.00          0.029864             6.50
#
#            Region
# AF7  Left Frontal
# F7   Left Frontal
# F5   Left Frontal
# F3   Left Frontal
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# AF8         0.059072            1.25          0.039693              1.5
# F8          0.050705            1.25          0.034163              1.5
# F6          0.044883            1.25          0.036767              1.5
# F4          0.042823            1.25          0.035363              1.5
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# AF8         0.028391            1.75          0.024314             6.75
# F8          0.033349            6.75          0.028509             1.75
# F6          0.027486            6.75          0.027353             7.25
# F4          0.031188            6.75          0.028229             7.25
#
#             Region
# AF8  Right Frontal
# F8   Right Frontal
# F6   Right Frontal
# F4   Right Frontal
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# FCz         0.035236            7.00          0.031485             7.25
# FC1         0.037318            7.00          0.035961             7.50
# FC2         0.031599            1.50          0.031325             7.00
# Cz          0.040181            1.25          0.032210             1.50
# C1          0.040253            1.25          0.033595             1.50
# C2          0.046658            1.25          0.037319             1.50
# CP1         0.045568            1.25          0.038988             1.50
# CP2         0.054564            1.25          0.044720             1.50
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# FCz         0.029644            1.25          0.029627             7.50
# FC1         0.034744            7.25          0.031377             6.50
# FC2         0.031049            1.25          0.030526             7.50
# Cz          0.029932            7.00          0.028196             1.75
# C1          0.031310            7.00          0.029118             7.25
# C2          0.027720            1.75          0.027243             7.25
# CP1         0.030280            7.00          0.029537             6.75
# CP2         0.034714            7.00          0.034054             6.75
#
#       Region
# FCz  Central
# FC1  Central
# FC2  Central
# Cz   Central
# C1   Central
# C2   Central
# CP1  Central
# CP2  Central
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# FC5         0.048419            1.25          0.034551             1.50
# FC3         0.036912            7.25          0.036865             7.00
# C5          0.042665            1.25          0.036113             7.50
# C3          0.034603            1.50          0.032459             1.25
# CP5         0.033260            7.00          0.033047             7.50
# CP3         0.035021            1.25          0.031008             1.50
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# FC5         0.030534            7.00          0.024280             7.25
# FC3         0.031066            6.75          0.030820             7.50
# C5          0.035614            7.00          0.030973             7.75
# C3          0.028880            7.75          0.027713             7.50
# CP5         0.032811            7.25          0.032422             7.75
# CP3         0.028720            7.25          0.027497             7.00
#
#            Region
# FC5  Left Central
# FC3  Left Central
# C5   Left Central
# C3   Left Central
# CP5  Left Central
# CP3  Left Central
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# FC6         0.048194            1.25          0.040269             1.50
# FC4         0.035490            1.25          0.030495             7.50
# C6          0.037631            7.00          0.036032             7.75
# C4          0.035943            1.25          0.035143             7.00
# CP6         0.036967            7.25          0.035872             7.00
# CP4         0.034897            1.25          0.032867             1.50
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# FC6         0.032545            7.25          0.031179             7.00
# FC4         0.030255            1.50          0.029084             6.75
# C6          0.034541            7.25          0.034378             8.00
# C4          0.029415            7.25          0.025686             7.75
# CP6         0.032485            1.25          0.031789             7.50
# CP4         0.030931            7.00          0.026556             7.75
#
#             Region
# FC6  Right Central
# FC4  Right Central
# C6   Right Central
# C4   Right Central
# CP6  Right Central
# CP4  Right Central
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# TP7         0.047977            7.00          0.039191             6.75
# T7          0.039883            7.25          0.039814             7.00
# FT7         0.047735            1.25          0.036908             1.50
# FT9         0.047699            1.25          0.041888             7.00
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# TP7         0.039085            7.25          0.037555             7.50
# T7          0.038145            1.25          0.034814             6.50
# FT7         0.035883            7.00          0.029723             6.75
# FT9         0.039925            1.50          0.034829             6.75
#
#             Region
# TP7  Left Temporal
# T7   Left Temporal
# FT7  Left Temporal
# FT9  Left Temporal
#       First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# TP8          0.045253            7.00          0.044243             7.25
# T8           0.042527            1.25          0.038385             7.00
# FT8          0.048387            1.25          0.035126             1.50
# FT10         0.051870            1.25          0.033053             7.00
#
#       Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# TP8          0.043052            6.75          0.039657             7.50
# T8           0.037642            7.25          0.035278             1.50
# FT8          0.032132            7.00          0.032014             6.75
# FT10         0.032278            1.50          0.032158             7.25
#
#               Region
# TP8   Right Temporal
# T8    Right Temporal
# FT8   Right Temporal
# FT10  Right Temporal
#     First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# P1         0.060854            1.25          0.037062              1.5
# P2         0.061275            1.25          0.042277              1.5
# Pz         0.071489            1.25          0.047617              1.5
#
#     Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# P1         0.030825            7.00          0.029511             6.75
# P2         0.028823            1.75          0.028730             7.00
# Pz         0.032289            7.00          0.027234             6.75
#
#       Region
# P1  Parietal
# P2  Parietal
# Pz  Parietal
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# P3          0.042796            1.25          0.031960             7.25
# P5          0.037271            7.25          0.035150             6.75
# P7          0.044511            6.75          0.042409             7.00
# PO7         0.039043            1.25          0.038380             7.25
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# P3          0.031685            7.00          0.030034             1.50
# P5          0.034333            7.00          0.031834             1.25
# P7          0.041119            7.25          0.037263             7.50
# PO7         0.038217            6.75          0.036652             7.00
#
#             Region
# P3   Left Parietal
# P5   Left Parietal
# P7   Left Parietal
# PO7  Left Parietal
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# P4          0.046021            1.25          0.038120             1.50
# P6          0.037137            1.25          0.032543             7.50
# P8          0.043537            1.25          0.040627             6.75
# PO8         0.049526            1.25          0.038386             1.50
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# P4          0.028716            6.75          0.027376             7.50
# P6          0.032441            7.00          0.031938             7.25
# P8          0.040587            7.25          0.039019             7.00
# PO8         0.036263            6.75          0.032841             7.00
#
#              Region
# P4   Right Parietal
# P6   Right Parietal
# P8   Right Parietal
# PO8  Right Parietal
#      First_Max_Value  First_Max_Freq  Second_Max_Value  Second_Max_Freq  \
# POz         0.066138            1.25          0.041328             1.50
# O1          0.041399            1.25          0.032749             6.75
# O2          0.043546            1.25          0.040622             1.50
# Oz          0.041705            1.25          0.036269             1.50
#
#      Third_Max_Value  Third_Max_Freq  Fourth_Max_Value  Fourth_Max_Freq  \
# POz         0.026423            7.25          0.025766             6.75
# O1          0.031745            1.50          0.029977             7.25
# O2          0.029598            6.75          0.027304             7.00
# Oz          0.029113            7.00          0.027487             6.75
#
#         Region
# POz  Occipital
# O1   Occipital
# O2   Occipital
# Oz   Occipital
