# %%
import pandas as pd
import mne as mne
import os 
import time
import numpy as np
import matplotlib.pyplot as plt
import joblib
import constants
from IPython.utils import io
import time
import sys
import yasa
from scipy.signal import welch

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score

#Import my modules
import format_eeg_data
import constants
import eeg_stat_ts
import run_expts

# %%
from tsfresh.feature_extraction import ComprehensiveFCParameters
from tsfresh.feature_extraction import MinimalFCParameters
from tsfresh.feature_extraction import extract_features

# %%
#Example Code 
settings = ComprehensiveFCParameters()
extract_features(df, default_fc_parameters=settings)

# %%
data_types = ['Wake','N1', 'N2', 'N3', 'REM']

# %%
load_path = '/user/home/ko20929/work/RBD_using_custom_package/Data/freq_6_second_files/'
X = pd.read_hdf(load_path + 'N1six_second_freq_df.h5', key='df', mode='r') 
X_subset = X.copy()
# Time series columns are -->  list(X_subset.columns)
X_subset.head()
# Out:
#                                        Delta_Central  \
# 0  0     0.109404
# 1     0.128268
# 2     0.388450
# 3...
# 1  0     0.410156
# 1     0.084750
# 2     0.130967
# 3...
# 2  0      0.278528
# 1      0.208112
# 2      0.20785...
# 3  0     0.274910
# 1     0.225020
# 2     0.543252
# 3...
# 4  0     0.140306
# 1     0.321896
# 2     0.251069
# 3...
#
#                                        Theta_Central  \
# 0  0     0.528768
# 1     0.357538
# 2     0.256406
# 3...
# 1  0     0.191052
# 1     0.303427
# 2     0.515542
# 3...
# 2  0      0.459842
# 1      0.489498
# 2      0.54696...
# 3  0     0.156747
# 1     0.428214
# 2     0.201013
# 3...
# 4  0     0.268037
# 1     0.394204
# 2     0.297541
# 3...
#
#                                        Alpha_Central  \
# 0  0     0.139484
# 1     0.247070
# 2     0.098152
# 3...
# 1  0     0.095865
# 1     0.285107
# 2     0.145799
# 3...
# 2  0      0.110260
# 1      0.166030
# 2      0.14542...
# 3  0     0.305831
# 1     0.169870
# 2     0.159707
# 3...
# 4  0     0.406490
# 1     0.151898
# 2     0.271547
# 3...
#
#                                        Sigma_Central  \
# 0  0     0.069121
# 1     0.071003
# 2     0.045401
# 3...
# 1  0     0.078800
# 1     0.200577
# 2     0.070714
# 3...
# 2  0      0.072991
# 1      0.059879
# 2      0.03999...
# 3  0     0.070555
# 1     0.045957
# 2     0.039586
# 3...
# 4  0     0.061803
# 1     0.042039
# 2     0.048904
# 3...
#
#                                         Beta_Central  \
# 0  0     0.137460
# 1     0.169332
# 2     0.113092
# 3...
# 1  0     0.119081
# 1     0.116503
# 2     0.122766
# 3...
# 2  0      0.072213
# 1      0.070097
# 2      0.05381...
# 3  0     0.177365
# 1     0.121809
# 2     0.047816
# 3...
# 4  0     0.113398
# 1     0.077674
# 2     0.119048
# 3...
#
#                                        Gamma_Central  \
# 0  0     0.015763
# 1     0.026789
# 2     0.098499
# 3...
# 1  0     0.105046
# 1     0.009636
# 2     0.014211
# 3...
# 2  0      0.006166
# 1      0.006384
# 2      0.00595...
# 3  0     0.014592
# 1     0.009128
# 2     0.008626
# 3...
# 4  0     0.009965
# 1     0.012288
# 2     0.011891
# 3...
#
#                                  TotalAbsPow_Central  \
# 0  0     56.478214
# 1     35.491996
# 2     25.14322...
# 1  0     33.427454
# 1     82.181849
# 2     61.23712...
# 2  0      42.987080
# 1      43.513680
# 2      44.60...
# 3  0      31.760377
# 1      50.954109
# 2      40.50...
# 4  0      42.084488
# 1      25.407852
# 2      24.35...
#
#                                        Delta_Frontal  \
# 0  0     0.057787
# 1     0.099344
# 2     0.314825
# 3...
# 1  0     0.432127
# 1     0.046141
# 2     0.073484
# 3...
# 2  0      0.350676
# 1      0.231853
# 2      0.25167...
# 3  0     0.291240
# 1     0.212158
# 2     0.665972
# 3...
# 4  0     0.135044
# 1     0.328255
# 2     0.270027
# 3...
#
#                                        Theta_Frontal  \
# 0  0     0.624778
# 1     0.270435
# 2     0.218789
# 3...
# 1  0     0.160412
# 1     0.429877
# 2     0.659885
# 3...
# 2  0      0.342208
# 1      0.474378
# 2      0.48284...
# 3  0     0.206970
# 1     0.471265
# 2     0.141227
# 3...
# 4  0     0.291613
# 1     0.447493
# 2     0.271449
# 3...
#
#                                        Alpha_Frontal  ...  \
# 0  0     0.148776
# 1     0.266792
# 2     0.101929
# 3...  ...
# 1  0     0.077179
# 1     0.310782
# 2     0.100654
# 3...  ...
# 2  0      0.123489
# 1      0.156441
# 2      0.13445...  ...
# 3  0     0.285123
# 1     0.131771
# 2     0.126080
# 3...  ...
# 4  0     0.405658
# 1     0.133345
# 2     0.328917
# 3...  ...
#
#                                  Beta_Right Parietal  \
# 0  0     0.085209
# 1     0.137645
# 2     0.134379
# 3...
# 1  0     0.079292
# 1     0.066283
# 2     0.092278
# 3...
# 2  0      0.035318
# 1      0.018583
# 2      0.02454...
# 3  0     0.160048
# 1     0.080978
# 2     0.029375
# 3...
# 4  0     0.058732
# 1     0.049240
# 2     0.085958
# 3...
#
#                                 Gamma_Right Parietal  \
# 0  0     0.029426
# 1     0.039926
# 2     0.145236
# 3...
# 1  0     0.054259
# 1     0.008816
# 2     0.009735
# 3...
# 2  0      0.005834
# 1      0.004263
# 2      0.00647...
# 3  0     0.014892
# 1     0.007601
# 2     0.005147
# 3...
# 4  0     0.004541
# 1     0.006880
# 2     0.009038
# 3...
#
#                           TotalAbsPow_Right Parietal  \
# 0  0     57.729249
# 1     34.627984
# 2     25.32113...
# 1  0     27.420742
# 1     89.509303
# 2     73.49035...
# 2  0      42.083418
# 1      64.507383
# 2      46.63...
# 3  0      35.204343
# 1      60.213843
# 2      67.24...
# 4  0     172.308857
# 1      73.809288
# 2      60.50...
#
#                                 Delta_Right Temporal  \
# 0  0     0.103704
# 1     0.129549
# 2     0.287141
# 3...
# 1  0     0.563288
# 1     0.122460
# 2     0.239900
# 3...
# 2  0      0.272976
# 1      0.338041
# 2      0.35291...
# 3  0     0.158661
# 1     0.234734
# 2     0.524541
# 3...
# 4  0     0.162786
# 1     0.328281
# 2     0.395475
# 3...
#
#                                 Theta_Right Temporal  \
# 0  0     0.683575
# 1     0.566254
# 2     0.372443
# 3...
# 1  0     0.149562
# 1     0.318702
# 2     0.474626
# 3...
# 2  0      0.555601
# 1      0.383562
# 2      0.46912...
# 3  0     0.156816
# 1     0.446193
# 2     0.250450
# 3...
# 4  0     0.429850
# 1     0.399364
# 2     0.217691
# 3...
#
#                                 Alpha_Right Temporal  \
# 0  0     0.102381
# 1     0.173220
# 2     0.125083
# 3...
# 1  0     0.133719
# 1     0.259901
# 2     0.101919
# 3...
# 2  0      0.082374
# 1      0.167539
# 2      0.09498...
# 3  0     0.522718
# 1     0.201080
# 2     0.142770
# 3...
# 4  0     0.316125
# 1     0.145221
# 2     0.269558
# 3...
#
#                                 Sigma_Right Temporal  \
# 0  0     0.037748
# 1     0.047110
# 2     0.061926
# 3...
# 1  0     0.046306
# 1     0.187723
# 2     0.081428
# 3...
# 2  0      0.039841
# 1      0.049630
# 2      0.02722...
# 3  0     0.052931
# 1     0.049839
# 2     0.044872
# 3...
# 4  0     0.027090
# 1     0.043778
# 2     0.038310
# 3...
#
#                                  Beta_Right Temporal  \
# 0  0     0.061342
# 1     0.070038
# 2     0.105391
# 3...
# 1  0     0.066633
# 1     0.094749
# 2     0.086383
# 3...
# 2  0      0.039838
# 1      0.047175
# 2      0.04050...
# 3  0     0.099408
# 1     0.061512
# 2     0.031993
# 3...
# 4  0     0.056098
# 1     0.067717
# 2     0.068431
# 3...
#
#                                 Gamma_Right Temporal  \
# 0  0     0.011249
# 1     0.013828
# 2     0.048015
# 3...
# 1  0     0.040492
# 1     0.016465
# 2     0.015744
# 3...
# 2  0      0.009370
# 1      0.014052
# 2      0.01525...
# 3  0     0.009466
# 1     0.006642
# 2     0.005375
# 3...
# 4  0     0.008050
# 1     0.015640
# 2     0.010535
# 3...
#
#                           TotalAbsPow_Right Temporal
# 0  0      65.601458
# 1      46.966847
# 2      25.92...
# 1  0     30.419358
# 1     52.505531
# 2     47.52746...
# 2  0      25.098137
# 1      21.298825
# 2      18.37...
# 3  0      37.276911
# 1      50.858296
# 2      55.43...
# 4  0      94.903393
# 1      47.946219
# 2      55.28...
#
# [5 rows x 91 columns]

# %%
t1 = time.time()
ts_fresh_df = format_eeg_data.convert_sktime_df_to_ts_fresh_format(X_subset, ts_cols = list(X_subset.columns))
t2 = time.time()
print(t2-t1)
# Out:
# 0.3066415786743164

# %%
t1 = time.time()

settings = MinimalFCParameters()
extracted_ts_fresh_df = extract_features(ts_fresh_df, column_id = 'id' , column_sort = 'time',  default_fc_parameters=settings)

t2 = time.time()
t2-t1
# Out:
# 23-Aug-23 17:31:07 | WARNING | Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 158/158 [00:01<00:00, 83.05it/s]
# 3.09556245803833

# %%
region_channel_dict = constants.region_to_channel_dict
list(region_channel_dict.values())
# Out:
# [['Fp1', 'Fpz', 'Fp2'],
#  ['F1', 'Fz', 'F2'],
#  ['AF7', 'F7', 'F5', 'F3'],
#  ['AF8', 'F8', 'F6', 'F4'],
#  ['FCz', 'FC1', 'FC2', 'Cz', 'C1', 'C2', 'CP1', 'CP2'],
#  ['FC5', 'FC3', 'C5', 'C3', 'CP5', 'CP3'],
#  ['FC6', 'FC4', 'C6', 'C4', 'CP6', 'CP4'],
#  ['TP7', 'T7', 'FT7', 'FT9'],
#  ['TP8', 'T8', 'FT8', 'FT10'],
#  ['P1', 'P2', 'Pz'],
#  ['P3', 'P5', 'P7', 'PO7'],
#  ['P4', 'P6', 'P8', 'PO8'],
#  ['POz', 'O1', 'O2', 'Oz']]

# %%
# This code generates a region to features dictionary - this will enable us to run expts regionally as before
regional_features_dict = {}
region_channel_dict = constants.region_to_channel_dict

for region, region_channels in region_channel_dict.items():

# %%
# This code generates a region to features dictionary - this will enable us to run expts regionally as before
regional_features_dict = {}
region_channel_dict = constants.region_to_channel_dict

for region, region_channels in region_channel_dict.items():
    region_features = []
    for channel in region_channels:
        region_features += [feature for feature in X_expt.columns if  feature.startswith(channel) ]
    regional_features_dict[region] = region_features

# %%
extracted_ts_fresh_df
# Out:
#     Delta_Central__sum_values  Delta_Central__median  Delta_Central__mean  \
# 0                   19.637975               0.387197             0.357054
# 1                   28.980683               0.370718             0.362259
# 2                   65.096704               0.435404             0.406854
# 3                   19.090635               0.496688             0.477266
# 4                   14.816290               0.499887             0.493876
# ..                        ...                    ...                  ...
# 66                 169.766664               0.417325             0.435299
# 67                  78.592236               0.464241             0.462307
# 68                  73.117212               0.296013             0.317901
# 69                  26.097714               0.516251             0.521954
# 70                  31.736626               0.535461             0.528944
#
#     Delta_Central__length  Delta_Central__standard_deviation  \
# 0                    55.0                           0.125856
# 1                    80.0                           0.126766
# 2                   160.0                           0.152821
# 3                    40.0                           0.133876
# 4                    30.0                           0.121475
# ..                    ...                                ...
# 66                  390.0                           0.152726
# 67                  170.0                           0.143518
# 68                  230.0                           0.146502
# 69                   50.0                           0.141921
# 70                   60.0                           0.137098
#
#     Delta_Central__variance  Delta_Central__root_mean_square  \
# 0                  0.015840                         0.378586
# 1                  0.016070                         0.383798
# 2                  0.023354                         0.434609
# 3                  0.017923                         0.495687
# 4                  0.014756                         0.508596
# ..                      ...                              ...
# 66                 0.023325                         0.461314
# 67                 0.020597                         0.484072
# 68                 0.021463                         0.350034
# 69                 0.020142                         0.540905
# 70                 0.018796                         0.546422
#
#     Delta_Central__maximum  Delta_Central__absolute_maximum  \
# 0                 0.662517                         0.662517
# 1                 0.665676                         0.665676
# 2                 0.744371                         0.744371
# 3                 0.797804                         0.797804
# 4                 0.702077                         0.702077
# ..                     ...                              ...
# 66                0.895601                         0.895601
# 67                0.815952                         0.815952
# 68                0.762121                         0.762121
# 69                0.853417                         0.853417
# 70                0.816426                         0.816426
#
#     Delta_Central__minimum  ...  TotalAbsPow_Right Temporal__sum_values  \
# 0                 0.109404  ...                             2359.947138
# 1                 0.084750  ...                             2354.892046
# 2                 0.067878  ...                             2896.529176
# 3                 0.125780  ...                             2146.539366
# 4                 0.140306  ...                             1876.877379
# ..                     ...  ...                                     ...
# 66                0.102277  ...                            10134.009318
# 67                0.126492  ...                             4938.882018
# 68                0.072258  ...                             4658.675273
# 69                0.072332  ...                             1624.554073
# 70                0.250980  ...                             1712.489597
#
#     TotalAbsPow_Right Temporal__median  TotalAbsPow_Right Temporal__mean  \
# 0                            38.222806                         42.908130
# 1                            23.853670                         29.436151
# 2                            16.211877                         18.103307
# 3                            45.247793                         53.663484
# 4                            51.173138                         62.562579
# ..                                 ...                               ...
# 66                           22.394881                         25.984639
# 67                           23.409599                         29.052247
# 68                           18.879615                         20.255110
# 69                           27.842989                         32.491081
# 70                           20.614195                         28.541493
#
#     TotalAbsPow_Right Temporal__length  \
# 0                                 55.0
# 1                                 80.0
# 2                                160.0
# 3                                 40.0
# 4                                 30.0
# ..                                 ...
# 66                               390.0
# 67                               170.0
# 68                               230.0
# 69                                50.0
# 70                                60.0
#
#     TotalAbsPow_Right Temporal__standard_deviation  \
# 0                                        18.398822
# 1                                        13.354014
# 2                                        10.187543
# 3                                        28.314061
# 4                                        44.946994
# ..                                             ...
# 66                                       13.533093
# 67                                       16.428265
# 68                                        7.448517
# 69                                       17.269258
# 70                                       16.451766
#
#     TotalAbsPow_Right Temporal__variance  \
# 0                             338.516661
# 1                             178.329677
# 2                             103.786026
# 3                             801.686030
# 4                            2020.232311
# ..                                   ...
# 66                            183.144601
# 67                            269.887893
# 68                             55.480409
# 69                            298.227273
# 70                            270.660614
#
#     TotalAbsPow_Right Temporal__root_mean_square  \
# 0                                      46.686446
# 1                                      32.323624
# 2                                      20.772957
# 3                                      60.674999
# 4                                      77.034464
# ..                                           ...
# 66                                     29.297544
# 67                                     33.375454
# 68                                     21.581239
# 69                                     36.795348
# 70                                     32.943549
#
#     TotalAbsPow_Right Temporal__maximum  \
# 0                            104.196111
# 1                             70.155116
# 2                             70.783535
# 3                            120.935957
# 4                            267.376990
# ..                                  ...
# 66                           138.174468
# 67                           108.053704
# 68                            80.176900
# 69                           112.587969
# 70                            86.632950
#
#     TotalAbsPow_Right Temporal__absolute_maximum  \
# 0                                     104.196111
# 1                                      70.155116
# 2                                      70.783535
# 3                                     120.935957
# 4                                     267.376990
# ..                                           ...
# 66                                    138.174468
# 67                                    108.053704
# 68                                     80.176900
# 69                                    112.587969
# 70                                     86.632950
#
#     TotalAbsPow_Right Temporal__minimum
# 0                             17.232903
# 1                             13.191839
# 2                              6.325506
# 3                             15.363375
# 4                             25.307210
# ..                                  ...
# 66                             8.223181
# 67                             8.524477
# 68                             9.665814
# 69                            14.335049
# 70                            11.278759
#
# [71 rows x 910 columns]
